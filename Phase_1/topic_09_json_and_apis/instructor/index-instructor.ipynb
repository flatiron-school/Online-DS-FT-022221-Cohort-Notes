# %% [markdown]
# # Yelp API - Lab
# https://github.com/jirvingphd/dsc-yelp-api-lab/tree/solution
#
# ## Introduction
#
# We've seen how the Yelp API works and how to create basic visualizations using Folium. It's time to put those skills to work in order to create a working map! Taking things a step further, you'll also independently explore how to perform pagination in order to retrieve a full results set from the Yelp API!
#
# ## Objectives
#
# You will be able to:
#
# * Using pagination and multiple functions, gather large amounts of data from an API, parse the data and make sense of it with meaningful analysis
# * Create maps using Folium
#
# ## Problem Introduction
#
# You've now worked with some API calls, but we have yet to see how to retrieve a more complete dataset in a programmatic manner. Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retrieving 50 at a time. Processes such as these are often referred to as pagination.
#
# In this lab, you will define a search and then paginate over the results to retrieve all of the results. You'll then parse these responses as a DataFrame (for further exploration) and create a map using Folium to visualize the results geographically.
#
# ## Part I - Make the Initial Request
#
# Start by making an initial request to the Yelp API. Your search must include at least 2 parameters: **term** and **location**. For example, you might search for pizza restaurants in NYC. The term and location is up to you but make the request below.

# %%
# Your code here
import json

def get_keys(path):
    with open(path) as f:
        return json.load(f)
    
api_key = get_keys('/Users/jamesirving/.secret/yelp_api.json')['api_key']

# %%
import requests
term = 'Pizza'
location = 'Baltimore, MD'
SEARCH_LIMIT = 10


headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }
url = "https://api.yelp.com/v3/businesses/search"

url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                'limit': SEARCH_LIMIT
            }
response = requests.get(url, headers=headers, params=url_params)
print(response)
print(type(response.text))
print(response.text[:1000])
# Out:
# <Response [200]>
# <class 'str'>
# {"businesses": [{"id": "BJrktyd8gy1bPd9flu54RA", "alias": "isabellas-brick-oven-pizza-and-panini-baltimore", "name": "Isabella's Brick Oven Pizza and Panini", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/5pf2EDd3hiqBGIOUYIQLIA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/isabellas-brick-oven-pizza-and-panini-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ", "review_count": 525, "categories": [{"alias": "italian", "title": "Italian"}, {"alias": "pizza", "title": "Pizza"}, {"alias": "sandwiches", "title": "Sandwiches"}], "rating": 4.5, "coordinates": {"latitude": 39.2870444, "longitude": -76.6020995}, "transactions": ["delivery", "pickup"], "price": "$$", "location": {"address1": "221 S High St", "address2": "", "address3": "", "city": "Baltimore", "zip_code": "21202", "country": "US", "state": "MD", "display_address": ["221 S High St", "Baltimore, MD 21202"]}, "phone":

# %%
## .json
response.json().keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
response.json()['total']
# Out:
# 1200

# %%
import pandas as pd
df = pd.DataFrame(response.json()['businesses'])
df
# Out:
#                        id                                              alias  \
# 0  BJrktyd8gy1bPd9flu54RA    isabellas-brick-oven-pizza-and-panini-baltimore
# 1  417YPonNwsTF-LKjGybNGA                       angelis-pizzeria-baltimore-2
# 2  9PgU81DELsu8GaVX8FT45w                      underground-pizza-baltimore-2
# 3  1n30b0G2weApQ4oEfPMWIA                           matthews-pizza-baltimore
# 4  I0GbQkQHF2sinkmG5vA3hg  bricknfire-at-baltimore-marriott-inner-harbor-...
# 5  y5Xo6_-vDTTuuXYNLYxVJQ                                 iggies-baltimore-2
# 6  UYryiA40L6yj2JX8YZ4G0Q                               joe-bennys-baltimore
# 7  4YQR0ZTvaR-L3Qs9gU-Qfg                    paulie-gees-hampden-baltimore-3
# 8  AtWb8bkh5IEf-GnpK4ORPQ                        joe-squared-pizza-baltimore
# 9  fKmcUEomdGcqMnL7SDYH8A                                    verde-baltimore
#
#                                                 name  \
# 0             Isabella's Brick Oven Pizza and Panini
# 1                                  Angeli's Pizzeria
# 2                                  Underground Pizza
# 3                                    Matthew's Pizza
# 4  BricknFire at Baltimore Marriott Inner Harbor ...
# 5                                             Iggies
# 6                                        Joe Benny's
# 7                               Paulie Gee's Hampden
# 8                                  Joe Squared Pizza
# 9                                              Verde
#
#                                            image_url  is_closed  \
# 0  https://s3-media1.fl.yelpcdn.com/bphoto/5pf2ED...      False
# 1  https://s3-media4.fl.yelpcdn.com/bphoto/285RaN...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/l2yfFl...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/n9refU...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/wLbKlF...      False
# 5  https://s3-media3.fl.yelpcdn.com/bphoto/L2XjGb...      False
# 6  https://s3-media1.fl.yelpcdn.com/bphoto/tEVTcQ...      False
# 7  https://s3-media1.fl.yelpcdn.com/bphoto/pb05-5...      False
# 8  https://s3-media1.fl.yelpcdn.com/bphoto/zIe6Gw...      False
# 9  https://s3-media4.fl.yelpcdn.com/bphoto/iAhavN...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/isabellas-brick-oven-...           525
# 1  https://www.yelp.com/biz/angelis-pizzeria-balt...           239
# 2  https://www.yelp.com/biz/underground-pizza-bal...            37
# 3  https://www.yelp.com/biz/matthews-pizza-baltim...           475
# 4  https://www.yelp.com/biz/bricknfire-at-baltimo...           196
# 5  https://www.yelp.com/biz/iggies-baltimore-2?ad...           392
# 6  https://www.yelp.com/biz/joe-bennys-baltimore?...           725
# 7  https://www.yelp.com/biz/paulie-gees-hampden-b...           298
# 8  https://www.yelp.com/biz/joe-squared-pizza-bal...           460
# 9  https://www.yelp.com/biz/verde-baltimore?adjus...           456
#
#                                           categories  rating  \
# 0  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 1  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 2             [{'alias': 'pizza', 'title': 'Pizza'}]     4.5
# 3             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 4  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.5
# 5             [{'alias': 'pizza', 'title': 'Pizza'}]     4.0
# 6  [{'alias': 'italian', 'title': 'Italian'}, {'a...     4.5
# 7  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
# 8  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     3.5
# 9  [{'alias': 'pizza', 'title': 'Pizza'}, {'alias...     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 39.2870444, 'longitude': -76.6020...  [delivery, pickup]
# 1  {'latitude': 39.2853676681653, 'longitude': -7...          [delivery]
# 2    {'latitude': 39.28907, 'longitude': -76.607268}          [delivery]
# 3  {'latitude': 39.2861976623535, 'longitude': -7...          [delivery]
# 4     {'latitude': 39.28685, 'longitude': -76.62138}  [delivery, pickup]
# 5  {'latitude': 39.2993096, 'longitude': -76.6131...  [delivery, pickup]
# 6  {'latitude': 39.2858595235079, 'longitude': -7...          [delivery]
# 7  {'latitude': 39.3307321665263, 'longitude': -7...  [delivery, pickup]
# 8  {'latitude': 39.31081713119976, 'longitude': -...  [delivery, pickup]
# 9     {'latitude': 39.28411, 'longitude': -76.58249}  [delivery, pickup]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '221 S High St', 'address2': '', ...  +14109628888
# 1    $$  {'address1': '413 S High St', 'address2': '', ...  +14437087556
# 2   NaN  {'address1': '30 Market Pl', 'address2': '', '...  +14433476190
# 3    $$  {'address1': '3131 Eastern Ave', 'address2': '...  +14102768755
# 4    $$  {'address1': '110 S Eutaw St', 'address2': Non...  +14437647847
# 5    $$  {'address1': '818 N Calvert St', 'address2': '...  +14105280818
# 6    $$  {'address1': '313 S High St', 'address2': '', ...  +14438354866
# 7    $$  {'address1': '3535 Chestnut Ave', 'address2': ...  +14108891048
# 8    $$  {'address1': '33 W N Ave', 'address2': None, '...
# 9    $$  {'address1': '641 S Montford Ave', 'address2':...  +14105221000
#
#     display_phone     distance
# 0  (410) 962-8888  2544.246639
# 1  (443) 708-7556  2746.815371
# 2  (443) 347-6190  2255.198296
# 3  (410) 276-8755  4095.106366
# 4  (443) 764-7847  2690.520752
# 5  (410) 528-0818  1139.265413
# 6  (443) 835-4866  2684.570855
# 7  (410) 889-1048  2947.937066
# 8                   768.396054
# 9  (410) 522-1000  3607.136138

# %%
def search_yelp(term = 'Pizza',location = 'Baltimore, MD',params={}):#,SEARCH_LIMIT = 10):

    headers = {'Authorization': 'Bearer {}'.format(api_key)}
    url = "https://api.yelp.com/v3/businesses/search"

    url_params = {'term': term.replace(' ', '+'),
                  'location': location.replace(' ', '+')}
    url_params.update(params)
    response = requests.get(url, headers=headers, params=url_params)
    return response.json()

# %%
response = search_yelp('Chinese')
response
# Out:
# {'businesses': [{'id': 'ry3Y5KSxtn7rVf3amw31rw',
#    'alias': 'china-house-baltimore-2',
#    'name': 'China House',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EjebY0vjN0gFxoCCWJJMGQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/china-house-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 184,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.2856979370117,
#     'longitude': -76.5847778320312},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '2233 Eastern Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Baltimore',
#     'zip_code': '21231',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['2233 Eastern Ave', 'Baltimore, MD 21231']},
#    'phone': '+14105223456',
#    'display_phone': '(410) 522-3456',
#    'distance': 3344.55380067889},
#   {'id': 'ZFFQuoUajWY_gYZ4HjfIKQ',
#    'alias': 'water-song-yunnan-kitchen-baltimore-3',
#    'name': 'Water Song Yunnan Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lL_yo7tRHQSVJpDmZUvJ0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/water-song-yunnan-kitchen-baltimore-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 68,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.276528, 'longitude': -76.613502},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '21 E Cross St',
#     'address2': '',
#     'address3': None,
#     'city': 'Baltimore',
#     'zip_code': '21230',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['21 E Cross St', 'Baltimore, MD 21230']},
#    'phone': '+14438694580',
#    'display_phone': '(443) 869-4580',
#    'distance': 3664.8172088990104},
#   {'id': 'JZlGOTvnm2a8B7eGRlZZUg',
#    'alias': 'nihao-baltimore-2',
#    'name': 'NiHao',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/i5VmneOAKW1rleqryGE9QQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nihao-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 79,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.282945, 'longitude': -76.583924},
#    'transactions': ['delivery'],
#    'location': {'address1': '2322 Boston St',
#     'address2': '',
#     'address3': None,
#     'city': 'Baltimore',
#     'zip_code': '21224',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['2322 Boston St', 'Baltimore, MD 21224']},
#    'phone': '+14438352036',
#    'display_phone': '(443) 835-2036',
#    'distance': 3640.0451267803455},
#   {'id': 'C6ktcKtaj62akb8X0CqAWg',
#    'alias': 'sunny-carry-out-baltimore',
#    'name': 'Sunny Carry Out',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uTMvf4qbZOqVA5KmkHlb3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sunny-carry-out-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 76,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.28325, 'longitude': -76.62783},
#    'transactions': ['pickup'],
#    'price': '$',
#    'location': {'address1': '758 Washington Blvd',
#     'address2': None,
#     'address3': None,
#     'city': 'Baltimore',
#     'zip_code': '21230',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['758 Washington Blvd', 'Baltimore, MD 21230']},
#    'phone': '+14102448816',
#    'display_phone': '(410) 244-8816',
#    'distance': 3317.393328446631},
#   {'id': 'Mt8KF8_1T27QAY3ol1S2cg',
#    'alias': 'wow-food-cafe-baltimore-9',
#    'name': 'WOW Food Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O8J8BF4mR8a95j4y77K71A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/wow-food-cafe-baltimore-9?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 177,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.292012, 'longitude': -76.616007},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '222 N Charles St',
#     'address2': '',
#     'address3': '',
#     'city': 'Baltimore',
#     'zip_code': '21201',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['222 N Charles St', 'Baltimore, MD 21201']},
#    'phone': '+16672130043',
#    'display_phone': '(667) 213-0043',
#    'distance': 2012.1957279863468},
#   {'id': 'QLr9ZfuU6hNyM1adspWO1A',
#    'alias': 'hao-chi-baltimore-2',
#    'name': 'Hao chi',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hvnHKQJVR_9uRk5AMuvhAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hao-chi-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 27,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.2838207, 'longitude': -76.5929894},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '629 S Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Baltimore',
#     'zip_code': '21231',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['629 S Broadway', 'Baltimore, MD 21231']},
#    'phone': '+14103270011',
#    'display_phone': '(410) 327-0011',
#    'distance': 3150.494408960339},
#   {'id': 'm69hGqYXyn2RZM_Sl7-ciQ',
#    'alias': 'panda-bbq-baltimore',
#    'name': 'Panda BBQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/D8aOHygFUkQEOH7q6sRimw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/panda-bbq-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 53,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.303624, 'longitude': -76.617175},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '30 W Biddle St',
#     'address2': None,
#     'address3': '',
#     'city': 'Baltimore',
#     'zip_code': '21201',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['30 W Biddle St', 'Baltimore, MD 21201']},
#    'phone': '+13108943736',
#    'display_phone': '(310) 894-3736',
#    'distance': 941.4819710628137},
#   {'id': 'agf95R52ibcUTde8FjsZAg',
#    'alias': 'chopstix-gourmet-rosedale-2',
#    'name': 'Chopstix Gourmet',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bW2Dwrb3aryo5fpa1kDRZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chopstix-gourmet-rosedale-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 271,
#    'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'dimsum', 'title': 'Dim Sum'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.311612418845,
#     'longitude': -76.5224506720849},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1201 67th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Rosedale',
#     'zip_code': '21237',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['1201 67th St', 'Rosedale, MD 21237']},
#    'phone': '+14108662903',
#    'display_phone': '(410) 866-2903',
#    'distance': 7454.0697796768945},
#   {'id': 'g_E1mONRDwe2kSQ6jKUTlw',
#    'alias': 'orient-express-baltimore',
#    'name': 'Orient Express',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GYkX8okTQwr5mifUSYrjyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/orient-express-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 140,
#    'categories': [{'alias': 'conveyorsushi', 'title': 'Conveyor Belt Sushi'},
#     {'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.3262711, 'longitude': -76.6155396},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '3111 St Paul St',
#     'address2': '',
#     'address3': '',
#     'city': 'Baltimore',
#     'zip_code': '21218',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['3111 St Paul St', 'Baltimore, MD 21218']},
#    'phone': '+14108890031',
#    'display_phone': '(410) 889-0031',
#    'distance': 1971.425376673585},
#   {'id': 'JBVolcom6kWoCKiAg7_wEA',
#    'alias': 'paul-chen-hong-kong-restaurant-baltimore',
#    'name': 'Paul Chen Hong Kong Restaurant',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JmY_8eAPB0bZhVD7RQiPJw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/paul-chen-hong-kong-restaurant-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 93,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 2.5,
#    'coordinates': {'latitude': 39.317108, 'longitude': -76.617276},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '2426 N Charles St',
#     'address2': '',
#     'address3': '',
#     'city': 'Baltimore',
#     'zip_code': '21218',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['2426 N Charles St', 'Baltimore, MD 21218']},
#    'phone': '+14102358745',
#    'display_phone': '(410) 235-8745',
#    'distance': 1122.4702995948614},
#   {'id': 'Ttoog2mHFp13k7E7N3URnw',
#    'alias': 'china-wok-baltimore-2',
#    'name': 'China Wok',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BJrvXIpsOJCGGARneCgqeA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/china-wok-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 37,
#    'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#     {'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 39.31236, 'longitude': -76.6181501},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '2010 Maryland Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Baltimore',
#     'zip_code': '21218',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['2010 Maryland Ave', 'Baltimore, MD 21218']},
#    'phone': '+14103320668',
#    'display_phone': '(410) 332-0668',
#    'distance': 900.7328818567693},
#   {'id': 'DlGHw3CU750gOLMoAEZ-gw',
#    'alias': 'asian-taste-baltimore-3',
#    'name': 'Asian Taste',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pu7mlSoRmEm73np0Zk8Tyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/asian-taste-baltimore-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 60,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.33889, 'longitude': -76.54968},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '5441 Belair Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'Baltimore',
#     'zip_code': '21206',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['5441 Belair Rd', 'Baltimore, MD 21206']},
#    'phone': '+14103251000',
#    'display_phone': '(410) 325-1000',
#    'distance': 6071.905886361407},
#   {'id': 'vwbkBDnfus6uTXm-cNP-cw',
#    'alias': 'david-chus-china-bistro-baltimore-2',
#    'name': "David Chu's China Bistro",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/D6x9M0FfX7AjZNIdZEmylQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/david-chus-china-bistro-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 51,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.36355, 'longitude': -76.71169},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '7105 Reisterstown Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Baltimore',
#     'zip_code': '21215',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['7105 Reisterstown Rd', 'Baltimore, MD 21215']},
#    'phone': '+14106025008',
#    'display_phone': '(410) 602-5008',
#    'distance': 10694.468048649553},
#   {'id': 'VviIFv3Wgg1rxDR43ZAmFg',
#    'alias': 'golden-wok-baltimore',
#    'name': 'Golden Wok',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3Oj57Wc7768ZrU5mojENLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/golden-wok-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 13,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.285725, 'longitude': -76.593079},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '435 S Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Baltimore',
#     'zip_code': '21231',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['435 S Broadway', 'Baltimore, MD 21231']},
#    'phone': '+14105226883',
#    'display_phone': '(410) 522-6883',
#    'distance': 2958.193034064875},
#   {'id': '231I9KI9iyL14G7RIwXx1w',
#    'alias': 'hot-pot-king-catonsville',
#    'name': 'Hot Pot King',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NFFsp7RMTGTKIXZ3BJ4YIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hot-pot-king-catonsville?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 6,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.287028, 'longitude': -76.76197},
#    'transactions': [],
#    'location': {'address1': '6510 Baltimore National Pike',
#     'address2': None,
#     'address3': 'The Hub Asian Food Hall',
#     'city': 'Catonsville',
#     'zip_code': '21228',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['6510 Baltimore National Pike',
#      'The Hub Asian Food Hall',
#      'Catonsville, MD 21228']},
#    'phone': '+16678025177',
#    'display_phone': '(667) 802-5177',
#    'distance': 13392.136503595075},
#   {'id': 'FJnWA-O8yjGfs-sP6aDeUg',
#    'alias': 'yums-asian-bistro-baltimore',
#    'name': "Yum's Asian Bistro",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Zsi9CqQFBchBjUiCqGTytg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/yums-asian-bistro-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 110,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 39.3180160522461,
#     'longitude': -76.6167373657227},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2501 N Charles St',
#     'address2': '',
#     'address3': '',
#     'city': 'Baltimore',
#     'zip_code': '21218',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['2501 N Charles St', 'Baltimore, MD 21218']},
#    'phone': '+14108892828',
#    'display_phone': '(410) 889-2828',
#    'distance': 1179.471050660839},
#   {'id': 'EyzwOeUWwoKGeZcOcVUW0A',
#    'alias': 'ekiben-baltimore-3',
#    'name': 'Ekiben',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Wcriq5edNKNhvahXe7SbBQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ekiben-baltimore-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 1247,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.2857429, 'longitude': -76.594557},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1622 Eastern Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Baltimore',
#     'zip_code': '21231',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['1622 Eastern Ave', 'Baltimore, MD 21231']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2899.3769673605893},
#   {'id': '3Szif3O7-yN90I_SEkxWNw',
#    'alias': 'red-pepper-sichuan-bistro-towson',
#    'name': 'Red Pepper Sichuan Bistro',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0Lzq6kLxa0DAbO1hzFV8Vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/red-pepper-sichuan-bistro-towson?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 107,
#    'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.40145, 'longitude': -76.6032},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '11 Allegheny Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Towson',
#     'zip_code': '21204',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['11 Allegheny Ave', 'Towson, MD 21204']},
#    'phone': '+14108327333',
#    'display_phone': '(410) 832-7333',
#    'distance': 10260.957618018312},
#   {'id': '7jdUowVElWm5IFylVpj8yQ',
#    'alias': 'blessings-chinese-and-american-food-carry-out-baltimore',
#    'name': 'Blessings Chinese & American Food Carry Out',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pOmogUGTTd9tUhwU-Ey6kA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/blessings-chinese-and-american-food-carry-out-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 13,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 39.2972468809007,
#     'longitude': -76.5878194074355},
#    'transactions': ['delivery'],
#    'price': '$',
#    'location': {'address1': '537 N Chester St',
#     'address2': '',
#     'address3': '',
#     'city': 'Baltimore',
#     'zip_code': '21205',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['537 N Chester St', 'Baltimore, MD 21205']},
#    'phone': '+14103270258',
#    'display_phone': '(410) 327-0258',
#    'distance': 2264.0178527707176},
#   {'id': '5rYJkTY_V5y5IGepcDmW_w',
#    'alias': 'bambao-baltimore',
#    'name': 'Bambao',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/m7bhGjM4Gz_rfHjlXllyAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bambao-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#    'review_count': 79,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'chinese', 'title': 'Chinese'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 39.28348, 'longitude': -76.599289},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1010 Aliceanna St',
#     'address2': '',
#     'address3': None,
#     'city': 'Baltimore',
#     'zip_code': '21202',
#     'country': 'US',
#     'state': 'MD',
#     'display_address': ['1010 Aliceanna St', 'Baltimore, MD 21202']},
#    'phone': '+14434383528',
#    'display_phone': '(443) 438-3528',
#    'distance': 2989.663641579894}],
#  'total': 335,
#  'region': {'center': {'longitude': -76.60903930664062,
#    'latitude': 39.309286203696686}}}

# %%
response.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
response['total']
# Out:
# 335

# %%
len(response['businesses'])
# Out:
# 20

# %%
df = pd.DataFrame(response['businesses'])
df
# Out:
#                         id                                              alias  \
# 0   ry3Y5KSxtn7rVf3amw31rw                            china-house-baltimore-2
# 1   ZFFQuoUajWY_gYZ4HjfIKQ              water-song-yunnan-kitchen-baltimore-3
# 2   JZlGOTvnm2a8B7eGRlZZUg                                  nihao-baltimore-2
# 3   C6ktcKtaj62akb8X0CqAWg                          sunny-carry-out-baltimore
# 4   Mt8KF8_1T27QAY3ol1S2cg                          wow-food-cafe-baltimore-9
# 5   QLr9ZfuU6hNyM1adspWO1A                                hao-chi-baltimore-2
# 6   m69hGqYXyn2RZM_Sl7-ciQ                                panda-bbq-baltimore
# 7   agf95R52ibcUTde8FjsZAg                        chopstix-gourmet-rosedale-2
# 8   g_E1mONRDwe2kSQ6jKUTlw                           orient-express-baltimore
# 9   JBVolcom6kWoCKiAg7_wEA           paul-chen-hong-kong-restaurant-baltimore
# 10  Ttoog2mHFp13k7E7N3URnw                              china-wok-baltimore-2
# 11  DlGHw3CU750gOLMoAEZ-gw                            asian-taste-baltimore-3
# 12  vwbkBDnfus6uTXm-cNP-cw                david-chus-china-bistro-baltimore-2
# 13  VviIFv3Wgg1rxDR43ZAmFg                               golden-wok-baltimore
# 14  231I9KI9iyL14G7RIwXx1w                           hot-pot-king-catonsville
# 15  FJnWA-O8yjGfs-sP6aDeUg                        yums-asian-bistro-baltimore
# 16  EyzwOeUWwoKGeZcOcVUW0A                                 ekiben-baltimore-3
# 17  3Szif3O7-yN90I_SEkxWNw                   red-pepper-sichuan-bistro-towson
# 18  7jdUowVElWm5IFylVpj8yQ  blessings-chinese-and-american-food-carry-out-...
# 19  5rYJkTY_V5y5IGepcDmW_w                                   bambao-baltimore
#
#                                            name  \
# 0                                   China House
# 1                     Water Song Yunnan Kitchen
# 2                                         NiHao
# 3                               Sunny Carry Out
# 4                                 WOW Food Cafe
# 5                                       Hao chi
# 6                                     Panda BBQ
# 7                              Chopstix Gourmet
# 8                                Orient Express
# 9                Paul Chen Hong Kong Restaurant
# 10                                    China Wok
# 11                                  Asian Taste
# 12                     David Chu's China Bistro
# 13                                   Golden Wok
# 14                                 Hot Pot King
# 15                           Yum's Asian Bistro
# 16                                       Ekiben
# 17                    Red Pepper Sichuan Bistro
# 18  Blessings Chinese & American Food Carry Out
# 19                                       Bambao
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/EjebY0...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/lL_yo7...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/i5Vmne...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/uTMvf4...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/O8J8BF...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/hvnHKQ...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/D8aOHy...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/bW2Dwr...      False
# 8   https://s3-media4.fl.yelpcdn.com/bphoto/GYkX8o...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/JmY_8e...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/BJrvXI...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/pu7mlS...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/D6x9M0...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/3Oj57W...      False
# 14  https://s3-media3.fl.yelpcdn.com/bphoto/NFFsp7...      False
# 15  https://s3-media3.fl.yelpcdn.com/bphoto/Zsi9Cq...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/Wcriq5...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/0Lzq6k...      False
# 18  https://s3-media1.fl.yelpcdn.com/bphoto/pOmogU...      False
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/m7bhGj...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/china-house-baltimore...           184
# 1   https://www.yelp.com/biz/water-song-yunnan-kit...            68
# 2   https://www.yelp.com/biz/nihao-baltimore-2?adj...            79
# 3   https://www.yelp.com/biz/sunny-carry-out-balti...            76
# 4   https://www.yelp.com/biz/wow-food-cafe-baltimo...           177
# 5   https://www.yelp.com/biz/hao-chi-baltimore-2?a...            27
# 6   https://www.yelp.com/biz/panda-bbq-baltimore?a...            53
# 7   https://www.yelp.com/biz/chopstix-gourmet-rose...           271
# 8   https://www.yelp.com/biz/orient-express-baltim...           140
# 9   https://www.yelp.com/biz/paul-chen-hong-kong-r...            93
# 10  https://www.yelp.com/biz/china-wok-baltimore-2...            37
# 11  https://www.yelp.com/biz/asian-taste-baltimore...            60
# 12  https://www.yelp.com/biz/david-chus-china-bist...            51
# 13  https://www.yelp.com/biz/golden-wok-baltimore?...            13
# 14  https://www.yelp.com/biz/hot-pot-king-catonsvi...             6
# 15  https://www.yelp.com/biz/yums-asian-bistro-bal...           110
# 16  https://www.yelp.com/biz/ekiben-baltimore-3?ad...          1247
# 17  https://www.yelp.com/biz/red-pepper-sichuan-bi...           107
# 18  https://www.yelp.com/biz/blessings-chinese-and...            13
# 19  https://www.yelp.com/biz/bambao-baltimore?adju...            79
#
#                                            categories  rating  \
# 0          [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 1   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.5
# 2          [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
# 3          [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 4   [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 5   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.0
# 6   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     3.5
# 7   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 8   [{'alias': 'conveyorsushi', 'title': 'Conveyor...     3.0
# 9          [{'alias': 'chinese', 'title': 'Chinese'}]     2.5
# 10  [{'alias': 'cantonese', 'title': 'Cantonese'},...     3.0
# 11         [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 12         [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 13         [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
# 14  [{'alias': 'hotpot', 'title': 'Hot Pot'}, {'al...     4.5
# 15  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     3.5
# 16  [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.5
# 17       [{'alias': 'szechuan', 'title': 'Szechuan'}]     4.5
# 18  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 19  [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.0
#
#                                           coordinates        transactions  \
# 0   {'latitude': 39.2856979370117, 'longitude': -7...          [delivery]
# 1    {'latitude': 39.276528, 'longitude': -76.613502}  [delivery, pickup]
# 2    {'latitude': 39.282945, 'longitude': -76.583924}          [delivery]
# 3      {'latitude': 39.28325, 'longitude': -76.62783}            [pickup]
# 4    {'latitude': 39.292012, 'longitude': -76.616007}          [delivery]
# 5   {'latitude': 39.2838207, 'longitude': -76.5929...  [delivery, pickup]
# 6    {'latitude': 39.303624, 'longitude': -76.617175}  [delivery, pickup]
# 7   {'latitude': 39.311612418845, 'longitude': -76...  [delivery, pickup]
# 8   {'latitude': 39.3262711, 'longitude': -76.6155...  [delivery, pickup]
# 9    {'latitude': 39.317108, 'longitude': -76.617276}  [delivery, pickup]
# 10   {'latitude': 39.31236, 'longitude': -76.6181501}  [delivery, pickup]
# 11     {'latitude': 39.33889, 'longitude': -76.54968}  [delivery, pickup]
# 12     {'latitude': 39.36355, 'longitude': -76.71169}                  []
# 13   {'latitude': 39.285725, 'longitude': -76.593079}                  []
# 14    {'latitude': 39.287028, 'longitude': -76.76197}                  []
# 15  {'latitude': 39.3180160522461, 'longitude': -7...  [delivery, pickup]
# 16  {'latitude': 39.2857429, 'longitude': -76.594557}          [delivery]
# 17      {'latitude': 39.40145, 'longitude': -76.6032}  [delivery, pickup]
# 18  {'latitude': 39.2972468809007, 'longitude': -7...          [delivery]
# 19    {'latitude': 39.28348, 'longitude': -76.599289}  [delivery, pickup]
#
#    price                                           location         phone  \
# 0      $  {'address1': '2233 Eastern Ave', 'address2': '...  +14105223456
# 1    NaN  {'address1': '21 E Cross St', 'address2': '', ...  +14438694580
# 2    NaN  {'address1': '2322 Boston St', 'address2': '',...  +14438352036
# 3      $  {'address1': '758 Washington Blvd', 'address2'...  +14102448816
# 4     $$  {'address1': '222 N Charles St', 'address2': '...  +16672130043
# 5    NaN  {'address1': '629 S Broadway', 'address2': '',...  +14103270011
# 6    NaN  {'address1': '30 W Biddle St', 'address2': Non...  +13108943736
# 7     $$  {'address1': '1201 67th St', 'address2': '', '...  +14108662903
# 8      $  {'address1': '3111 St Paul St', 'address2': ''...  +14108890031
# 9      $  {'address1': '2426 N Charles St', 'address2': ...  +14102358745
# 10     $  {'address1': '2010 Maryland Ave', 'address2': ...  +14103320668
# 11     $  {'address1': '5441 Belair Rd', 'address2': Non...  +14103251000
# 12    $$  {'address1': '7105 Reisterstown Rd', 'address2...  +14106025008
# 13     $  {'address1': '435 S Broadway', 'address2': '',...  +14105226883
# 14   NaN  {'address1': '6510 Baltimore National Pike', '...  +16678025177
# 15    $$  {'address1': '2501 N Charles St', 'address2': ...  +14108892828
# 16    $$  {'address1': '1622 Eastern Ave', 'address2': '...
# 17    $$  {'address1': '11 Allegheny Ave', 'address2': N...  +14108327333
# 18     $  {'address1': '537 N Chester St', 'address2': '...  +14103270258
# 19    $$  {'address1': '1010 Aliceanna St', 'address2': ...  +14434383528
#
#      display_phone      distance
# 0   (410) 522-3456   3344.553801
# 1   (443) 869-4580   3664.817209
# 2   (443) 835-2036   3640.045127
# 3   (410) 244-8816   3317.393328
# 4   (667) 213-0043   2012.195728
# 5   (410) 327-0011   3150.494409
# 6   (310) 894-3736    941.481971
# 7   (410) 866-2903   7454.069780
# 8   (410) 889-0031   1971.425377
# 9   (410) 235-8745   1122.470300
# 10  (410) 332-0668    900.732882
# 11  (410) 325-1000   6071.905886
# 12  (410) 602-5008  10694.468049
# 13  (410) 522-6883   2958.193034
# 14  (667) 802-5177  13392.136504
# 15  (410) 889-2828   1179.471051
# 16                   2899.376967
# 17  (410) 832-7333  10260.957618
# 18  (410) 327-0258   2264.017853
# 19  (443) 438-3528   2989.663642

# %%
count = 20

# %% [markdown]
# ## Pagination
#
# Now that you have an initial response, you can examine the contents of the JSON container. For example, you might start with ```response.json().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data. Your final goal will be to reformat the data concerning the businesses themselves into a pandas DataFrame from the json objects.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day and are also can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %%
response2 = search_yelp(term='Chinese')#,params={'offset':20})
pd.DataFrame(response2['businesses'])
# Out:
#                         id                                              alias  \
# 0   ry3Y5KSxtn7rVf3amw31rw                            china-house-baltimore-2
# 1   ZFFQuoUajWY_gYZ4HjfIKQ              water-song-yunnan-kitchen-baltimore-3
# 2   JZlGOTvnm2a8B7eGRlZZUg                                  nihao-baltimore-2
# 3   C6ktcKtaj62akb8X0CqAWg                          sunny-carry-out-baltimore
# 4   Mt8KF8_1T27QAY3ol1S2cg                          wow-food-cafe-baltimore-9
# 5   QLr9ZfuU6hNyM1adspWO1A                                hao-chi-baltimore-2
# 6   m69hGqYXyn2RZM_Sl7-ciQ                                panda-bbq-baltimore
# 7   agf95R52ibcUTde8FjsZAg                        chopstix-gourmet-rosedale-2
# 8   g_E1mONRDwe2kSQ6jKUTlw                           orient-express-baltimore
# 9   JBVolcom6kWoCKiAg7_wEA           paul-chen-hong-kong-restaurant-baltimore
# 10  Ttoog2mHFp13k7E7N3URnw                              china-wok-baltimore-2
# 11  DlGHw3CU750gOLMoAEZ-gw                            asian-taste-baltimore-3
# 12  vwbkBDnfus6uTXm-cNP-cw                david-chus-china-bistro-baltimore-2
# 13  VviIFv3Wgg1rxDR43ZAmFg                               golden-wok-baltimore
# 14  231I9KI9iyL14G7RIwXx1w                           hot-pot-king-catonsville
# 15  FJnWA-O8yjGfs-sP6aDeUg                        yums-asian-bistro-baltimore
# 16  EyzwOeUWwoKGeZcOcVUW0A                                 ekiben-baltimore-3
# 17  3Szif3O7-yN90I_SEkxWNw                   red-pepper-sichuan-bistro-towson
# 18  7jdUowVElWm5IFylVpj8yQ  blessings-chinese-and-american-food-carry-out-...
# 19  5rYJkTY_V5y5IGepcDmW_w                                   bambao-baltimore
#
#                                            name  \
# 0                                   China House
# 1                     Water Song Yunnan Kitchen
# 2                                         NiHao
# 3                               Sunny Carry Out
# 4                                 WOW Food Cafe
# 5                                       Hao chi
# 6                                     Panda BBQ
# 7                              Chopstix Gourmet
# 8                                Orient Express
# 9                Paul Chen Hong Kong Restaurant
# 10                                    China Wok
# 11                                  Asian Taste
# 12                     David Chu's China Bistro
# 13                                   Golden Wok
# 14                                 Hot Pot King
# 15                           Yum's Asian Bistro
# 16                                       Ekiben
# 17                    Red Pepper Sichuan Bistro
# 18  Blessings Chinese & American Food Carry Out
# 19                                       Bambao
#
#                                             image_url  is_closed  \
# 0   https://s3-media3.fl.yelpcdn.com/bphoto/EjebY0...      False
# 1   https://s3-media1.fl.yelpcdn.com/bphoto/lL_yo7...      False
# 2   https://s3-media1.fl.yelpcdn.com/bphoto/i5Vmne...      False
# 3   https://s3-media2.fl.yelpcdn.com/bphoto/uTMvf4...      False
# 4   https://s3-media2.fl.yelpcdn.com/bphoto/O8J8BF...      False
# 5   https://s3-media2.fl.yelpcdn.com/bphoto/hvnHKQ...      False
# 6   https://s3-media2.fl.yelpcdn.com/bphoto/D8aOHy...      False
# 7   https://s3-media2.fl.yelpcdn.com/bphoto/bW2Dwr...      False
# 8   https://s3-media4.fl.yelpcdn.com/bphoto/GYkX8o...      False
# 9   https://s3-media2.fl.yelpcdn.com/bphoto/JmY_8e...      False
# 10  https://s3-media1.fl.yelpcdn.com/bphoto/BJrvXI...      False
# 11  https://s3-media2.fl.yelpcdn.com/bphoto/pu7mlS...      False
# 12  https://s3-media1.fl.yelpcdn.com/bphoto/D6x9M0...      False
# 13  https://s3-media3.fl.yelpcdn.com/bphoto/3Oj57W...      False
# 14  https://s3-media3.fl.yelpcdn.com/bphoto/NFFsp7...      False
# 15  https://s3-media3.fl.yelpcdn.com/bphoto/Zsi9Cq...      False
# 16  https://s3-media3.fl.yelpcdn.com/bphoto/Wcriq5...      False
# 17  https://s3-media2.fl.yelpcdn.com/bphoto/0Lzq6k...      False
# 18  https://s3-media1.fl.yelpcdn.com/bphoto/pOmogU...      False
# 19  https://s3-media4.fl.yelpcdn.com/bphoto/m7bhGj...      False
#
#                                                   url  review_count  \
# 0   https://www.yelp.com/biz/china-house-baltimore...           184
# 1   https://www.yelp.com/biz/water-song-yunnan-kit...            68
# 2   https://www.yelp.com/biz/nihao-baltimore-2?adj...            79
# 3   https://www.yelp.com/biz/sunny-carry-out-balti...            76
# 4   https://www.yelp.com/biz/wow-food-cafe-baltimo...           177
# 5   https://www.yelp.com/biz/hao-chi-baltimore-2?a...            27
# 6   https://www.yelp.com/biz/panda-bbq-baltimore?a...            53
# 7   https://www.yelp.com/biz/chopstix-gourmet-rose...           271
# 8   https://www.yelp.com/biz/orient-express-baltim...           140
# 9   https://www.yelp.com/biz/paul-chen-hong-kong-r...            93
# 10  https://www.yelp.com/biz/china-wok-baltimore-2...            37
# 11  https://www.yelp.com/biz/asian-taste-baltimore...            60
# 12  https://www.yelp.com/biz/david-chus-china-bist...            51
# 13  https://www.yelp.com/biz/golden-wok-baltimore?...            13
# 14  https://www.yelp.com/biz/hot-pot-king-catonsvi...             6
# 15  https://www.yelp.com/biz/yums-asian-bistro-bal...           110
# 16  https://www.yelp.com/biz/ekiben-baltimore-3?ad...          1247
# 17  https://www.yelp.com/biz/red-pepper-sichuan-bi...           107
# 18  https://www.yelp.com/biz/blessings-chinese-and...            13
# 19  https://www.yelp.com/biz/bambao-baltimore?adju...            79
#
#                                            categories  rating  \
# 0          [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 1   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.5
# 2          [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
# 3          [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 4   [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# 5   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.0
# 6   [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     3.5
# 7   [{'alias': 'sushi', 'title': 'Sushi Bars'}, {'...     4.0
# 8   [{'alias': 'conveyorsushi', 'title': 'Conveyor...     3.0
# 9          [{'alias': 'chinese', 'title': 'Chinese'}]     2.5
# 10  [{'alias': 'cantonese', 'title': 'Cantonese'},...     3.0
# 11         [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 12         [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 13         [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
# 14  [{'alias': 'hotpot', 'title': 'Hot Pot'}, {'al...     4.5
# 15  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     3.5
# 16  [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.5
# 17       [{'alias': 'szechuan', 'title': 'Szechuan'}]     4.5
# 18  [{'alias': 'newamerican', 'title': 'American (...     4.5
# 19  [{'alias': 'asianfusion', 'title': 'Asian Fusi...     4.0
#
#                                           coordinates        transactions  \
# 0   {'latitude': 39.2856979370117, 'longitude': -7...          [delivery]
# 1    {'latitude': 39.276528, 'longitude': -76.613502}  [delivery, pickup]
# 2    {'latitude': 39.282945, 'longitude': -76.583924}          [delivery]
# 3      {'latitude': 39.28325, 'longitude': -76.62783}            [pickup]
# 4    {'latitude': 39.292012, 'longitude': -76.616007}          [delivery]
# 5   {'latitude': 39.2838207, 'longitude': -76.5929...  [delivery, pickup]
# 6    {'latitude': 39.303624, 'longitude': -76.617175}  [delivery, pickup]
# 7   {'latitude': 39.311612418845, 'longitude': -76...  [delivery, pickup]
# 8   {'latitude': 39.3262711, 'longitude': -76.6155...  [delivery, pickup]
# 9    {'latitude': 39.317108, 'longitude': -76.617276}  [delivery, pickup]
# 10   {'latitude': 39.31236, 'longitude': -76.6181501}  [delivery, pickup]
# 11     {'latitude': 39.33889, 'longitude': -76.54968}  [delivery, pickup]
# 12     {'latitude': 39.36355, 'longitude': -76.71169}                  []
# 13   {'latitude': 39.285725, 'longitude': -76.593079}                  []
# 14    {'latitude': 39.287028, 'longitude': -76.76197}                  []
# 15  {'latitude': 39.3180160522461, 'longitude': -7...  [delivery, pickup]
# 16  {'latitude': 39.2857429, 'longitude': -76.594557}          [delivery]
# 17      {'latitude': 39.40145, 'longitude': -76.6032}  [delivery, pickup]
# 18  {'latitude': 39.2972468809007, 'longitude': -7...          [delivery]
# 19    {'latitude': 39.28348, 'longitude': -76.599289}  [delivery, pickup]
#
#    price                                           location         phone  \
# 0      $  {'address1': '2233 Eastern Ave', 'address2': '...  +14105223456
# 1    NaN  {'address1': '21 E Cross St', 'address2': '', ...  +14438694580
# 2    NaN  {'address1': '2322 Boston St', 'address2': '',...  +14438352036
# 3      $  {'address1': '758 Washington Blvd', 'address2'...  +14102448816
# 4     $$  {'address1': '222 N Charles St', 'address2': '...  +16672130043
# 5    NaN  {'address1': '629 S Broadway', 'address2': '',...  +14103270011
# 6    NaN  {'address1': '30 W Biddle St', 'address2': Non...  +13108943736
# 7     $$  {'address1': '1201 67th St', 'address2': '', '...  +14108662903
# 8      $  {'address1': '3111 St Paul St', 'address2': ''...  +14108890031
# 9      $  {'address1': '2426 N Charles St', 'address2': ...  +14102358745
# 10     $  {'address1': '2010 Maryland Ave', 'address2': ...  +14103320668
# 11     $  {'address1': '5441 Belair Rd', 'address2': Non...  +14103251000
# 12    $$  {'address1': '7105 Reisterstown Rd', 'address2...  +14106025008
# 13     $  {'address1': '435 S Broadway', 'address2': '',...  +14105226883
# 14   NaN  {'address1': '6510 Baltimore National Pike', '...  +16678025177
# 15    $$  {'address1': '2501 N Charles St', 'address2': ...  +14108892828
# 16    $$  {'address1': '1622 Eastern Ave', 'address2': '...
# 17    $$  {'address1': '11 Allegheny Ave', 'address2': N...  +14108327333
# 18     $  {'address1': '537 N Chester St', 'address2': '...  +14103270258
# 19    $$  {'address1': '1010 Aliceanna St', 'address2': ...  +14434383528
#
#      display_phone      distance
# 0   (410) 522-3456   3344.553801
# 1   (443) 869-4580   3664.817209
# 2   (443) 835-2036   3640.045127
# 3   (410) 244-8816   3317.393328
# 4   (667) 213-0043   2012.195728
# 5   (410) 327-0011   3150.494409
# 6   (310) 894-3736    941.481971
# 7   (410) 866-2903   7454.069780
# 8   (410) 889-0031   1971.425377
# 9   (410) 235-8745   1122.470300
# 10  (410) 332-0668    900.732882
# 11  (410) 325-1000   6071.905886
# 12  (410) 602-5008  10694.468049
# 13  (410) 522-6883   2958.193034
# 14  (667) 802-5177  13392.136504
# 15  (410) 889-2828   1179.471051
# 16                   2899.376967
# 17  (410) 832-7333  10260.957618
# 18  (410) 327-0258   2264.017853
# 19  (443) 438-3528   2989.663642

# %%
# Your code here; use a function or loop to retrieve all the results from your original request

## Get the first query result
response = search_yelp('Chinese',location = 'Baltimore, MD',params={})

## Check the ['total'] results and the length for the # of results returned
total = response['total']
n_results = len(response['businesses'])
## create a list of dfs 
results = []
results.extend(response['businesses'])
n_results, total

## Create an offset parameter using the 
offset = n_results

## start a for/while loop to get all results
while offset < total:
    response_loop = search_yelp('Chinese',location='Baltimore, MD',
                                params={'offset':offset})
    results.extend(response_loop['businesses'])
    n_results = len(response_loop['businesses'])
    offset += n_results

# %%
results
# Out:
# [{'id': 'ry3Y5KSxtn7rVf3amw31rw',
#   'alias': 'china-house-baltimore-2',
#   'name': 'China House',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EjebY0vjN0gFxoCCWJJMGQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-house-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 184,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.2856979370117,
#    'longitude': -76.5847778320312},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '2233 Eastern Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21231',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['2233 Eastern Ave', 'Baltimore, MD 21231']},
#   'phone': '+14105223456',
#   'display_phone': '(410) 522-3456',
#   'distance': 3344.55380067889},
#  {'id': 'ZFFQuoUajWY_gYZ4HjfIKQ',
#   'alias': 'water-song-yunnan-kitchen-baltimore-3',
#   'name': 'Water Song Yunnan Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lL_yo7tRHQSVJpDmZUvJ0Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/water-song-yunnan-kitchen-baltimore-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 68,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.276528, 'longitude': -76.613502},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '21 E Cross St',
#    'address2': '',
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21230',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['21 E Cross St', 'Baltimore, MD 21230']},
#   'phone': '+14438694580',
#   'display_phone': '(443) 869-4580',
#   'distance': 3664.8172088990104},
#  {'id': 'JZlGOTvnm2a8B7eGRlZZUg',
#   'alias': 'nihao-baltimore-2',
#   'name': 'NiHao',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/i5VmneOAKW1rleqryGE9QQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nihao-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 79,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.282945, 'longitude': -76.583924},
#   'transactions': ['delivery'],
#   'location': {'address1': '2322 Boston St',
#    'address2': '',
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21224',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['2322 Boston St', 'Baltimore, MD 21224']},
#   'phone': '+14438352036',
#   'display_phone': '(443) 835-2036',
#   'distance': 3640.0451267803455},
#  {'id': 'C6ktcKtaj62akb8X0CqAWg',
#   'alias': 'sunny-carry-out-baltimore',
#   'name': 'Sunny Carry Out',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uTMvf4qbZOqVA5KmkHlb3A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sunny-carry-out-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 76,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.28325, 'longitude': -76.62783},
#   'transactions': ['pickup'],
#   'price': '$',
#   'location': {'address1': '758 Washington Blvd',
#    'address2': None,
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21230',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['758 Washington Blvd', 'Baltimore, MD 21230']},
#   'phone': '+14102448816',
#   'display_phone': '(410) 244-8816',
#   'distance': 3317.393328446631},
#  {'id': 'Mt8KF8_1T27QAY3ol1S2cg',
#   'alias': 'wow-food-cafe-baltimore-9',
#   'name': 'WOW Food Cafe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O8J8BF4mR8a95j4y77K71A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wow-food-cafe-baltimore-9?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 177,
#   'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.292012, 'longitude': -76.616007},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '222 N Charles St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21201',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['222 N Charles St', 'Baltimore, MD 21201']},
#   'phone': '+16672130043',
#   'display_phone': '(667) 213-0043',
#   'distance': 2012.1957279863468},
#  {'id': 'QLr9ZfuU6hNyM1adspWO1A',
#   'alias': 'hao-chi-baltimore-2',
#   'name': 'Hao chi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hvnHKQJVR_9uRk5AMuvhAw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hao-chi-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 27,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.2838207, 'longitude': -76.5929894},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '629 S Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21231',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['629 S Broadway', 'Baltimore, MD 21231']},
#   'phone': '+14103270011',
#   'display_phone': '(410) 327-0011',
#   'distance': 3150.494408960339},
#  {'id': 'm69hGqYXyn2RZM_Sl7-ciQ',
#   'alias': 'panda-bbq-baltimore',
#   'name': 'Panda BBQ',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/D8aOHygFUkQEOH7q6sRimw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/panda-bbq-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 53,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.303624, 'longitude': -76.617175},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '30 W Biddle St',
#    'address2': None,
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21201',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['30 W Biddle St', 'Baltimore, MD 21201']},
#   'phone': '+13108943736',
#   'display_phone': '(310) 894-3736',
#   'distance': 941.4819710628137},
#  {'id': 'agf95R52ibcUTde8FjsZAg',
#   'alias': 'chopstix-gourmet-rosedale-2',
#   'name': 'Chopstix Gourmet',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bW2Dwrb3aryo5fpa1kDRZQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chopstix-gourmet-rosedale-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 271,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'dimsum', 'title': 'Dim Sum'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.311612418845, 'longitude': -76.5224506720849},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1201 67th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Rosedale',
#    'zip_code': '21237',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1201 67th St', 'Rosedale, MD 21237']},
#   'phone': '+14108662903',
#   'display_phone': '(410) 866-2903',
#   'distance': 7454.0697796768945},
#  {'id': 'g_E1mONRDwe2kSQ6jKUTlw',
#   'alias': 'orient-express-baltimore',
#   'name': 'Orient Express',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GYkX8okTQwr5mifUSYrjyg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/orient-express-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 140,
#   'categories': [{'alias': 'conveyorsushi', 'title': 'Conveyor Belt Sushi'},
#    {'alias': 'szechuan', 'title': 'Szechuan'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.3262711, 'longitude': -76.6155396},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '3111 St Paul St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21218',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['3111 St Paul St', 'Baltimore, MD 21218']},
#   'phone': '+14108890031',
#   'display_phone': '(410) 889-0031',
#   'distance': 1971.425376673585},
#  {'id': 'JBVolcom6kWoCKiAg7_wEA',
#   'alias': 'paul-chen-hong-kong-restaurant-baltimore',
#   'name': 'Paul Chen Hong Kong Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JmY_8eAPB0bZhVD7RQiPJw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paul-chen-hong-kong-restaurant-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 93,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 39.317108, 'longitude': -76.617276},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '2426 N Charles St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21218',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['2426 N Charles St', 'Baltimore, MD 21218']},
#   'phone': '+14102358745',
#   'display_phone': '(410) 235-8745',
#   'distance': 1122.4702995948614},
#  {'id': 'Ttoog2mHFp13k7E7N3URnw',
#   'alias': 'china-wok-baltimore-2',
#   'name': 'China Wok',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BJrvXIpsOJCGGARneCgqeA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-wok-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 37,
#   'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#    {'alias': 'szechuan', 'title': 'Szechuan'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.31236, 'longitude': -76.6181501},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '2010 Maryland Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21218',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['2010 Maryland Ave', 'Baltimore, MD 21218']},
#   'phone': '+14103320668',
#   'display_phone': '(410) 332-0668',
#   'distance': 900.7328818567693},
#  {'id': 'DlGHw3CU750gOLMoAEZ-gw',
#   'alias': 'asian-taste-baltimore-3',
#   'name': 'Asian Taste',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pu7mlSoRmEm73np0Zk8Tyw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/asian-taste-baltimore-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 60,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.33889, 'longitude': -76.54968},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '5441 Belair Rd',
#    'address2': None,
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21206',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['5441 Belair Rd', 'Baltimore, MD 21206']},
#   'phone': '+14103251000',
#   'display_phone': '(410) 325-1000',
#   'distance': 6071.905886361407},
#  {'id': 'vwbkBDnfus6uTXm-cNP-cw',
#   'alias': 'david-chus-china-bistro-baltimore-2',
#   'name': "David Chu's China Bistro",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/D6x9M0FfX7AjZNIdZEmylQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/david-chus-china-bistro-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 51,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.36355, 'longitude': -76.71169},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '7105 Reisterstown Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21215',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['7105 Reisterstown Rd', 'Baltimore, MD 21215']},
#   'phone': '+14106025008',
#   'display_phone': '(410) 602-5008',
#   'distance': 10694.468048649553},
#  {'id': 'VviIFv3Wgg1rxDR43ZAmFg',
#   'alias': 'golden-wok-baltimore',
#   'name': 'Golden Wok',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3Oj57Wc7768ZrU5mojENLQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/golden-wok-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 13,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.285725, 'longitude': -76.593079},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '435 S Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21231',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['435 S Broadway', 'Baltimore, MD 21231']},
#   'phone': '+14105226883',
#   'display_phone': '(410) 522-6883',
#   'distance': 2958.193034064875},
#  {'id': '231I9KI9iyL14G7RIwXx1w',
#   'alias': 'hot-pot-king-catonsville',
#   'name': 'Hot Pot King',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NFFsp7RMTGTKIXZ3BJ4YIg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hot-pot-king-catonsville?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 6,
#   'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#    {'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.287028, 'longitude': -76.76197},
#   'transactions': [],
#   'location': {'address1': '6510 Baltimore National Pike',
#    'address2': None,
#    'address3': 'The Hub Asian Food Hall',
#    'city': 'Catonsville',
#    'zip_code': '21228',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['6510 Baltimore National Pike',
#     'The Hub Asian Food Hall',
#     'Catonsville, MD 21228']},
#   'phone': '+16678025177',
#   'display_phone': '(667) 802-5177',
#   'distance': 13392.136503595075},
#  {'id': 'FJnWA-O8yjGfs-sP6aDeUg',
#   'alias': 'yums-asian-bistro-baltimore',
#   'name': "Yum's Asian Bistro",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Zsi9CqQFBchBjUiCqGTytg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/yums-asian-bistro-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 110,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.3180160522461,
#    'longitude': -76.6167373657227},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2501 N Charles St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21218',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['2501 N Charles St', 'Baltimore, MD 21218']},
#   'phone': '+14108892828',
#   'display_phone': '(410) 889-2828',
#   'distance': 1179.471050660839},
#  {'id': 'EyzwOeUWwoKGeZcOcVUW0A',
#   'alias': 'ekiben-baltimore-3',
#   'name': 'Ekiben',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Wcriq5edNKNhvahXe7SbBQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ekiben-baltimore-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 1247,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.2857429, 'longitude': -76.594557},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1622 Eastern Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21231',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1622 Eastern Ave', 'Baltimore, MD 21231']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2899.3769673605893},
#  {'id': '3Szif3O7-yN90I_SEkxWNw',
#   'alias': 'red-pepper-sichuan-bistro-towson',
#   'name': 'Red Pepper Sichuan Bistro',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0Lzq6kLxa0DAbO1hzFV8Vg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/red-pepper-sichuan-bistro-towson?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 107,
#   'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.40145, 'longitude': -76.6032},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '11 Allegheny Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Towson',
#    'zip_code': '21204',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['11 Allegheny Ave', 'Towson, MD 21204']},
#   'phone': '+14108327333',
#   'display_phone': '(410) 832-7333',
#   'distance': 10260.957618018312},
#  {'id': '7jdUowVElWm5IFylVpj8yQ',
#   'alias': 'blessings-chinese-and-american-food-carry-out-baltimore',
#   'name': 'Blessings Chinese & American Food Carry Out',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pOmogUGTTd9tUhwU-Ey6kA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blessings-chinese-and-american-food-carry-out-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 13,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.2972468809007,
#    'longitude': -76.5878194074355},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '537 N Chester St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21205',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['537 N Chester St', 'Baltimore, MD 21205']},
#   'phone': '+14103270258',
#   'display_phone': '(410) 327-0258',
#   'distance': 2264.0178527707176},
#  {'id': '5rYJkTY_V5y5IGepcDmW_w',
#   'alias': 'bambao-baltimore',
#   'name': 'Bambao',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/m7bhGjM4Gz_rfHjlXllyAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bambao-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 79,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.28348, 'longitude': -76.599289},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1010 Aliceanna St',
#    'address2': '',
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21202',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1010 Aliceanna St', 'Baltimore, MD 21202']},
#   'phone': '+14434383528',
#   'display_phone': '(443) 438-3528',
#   'distance': 2989.663641579894},
#  {'id': 'W2ZYDx9kHdgDCRyMf2cj5g',
#   'alias': 'yungs-carry-out-baltimore',
#   'name': "Yung's Carry Out",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RbdaI2PBhnbqm8pxS36FnQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/yungs-carry-out-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 27,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.29932, 'longitude': -76.61198},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '818 Guilford Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21202',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['818 Guilford Ave', 'Baltimore, MD 21202']},
#   'phone': '+14105398200',
#   'display_phone': '(410) 539-8200',
#   'distance': 1167.4044050010205},
#  {'id': 'TFTpMx-oPw19w3UaEWiD-g',
#   'alias': 'be-more-thai-restaurant-baltimore',
#   'name': 'Be More Thai Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SPQo7ezzziQyWIb3PPM-TQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/be-more-thai-restaurant-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 5,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 39.2781233929, 'longitude': -76.6126726262},
#   'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#   'location': {'address1': '1006 Light St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21230',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1006 Light St', 'Baltimore, MD 21230']},
#   'phone': '+14434384805',
#   'display_phone': '(443) 438-4805',
#   'distance': 3479.220081703541},
#  {'id': 'lX7xaoJy7ikZWuACkflWOQ',
#   'alias': 'china-wok-baltimore-3',
#   'name': 'China Wok',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cFHHocXewqviY__nX9jIKg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-wok-baltimore-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 13,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.295040727015, 'longitude': -76.569921687262},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '200 N Highland Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21224',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['200 N Highland Ave', 'Baltimore, MD 21224']},
#   'phone': '+14107323818',
#   'display_phone': '(410) 732-3818',
#   'distance': 3719.9564099135805},
#  {'id': 'vOvqK5zBxR1xfXpQUGto3A',
#   'alias': 'asian-harbor-baltimore',
#   'name': 'Asian Harbor',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/k9mzuhCcLxSa1bt-yudbtg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/asian-harbor-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 140,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'thai', 'title': 'Thai'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.28916, 'longitude': -76.60202},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1007 E Lombard St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21202',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1007 E Lombard St', 'Baltimore, MD 21202']},
#   'phone': '+14103276688',
#   'display_phone': '(410) 327-6688',
#   'distance': 2316.6906999377816},
#  {'id': 'KqLOev35hJ9H9jx4Fgu-bg',
#   'alias': 'chow-mein-charlie-baltimore',
#   'name': 'Chow Mein Charlie',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/M38S3jjL9y1QyUWqXJ9Ldw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chow-mein-charlie-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 35,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.3446732, 'longitude': -76.6313477},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '508 W Cold Spring Ln',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21210',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['508 W Cold Spring Ln', 'Baltimore, MD 21210']},
#   'phone': '+14108898886',
#   'display_phone': '(410) 889-8886',
#   'distance': 4375.615879846506},
#  {'id': 'Daqo6Vkj-m42dMZghpM6fQ',
#   'alias': 'chang-le-baltimore',
#   'name': 'Chang Le',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zW9a6lAHx8vLzV4M6UcnkQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chang-le-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 2,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.3563004, 'longitude': -76.6097651},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '5415 York Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21212',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['5415 York Rd', 'Baltimore, MD 21212']},
#   'phone': '+14104640880',
#   'display_phone': '(410) 464-0880',
#   'distance': 5216.7156823619935},
#  {'id': 'oacWY_a20bX6c9unbvkqCg',
#   'alias': 'peking-house-baltimore',
#   'name': 'Peking House',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AONzmVo3svWKsiaV71O_Rg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/peking-house-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 58,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.2894596252579,
#    'longitude': -76.6144597911173},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '115 E Baltimore St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21202',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['115 E Baltimore St', 'Baltimore, MD 21202']},
#   'phone': '+14105398183',
#   'display_phone': '(410) 539-8183',
#   'distance': 2253.4117369395467},
#  {'id': 'VTfawN586c5Lk3-UOIgmDQ',
#   'alias': 'winli-asian-restaurant-parkville',
#   'name': 'Winli Asian Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OSj9-HGKA9oWPt4k3usarQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/winli-asian-restaurant-parkville?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 51,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.38913, 'longitude': -76.54284},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2519 Putty Hill Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Parkville',
#    'zip_code': '21234',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['2519 Putty Hill Ave', 'Parkville, MD 21234']},
#   'phone': '+14108821388',
#   'display_phone': '(410) 882-1388',
#   'distance': 10541.24056050453},
#  {'id': 'zTzDIDY5GBkVpsHQGPsxsg',
#   'alias': 'asian-taste-baltimore',
#   'name': 'Asian Taste',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mK7NDAulPodKlOQAFBUCnw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/asian-taste-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 112,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'thai', 'title': 'Thai'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.3312658, 'longitude': -76.6316088},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '916 W 36th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21211',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['916 W 36th St', 'Baltimore, MD 21211']},
#   'phone': '+14104670100',
#   'display_phone': '(410) 467-0100',
#   'distance': 3170.3566668006765},
#  {'id': 'kHHXwR_0Ewfl3zm18WllEw',
#   'alias': 'mi-and-yu-noodle-bar-baltimore',
#   'name': 'Mi & Yu Noodle Bar',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xGrN3cozlgycYPkCXgNrcA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mi-and-yu-noodle-bar-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 368,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.2775395144376, 'longitude': -76.614495953057},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1016 S Charles St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21230',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1016 S Charles St', 'Baltimore, MD 21230']},
#   'phone': '+14433889295',
#   'display_phone': '(443) 388-9295',
#   'distance': 3561.1613569216447},
#  {'id': 'TG3uNkNGCSnBtSs_HGdgyQ',
#   'alias': 'new-china-ii-baltimore',
#   'name': 'New China II',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wV8e36bwBUbzg6rE-hFqxA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/new-china-ii-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 45,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.3378162, 'longitude': -76.635479},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1030 W 41st St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21211',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1030 W 41st St', 'Baltimore, MD 21211']},
#   'phone': '+14108890600',
#   'display_phone': '(410) 889-0600',
#   'distance': 3869.241838396611},
#  {'id': 'Lwtoibioq-6HDhkxdhXNBw',
#   'alias': 'china-room-baltimore',
#   'name': 'China Room',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZaVUAtu00VwGUiKSTVfMRQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-room-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 39.288032, 'longitude': -76.611076},
#   'transactions': [],
#   'location': {'address1': '44 South St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21202',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['44 South St', 'Baltimore, MD 21202']},
#   'phone': '+14107276666',
#   'display_phone': '(410) 727-6666',
#   'distance': 2368.7705856057846},
#  {'id': 'MH7myc7xK6JMDaKnHupmEg',
#   'alias': 'china-wok-baltimore',
#   'name': 'China Wok',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5jEy92KY0_gA-CEBU44w-g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-wok-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 17,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.373288, 'longitude': -76.61067},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '6372 York Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21212',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['6372 York Rd', 'Baltimore, MD 21212']},
#   'phone': '+14103775933',
#   'display_phone': '(410) 377-5933',
#   'distance': 7118.048663647896},
#  {'id': '4Eln3ufzz3yDa3SHl5iETQ',
#   'alias': 'joy-garden-carry-out-baltimore',
#   'name': 'Joy Garden Carry Out',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YRAwsKak5GBMxltAW5izuQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joy-garden-carry-out-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 8,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.3161888, 'longitude': -76.596283},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2310 Harford Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21218',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['2310 Harford Rd', 'Baltimore, MD 21218']},
#   'phone': '+14108897608',
#   'display_phone': '(410) 889-7608',
#   'distance': 1339.202085409877},
#  {'id': 'IHOmoBVhY4QimpuPyVaYNw',
#   'alias': 'bodhi-federal-hill-baltimore-2',
#   'name': 'Bodhi Federal Hill',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1mD9vzQuk3_IQPZMj16Urg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bodhi-federal-hill-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 124,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.27299, 'longitude': -76.61207},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1444 Light St',
#    'address2': '',
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21230',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1444 Light St', 'Baltimore, MD 21230']},
#   'phone': '+14437087527',
#   'display_phone': '(443) 708-7527',
#   'distance': 4039.868511499254},
#  {'id': 'JCb1AneRdjCMYdiEj68ZKA',
#   'alias': 'jia-home-cooking-baltimore-2',
#   'name': 'Jia Home Cooking',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XudwuDBnrGkV3rEKcsQ3eQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jia-home-cooking-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 3,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.327324, 'longitude': -76.600356},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '1101 E 33rd St',
#    'address2': '',
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21218',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1101 E 33rd St', 'Baltimore, MD 21218']},
#   'phone': '+14439973612',
#   'display_phone': '(443) 997-3612',
#   'distance': 2136.058259307638},
#  {'id': 'qBkUx6sD3AcwMh7wOu2sag',
#   'alias': 'peking-court-baltimore-3',
#   'name': 'Peking Court',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CN2cY-a_tGzmh6Nr-g1P8A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/peking-court-baltimore-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 16,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.347091722668125,
#    'longitude': -76.68885373644456},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '5421 Reisterstown Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21215',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['5421 Reisterstown Rd', 'Baltimore, MD 21215']},
#   'phone': '+14107648055',
#   'display_phone': '(410) 764-8055',
#   'distance': 8049.864927337656},
#  {'id': '54ncVboHsebXvd2WXBOzXA',
#   'alias': 'oriental-wok-baltimore',
#   'name': 'Oriental Wok',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YZxkXugJkRXfhP4wvn6Lzw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/oriental-wok-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 55,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.2867088317871,
#    'longitude': -76.5693435668945},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '3316 Eastern Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21224',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['3316 Eastern Ave', 'Baltimore, MD 21224']},
#   'phone': '+14102763316',
#   'display_phone': '(410) 276-3316',
#   'distance': 4244.620684207598},
#  {'id': '9FDafP9qsin3hKBn-oC6Gw',
#   'alias': 'new-world-carry-out-baltimore',
#   'name': 'New World Carry Out',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xnwbLuEbY6N36hQjD_nYvQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/new-world-carry-out-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 2,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.3112050551715,
#    'longitude': -76.6112018376589},
#   'transactions': [],
#   'location': {'address1': '333 E North Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21202',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['333 E North Ave', 'Baltimore, MD 21202']},
#   'phone': '+14107526855',
#   'display_phone': '(410) 752-6855',
#   'distance': 283.09108678234406},
#  {'id': '6i0YJ-c8RX25NUIelG9OiQ',
#   'alias': 'pinch-dumplings-baltimore',
#   'name': 'Pinch Dumplings',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iGbY7kWXFybLfGE8jzGFAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pinch-dumplings-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 88,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'vegan', 'title': 'Vegan'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.2958526456593,
#    'longitude': -76.6184662457026},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '520 Park Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21201',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['520 Park Ave', 'Baltimore, MD 21201']},
#   'phone': '+16673093445',
#   'display_phone': '(667) 309-3445',
#   'distance': 1699.7637475671245},
#  {'id': 'fEBbuNYy6FiFYY_KP6z-jQ',
#   'alias': 'loon-yee-carry-out-baltimore-2',
#   'name': 'Loon Yee Carry Out',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2ImNkEjzHtUmCj7hXKcBTw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/loon-yee-carry-out-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 4,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.2934977263212,
#    'longitude': -76.6930574923754},
#   'transactions': ['delivery'],
#   'location': {'address1': '4566 Edmondson Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21229',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['4566 Edmondson Ave', 'Baltimore, MD 21229']},
#   'phone': '+14109470600',
#   'display_phone': '(410) 947-0600',
#   'distance': 7449.324456717534},
#  {'id': '1i7J-ChCAtY-71H9fDDKgg',
#   'alias': 'ja-kum-sung-glen-burnie',
#   'name': 'Ja Kum Sung',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PsWvje8076KUs148mqlY7Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ja-kum-sung-glen-burnie?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 232,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.1605684234704,
#    'longitude': -76.6204474121332},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '7523 Ritchie Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Glen Burnie',
#    'zip_code': '21061',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['7523 Ritchie Hwy', 'Glen Burnie, MD 21061']},
#   'phone': '+14107665208',
#   'display_phone': '(410) 766-5208',
#   'distance': 16565.80812914766},
#  {'id': 'bSoqhbacgin62xRmwV5Ygg',
#   'alias': 'china-express-baltimore',
#   'name': 'China Express',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AK2GhR12cdd4v5zEAcQGqw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-express-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 32,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.3281556, 'longitude': -76.6100356},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '419 E 33rd St',
#    'address2': None,
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21218',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['419 E 33rd St', 'Baltimore, MD 21218']},
#   'phone': '+14102351100',
#   'display_phone': '(410) 235-1100',
#   'distance': 2102.7023303128194},
#  {'id': 'Ibh1sWpE2SReWUnvuxiK8A',
#   'alias': 'bodhi-corner-baltimore',
#   'name': 'Bodhi Corner',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZJe0Xi5BhQ8ZPhsB9nXHtg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bodhi-corner-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 119,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.33003, 'longitude': -76.6296},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3500 Chestnut Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21211',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['3500 Chestnut Ave', 'Baltimore, MD 21211']},
#   'phone': '+14434384068',
#   'display_phone': '(443) 438-4068',
#   'distance': 2905.7884543613154},
#  {'id': 'GzsJkLpwdkU9biaRD6Y5Cg',
#   'alias': 'china-moon-carry-out-towson',
#   'name': 'China Moon Carry Out',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-isWvG4ke2VVrCVM96ydCQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-moon-carry-out-towson?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 86,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.429332, 'longitude': -76.622377},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '9 W Ridgely Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Towson',
#    'zip_code': '21093',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['9 W Ridgely Rd', 'Towson, MD 21093']},
#   'phone': '+14102520960',
#   'display_phone': '(410) 252-0960',
#   'distance': 13397.617320275782},
#  {'id': 'vkN3OgAcz-A3-w2DcuimLg',
#   'alias': 'china-kitchen-baltimore',
#   'name': 'China Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BoBkiEHgVWzGWGqBaO0Gcw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-kitchen-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 25,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.266288, 'longitude': -76.699627},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '4642 Wilkens Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21229',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['4642 Wilkens Ave', 'Baltimore, MD 21229']},
#   'phone': '+14105360746',
#   'display_phone': '(410) 536-0746',
#   'distance': 9145.476865369334},
#  {'id': 'EfWcMYxg86BiJI_VJNUJgQ',
#   'alias': 'wing-wah-baltimore',
#   'name': 'Wing Wah',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vf0Hc4thLN5CWHwePJSDsQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wing-wah-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 4,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.32419, 'longitude': -76.58825},
#   'transactions': [],
#   'location': {'address1': '2837 Hillen Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21218',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['2837 Hillen Rd', 'Baltimore, MD 21218']},
#   'phone': '+14102352235',
#   'display_phone': '(410) 235-2235',
#   'distance': 2437.902573211982},
#  {'id': 'KpOC2uonHcoP8cMj2mDJOA',
#   'alias': 'number-1-chinese-kitchen-baltimore',
#   'name': 'Number 1 Chinese Kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p-NTDYQoMTcTphzQseKRjQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/number-1-chinese-kitchen-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 37,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 39.3371, 'longitude': -76.63345},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '3998 Roland Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21211',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['3998 Roland Ave', 'Baltimore, MD 21211']},
#   'phone': '+14102351688',
#   'display_phone': '(410) 235-1688',
#   'distance': 3729.0624783302833},
#  {'id': '0E9zZ-t3Xt1GqQzWFXfcDg',
#   'alias': 'new-china-restaurant-baltimore',
#   'name': 'New China Restaurant',
#   'image_url': '',
#   'is_closed': False,
# ...
#   'review_count': 7,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.2822276361819,
#    'longitude': -76.7541631617926},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '822 N Rolling Rd',
#    'address2': None,
#    'address3': None,
#    'city': 'Catonsville',
#    'zip_code': '21228',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['822 N Rolling Rd', 'Catonsville, MD 21228']},
#   'phone': '+14107190033',
#   'display_phone': '(410) 719-0033',
#   'distance': 12845.566276485271},
#  {'id': 'pnUvQAEnn1vTNaZHwVIyGw',
#   'alias': 'crystal-thai-restaurant-owings-mills',
#   'name': 'Crystal Thai Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KQeNe7hmpZ8Lhllpkro6eQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/crystal-thai-restaurant-owings-mills?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 108,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.39749, 'longitude': -76.748265},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '9191 Reisterstown Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Owings Mills',
#    'zip_code': '21117',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['9191 Reisterstown Rd', 'Owings Mills, MD 21117']},
#   'phone': '+14105810444',
#   'display_phone': '(410) 581-0444',
#   'distance': 15475.569706877523},
#  {'id': 'Ggs6p6qyVJVN9p3vYCx-xw',
#   'alias': 'pho-d-lite-parkville',
#   'name': "Pho D'Lite",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SI6h8hrpZr6DM31yiBmhxA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pho-d-lite-parkville?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 123,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'soup', 'title': 'Soup'},
#    {'alias': 'thai', 'title': 'Thai'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.40217, 'longitude': -76.542174},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '8926 Waltham Woods Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Parkville',
#    'zip_code': '21234',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['8926 Waltham Woods Rd', 'Parkville, MD 21234']},
#   'phone': '+14106577711',
#   'display_phone': '(410) 657-7711',
#   'distance': 11820.420046371672},
#  {'id': 'smRqDeLha2qwstlqKm1RTg',
#   'alias': 'san-sushi-too-towson-2',
#   'name': 'San Sushi Too',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6F95OrlES6ame6JWoFODoA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/san-sushi-too-towson-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 124,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.4007150809847,
#    'longitude': -76.6035568711644},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '10 W Pennsylvania Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Towson',
#    'zip_code': '21204',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['10 W Pennsylvania Ave', 'Towson, MD 21204']},
#   'phone': '+14108250907',
#   'display_phone': '(410) 825-0907',
#   'distance': 10177.33807680297},
#  {'id': 'zTWmVSpjbQdGye3R4awrkg',
#   'alias': 'howa-chinese-food-carry-out-dundalk',
#   'name': 'Howa Chinese Food Carry Out',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/howa-chinese-food-carry-out-dundalk?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 2,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 1.0,
#   'coordinates': {'latitude': 39.244149, 'longitude': -76.513212},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '107 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Dundalk',
#    'zip_code': '21222',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['107 Main St', 'Dundalk, MD 21222']},
#   'phone': '+14102822880',
#   'display_phone': '(410) 282-2880',
#   'distance': 10977.060670803749},
#  {'id': 'Yneik64IVKrusjr3fBtJ9g',
#   'alias': '8-at-luk-fu-hanover',
#   'name': '8 AT LUK FU',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y0_JTYPpLKPh5-6HXxBDxg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/8-at-luk-fu-hanover?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 22,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.1573726, 'longitude': -76.726976},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '7002 Arundel Mills Cir',
#    'address2': '',
#    'address3': None,
#    'city': 'Hanover',
#    'zip_code': '21076',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['7002 Arundel Mills Cir', 'Hanover, MD 21076']},
#   'phone': '+14438427000',
#   'display_phone': '(443) 842-7000',
#   'distance': 19710.901282090315},
#  {'id': 'MyJYoOb2LOk6IcCDFHVI_w',
#   'alias': 'qs-asian-cafe-catonsville',
#   'name': "Q's Asian Cafe",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zyL1r2PFIKSPcZbN9sJDIg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/qs-asian-cafe-catonsville?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 53,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 39.2868441317606,
#    'longitude': -76.7648959997538},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '6600 Baltimore National Pike',
#    'address2': '',
#    'address3': '',
#    'city': 'Catonsville',
#    'zip_code': '21228',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['6600 Baltimore National Pike',
#     'Catonsville, MD 21228']},
#   'phone': '+14107197033',
#   'display_phone': '(410) 719-7033',
#   'distance': 13641.558061323254},
#  {'id': 'gwjfRoWfbI5_1QkeeVOFxg',
#   'alias': 'east-china-cafe-gwynn-oak',
#   'name': 'East China Cafe',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/east-china-cafe-gwynn-oak?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 39.315879, 'longitude': -76.739471},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1724 Woodlawn Dr',
#    'address2': 'Ste 1',
#    'address3': None,
#    'city': 'Gwynn Oak',
#    'zip_code': '21207',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1724 Woodlawn Dr', 'Ste 1', 'Gwynn Oak, MD 21207']},
#   'phone': '+14105978825',
#   'display_phone': '(410) 597-8825',
#   'distance': 11144.643540667526},
#  {'id': 'hHIYrmLi35Z9S-LS65S_0w',
#   'alias': 'noodles-and-company-towson',
#   'name': 'Noodles & Company',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y4NcXONOGrBjjOAdxeqseg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/noodles-and-company-towson?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 66,
#   'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.3968347, 'longitude': -76.5845236},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '825 Goucher Blvd',
#    'address2': '100 B',
#    'address3': '',
#    'city': 'Towson',
#    'zip_code': '21286',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['825 Goucher Blvd', '100 B', 'Towson, MD 21286']},
#   'phone': '+14102960778',
#   'display_phone': '(410) 296-0778',
#   'distance': 9960.53555224952},
#  {'id': 'ceutLk2DAvfqVEbJpwTBOQ',
#   'alias': 'b-and-a-carry-out-peking-glen-burnie',
#   'name': 'B & A Carry Out Peking',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DnXxPvNfEdIUb6ABU0aZ5A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/b-and-a-carry-out-peking-glen-burnie?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'vegetarian', 'title': 'Vegetarian'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 1.0,
#   'coordinates': {'latitude': 39.1833202000337, 'longitude': -76.639473854982},
#   'transactions': [],
#   'location': {'address1': '7225 Baltimore Annapolis Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Glen Burnie',
#    'zip_code': '21061',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['7225 Baltimore Annapolis Blvd',
#     'Glen Burnie, MD 21061']},
#   'phone': '+14107666100',
#   'display_phone': '(410) 766-6100',
#   'distance': 14249.845619857779},
#  {'id': 'O5Jk5m2sm2o_zzOzDYDCTg',
#   'alias': 'ruby-thai-kitchen-towson',
#   'name': 'Ruby Thai Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HxgkNYJaSET5x5TR4ykMaQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ruby-thai-kitchen-towson?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 14,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 39.404075, 'longitude': -76.59921},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '825 Dulaney Valley Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Towson',
#    'zip_code': '21204',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['825 Dulaney Valley Rd', 'Towson, MD 21204']},
#   'phone': '+14104948800',
#   'display_phone': '(410) 494-8800',
#   'distance': 10573.847138426852},
#  {'id': 'UQ6BeOKeM-01v9-8-IQNhw',
#   'alias': 'panera-bread-pikesville',
#   'name': 'Panera Bread',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LnZlJSDp6xIKZ34d-PAAGg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/panera-bread-pikesville?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 37,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.3902676, 'longitude': -76.7412866},
#   'transactions': ['pickup'],
#   'price': '$',
#   'location': {'address1': '1852 Reisterstown Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Pikesville',
#    'zip_code': '21208',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1852 Reisterstown Rd', 'Pikesville, MD 21208']},
#   'phone': '+14106025125',
#   'display_phone': '(410) 602-5125',
#   'distance': 14504.93675231911},
#  {'id': 'AtwKjW3qylM0781037XMEQ',
#   'alias': 'noodles-and-company-columbia',
#   'name': 'Noodles & Company',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iMMLXx_hthHRPzXBnIZFbw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/noodles-and-company-columbia?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 135,
#   'categories': [{'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.1994255, 'longitude': -76.81267},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '6191 Old Dobbin Ln',
#    'address2': '',
#    'address3': '',
#    'city': 'Columbia',
#    'zip_code': '21045',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['6191 Old Dobbin Ln', 'Columbia, MD 21045']},
#   'phone': '+14108723729',
#   'display_phone': '(410) 872-3729',
#   'distance': 21369.206243316865},
#  {'id': 'K1Xgb1aTIqL7qD0MjewpAA',
#   'alias': 'kellys-cajun-grill-hanover',
#   'name': "Kelly's Cajun Grill",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HuOdldV7CnwRlnd0Ce9HHA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kellys-cajun-grill-hanover?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 26,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 39.1570476964906,
#    'longitude': -76.7256807160005},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '7000 Arundel Mills Cir',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '21076',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['7000 Arundel Mills Cir', 'Hanover, MD 21076']},
#   'phone': '+14105405110',
#   'display_phone': '(410) 540-5110',
#   'distance': 19684.713837345524},
#  {'id': 'viOIpHVViYTOtJw8C7UXng',
#   'alias': 'pho-viet-baltimore-3',
#   'name': 'Pho Viet',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/k5OjG8mHMnTpu1GWiM0I4Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pho-viet-baltimore-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 157,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.290687, 'longitude': -76.614278},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '104 Saint Paul St',
#    'address2': None,
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21202',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['104 Saint Paul St', 'Baltimore, MD 21202']},
#   'phone': '+14102441428',
#   'display_phone': '(410) 244-1428',
#   'distance': 2116.690510929977},
#  {'id': 'Fyl3yDKK6K_RSBqRfdKykw',
#   'alias': 'panda-express-towson-3',
#   'name': 'Panda Express',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oEfc3x_vaavTgdrSkYkt1Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/panda-express-towson-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 2,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 39.393877, 'longitude': -76.618202},
#   'transactions': [],
#   'location': {'address1': '8000 York Rd',
#    'address2': 'Towson University',
#    'address3': None,
#    'city': 'Towson',
#    'zip_code': '21252',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['8000 York Rd',
#     'Towson University',
#     'Towson, MD 21252']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 9438.993628984152}]

# %%
## Save the results to json file
import json
with open('results.json','w') as f:
    json.dump(results,f)

# %%
with open('results.json') as f:
    loaded_results = json.load(f)
loaded_results
# Out:
# [{'id': 'ry3Y5KSxtn7rVf3amw31rw',
#   'alias': 'china-house-baltimore-2',
#   'name': 'China House',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EjebY0vjN0gFxoCCWJJMGQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-house-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 184,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.2856979370117,
#    'longitude': -76.5847778320312},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '2233 Eastern Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21231',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['2233 Eastern Ave', 'Baltimore, MD 21231']},
#   'phone': '+14105223456',
#   'display_phone': '(410) 522-3456',
#   'distance': 3344.55380067889},
#  {'id': 'ZFFQuoUajWY_gYZ4HjfIKQ',
#   'alias': 'water-song-yunnan-kitchen-baltimore-3',
#   'name': 'Water Song Yunnan Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lL_yo7tRHQSVJpDmZUvJ0Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/water-song-yunnan-kitchen-baltimore-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 68,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'noodles', 'title': 'Noodles'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.276528, 'longitude': -76.613502},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '21 E Cross St',
#    'address2': '',
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21230',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['21 E Cross St', 'Baltimore, MD 21230']},
#   'phone': '+14438694580',
#   'display_phone': '(443) 869-4580',
#   'distance': 3664.8172088990104},
#  {'id': 'JZlGOTvnm2a8B7eGRlZZUg',
#   'alias': 'nihao-baltimore-2',
#   'name': 'NiHao',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/i5VmneOAKW1rleqryGE9QQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nihao-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 79,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.282945, 'longitude': -76.583924},
#   'transactions': ['delivery'],
#   'location': {'address1': '2322 Boston St',
#    'address2': '',
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21224',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['2322 Boston St', 'Baltimore, MD 21224']},
#   'phone': '+14438352036',
#   'display_phone': '(443) 835-2036',
#   'distance': 3640.0451267803455},
#  {'id': 'C6ktcKtaj62akb8X0CqAWg',
#   'alias': 'sunny-carry-out-baltimore',
#   'name': 'Sunny Carry Out',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uTMvf4qbZOqVA5KmkHlb3A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sunny-carry-out-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 76,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.28325, 'longitude': -76.62783},
#   'transactions': ['pickup'],
#   'price': '$',
#   'location': {'address1': '758 Washington Blvd',
#    'address2': None,
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21230',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['758 Washington Blvd', 'Baltimore, MD 21230']},
#   'phone': '+14102448816',
#   'display_phone': '(410) 244-8816',
#   'distance': 3317.393328446631},
#  {'id': 'Mt8KF8_1T27QAY3ol1S2cg',
#   'alias': 'wow-food-cafe-baltimore-9',
#   'name': 'WOW Food Cafe',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/O8J8BF4mR8a95j4y77K71A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wow-food-cafe-baltimore-9?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 177,
#   'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.292012, 'longitude': -76.616007},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '222 N Charles St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21201',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['222 N Charles St', 'Baltimore, MD 21201']},
#   'phone': '+16672130043',
#   'display_phone': '(667) 213-0043',
#   'distance': 2012.1957279863468},
#  {'id': 'QLr9ZfuU6hNyM1adspWO1A',
#   'alias': 'hao-chi-baltimore-2',
#   'name': 'Hao chi',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hvnHKQJVR_9uRk5AMuvhAw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hao-chi-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 27,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.2838207, 'longitude': -76.5929894},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '629 S Broadway',
#    'address2': '',
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21231',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['629 S Broadway', 'Baltimore, MD 21231']},
#   'phone': '+14103270011',
#   'display_phone': '(410) 327-0011',
#   'distance': 3150.494408960339},
#  {'id': 'm69hGqYXyn2RZM_Sl7-ciQ',
#   'alias': 'panda-bbq-baltimore',
#   'name': 'Panda BBQ',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/D8aOHygFUkQEOH7q6sRimw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/panda-bbq-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 53,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.303624, 'longitude': -76.617175},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '30 W Biddle St',
#    'address2': None,
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21201',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['30 W Biddle St', 'Baltimore, MD 21201']},
#   'phone': '+13108943736',
#   'display_phone': '(310) 894-3736',
#   'distance': 941.4819710628137},
#  {'id': 'agf95R52ibcUTde8FjsZAg',
#   'alias': 'chopstix-gourmet-rosedale-2',
#   'name': 'Chopstix Gourmet',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/bW2Dwrb3aryo5fpa1kDRZQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chopstix-gourmet-rosedale-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 271,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'dimsum', 'title': 'Dim Sum'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.311612418845, 'longitude': -76.5224506720849},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1201 67th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Rosedale',
#    'zip_code': '21237',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1201 67th St', 'Rosedale, MD 21237']},
#   'phone': '+14108662903',
#   'display_phone': '(410) 866-2903',
#   'distance': 7454.0697796768945},
#  {'id': 'g_E1mONRDwe2kSQ6jKUTlw',
#   'alias': 'orient-express-baltimore',
#   'name': 'Orient Express',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GYkX8okTQwr5mifUSYrjyg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/orient-express-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 140,
#   'categories': [{'alias': 'conveyorsushi', 'title': 'Conveyor Belt Sushi'},
#    {'alias': 'szechuan', 'title': 'Szechuan'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.3262711, 'longitude': -76.6155396},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '3111 St Paul St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21218',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['3111 St Paul St', 'Baltimore, MD 21218']},
#   'phone': '+14108890031',
#   'display_phone': '(410) 889-0031',
#   'distance': 1971.425376673585},
#  {'id': 'JBVolcom6kWoCKiAg7_wEA',
#   'alias': 'paul-chen-hong-kong-restaurant-baltimore',
#   'name': 'Paul Chen Hong Kong Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JmY_8eAPB0bZhVD7RQiPJw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/paul-chen-hong-kong-restaurant-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 93,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 39.317108, 'longitude': -76.617276},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '2426 N Charles St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21218',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['2426 N Charles St', 'Baltimore, MD 21218']},
#   'phone': '+14102358745',
#   'display_phone': '(410) 235-8745',
#   'distance': 1122.4702995948614},
#  {'id': 'Ttoog2mHFp13k7E7N3URnw',
#   'alias': 'china-wok-baltimore-2',
#   'name': 'China Wok',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BJrvXIpsOJCGGARneCgqeA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-wok-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 37,
#   'categories': [{'alias': 'cantonese', 'title': 'Cantonese'},
#    {'alias': 'szechuan', 'title': 'Szechuan'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.31236, 'longitude': -76.6181501},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '2010 Maryland Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21218',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['2010 Maryland Ave', 'Baltimore, MD 21218']},
#   'phone': '+14103320668',
#   'display_phone': '(410) 332-0668',
#   'distance': 900.7328818567693},
#  {'id': 'DlGHw3CU750gOLMoAEZ-gw',
#   'alias': 'asian-taste-baltimore-3',
#   'name': 'Asian Taste',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pu7mlSoRmEm73np0Zk8Tyw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/asian-taste-baltimore-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 60,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.33889, 'longitude': -76.54968},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '5441 Belair Rd',
#    'address2': None,
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21206',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['5441 Belair Rd', 'Baltimore, MD 21206']},
#   'phone': '+14103251000',
#   'display_phone': '(410) 325-1000',
#   'distance': 6071.905886361407},
#  {'id': 'vwbkBDnfus6uTXm-cNP-cw',
#   'alias': 'david-chus-china-bistro-baltimore-2',
#   'name': "David Chu's China Bistro",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/D6x9M0FfX7AjZNIdZEmylQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/david-chus-china-bistro-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 51,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.36355, 'longitude': -76.71169},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '7105 Reisterstown Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21215',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['7105 Reisterstown Rd', 'Baltimore, MD 21215']},
#   'phone': '+14106025008',
#   'display_phone': '(410) 602-5008',
#   'distance': 10694.468048649553},
#  {'id': 'VviIFv3Wgg1rxDR43ZAmFg',
#   'alias': 'golden-wok-baltimore',
#   'name': 'Golden Wok',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3Oj57Wc7768ZrU5mojENLQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/golden-wok-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 13,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.285725, 'longitude': -76.593079},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '435 S Broadway',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21231',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['435 S Broadway', 'Baltimore, MD 21231']},
#   'phone': '+14105226883',
#   'display_phone': '(410) 522-6883',
#   'distance': 2958.193034064875},
#  {'id': '231I9KI9iyL14G7RIwXx1w',
#   'alias': 'hot-pot-king-catonsville',
#   'name': 'Hot Pot King',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NFFsp7RMTGTKIXZ3BJ4YIg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/hot-pot-king-catonsville?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 6,
#   'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#    {'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.287028, 'longitude': -76.76197},
#   'transactions': [],
#   'location': {'address1': '6510 Baltimore National Pike',
#    'address2': None,
#    'address3': 'The Hub Asian Food Hall',
#    'city': 'Catonsville',
#    'zip_code': '21228',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['6510 Baltimore National Pike',
#     'The Hub Asian Food Hall',
#     'Catonsville, MD 21228']},
#   'phone': '+16678025177',
#   'display_phone': '(667) 802-5177',
#   'distance': 13392.136503595075},
#  {'id': 'FJnWA-O8yjGfs-sP6aDeUg',
#   'alias': 'yums-asian-bistro-baltimore',
#   'name': "Yum's Asian Bistro",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Zsi9CqQFBchBjUiCqGTytg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/yums-asian-bistro-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 110,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.3180160522461,
#    'longitude': -76.6167373657227},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2501 N Charles St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21218',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['2501 N Charles St', 'Baltimore, MD 21218']},
#   'phone': '+14108892828',
#   'display_phone': '(410) 889-2828',
#   'distance': 1179.471050660839},
#  {'id': 'EyzwOeUWwoKGeZcOcVUW0A',
#   'alias': 'ekiben-baltimore-3',
#   'name': 'Ekiben',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Wcriq5edNKNhvahXe7SbBQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ekiben-baltimore-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 1247,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.2857429, 'longitude': -76.594557},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1622 Eastern Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21231',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1622 Eastern Ave', 'Baltimore, MD 21231']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2899.3769673605893},
#  {'id': '3Szif3O7-yN90I_SEkxWNw',
#   'alias': 'red-pepper-sichuan-bistro-towson',
#   'name': 'Red Pepper Sichuan Bistro',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0Lzq6kLxa0DAbO1hzFV8Vg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/red-pepper-sichuan-bistro-towson?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 107,
#   'categories': [{'alias': 'szechuan', 'title': 'Szechuan'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.40145, 'longitude': -76.6032},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '11 Allegheny Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Towson',
#    'zip_code': '21204',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['11 Allegheny Ave', 'Towson, MD 21204']},
#   'phone': '+14108327333',
#   'display_phone': '(410) 832-7333',
#   'distance': 10260.957618018312},
#  {'id': '7jdUowVElWm5IFylVpj8yQ',
#   'alias': 'blessings-chinese-and-american-food-carry-out-baltimore',
#   'name': 'Blessings Chinese & American Food Carry Out',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pOmogUGTTd9tUhwU-Ey6kA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blessings-chinese-and-american-food-carry-out-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 13,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.2972468809007,
#    'longitude': -76.5878194074355},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '537 N Chester St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21205',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['537 N Chester St', 'Baltimore, MD 21205']},
#   'phone': '+14103270258',
#   'display_phone': '(410) 327-0258',
#   'distance': 2264.0178527707176},
#  {'id': '5rYJkTY_V5y5IGepcDmW_w',
#   'alias': 'bambao-baltimore',
#   'name': 'Bambao',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/m7bhGjM4Gz_rfHjlXllyAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bambao-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 79,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.28348, 'longitude': -76.599289},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1010 Aliceanna St',
#    'address2': '',
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21202',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1010 Aliceanna St', 'Baltimore, MD 21202']},
#   'phone': '+14434383528',
#   'display_phone': '(443) 438-3528',
#   'distance': 2989.663641579894},
#  {'id': 'W2ZYDx9kHdgDCRyMf2cj5g',
#   'alias': 'yungs-carry-out-baltimore',
#   'name': "Yung's Carry Out",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RbdaI2PBhnbqm8pxS36FnQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/yungs-carry-out-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 27,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.29932, 'longitude': -76.61198},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '818 Guilford Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21202',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['818 Guilford Ave', 'Baltimore, MD 21202']},
#   'phone': '+14105398200',
#   'display_phone': '(410) 539-8200',
#   'distance': 1167.4044050010205},
#  {'id': 'TFTpMx-oPw19w3UaEWiD-g',
#   'alias': 'be-more-thai-restaurant-baltimore',
#   'name': 'Be More Thai Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SPQo7ezzziQyWIb3PPM-TQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/be-more-thai-restaurant-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 5,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 39.2781233929, 'longitude': -76.6126726262},
#   'transactions': ['pickup', 'delivery', 'restaurant_reservation'],
#   'location': {'address1': '1006 Light St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21230',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1006 Light St', 'Baltimore, MD 21230']},
#   'phone': '+14434384805',
#   'display_phone': '(443) 438-4805',
#   'distance': 3479.220081703541},
#  {'id': 'lX7xaoJy7ikZWuACkflWOQ',
#   'alias': 'china-wok-baltimore-3',
#   'name': 'China Wok',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cFHHocXewqviY__nX9jIKg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-wok-baltimore-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 13,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.295040727015, 'longitude': -76.569921687262},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '200 N Highland Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21224',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['200 N Highland Ave', 'Baltimore, MD 21224']},
#   'phone': '+14107323818',
#   'display_phone': '(410) 732-3818',
#   'distance': 3719.9564099135805},
#  {'id': 'vOvqK5zBxR1xfXpQUGto3A',
#   'alias': 'asian-harbor-baltimore',
#   'name': 'Asian Harbor',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/k9mzuhCcLxSa1bt-yudbtg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/asian-harbor-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 140,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'thai', 'title': 'Thai'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.28916, 'longitude': -76.60202},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1007 E Lombard St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21202',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1007 E Lombard St', 'Baltimore, MD 21202']},
#   'phone': '+14103276688',
#   'display_phone': '(410) 327-6688',
#   'distance': 2316.6906999377816},
#  {'id': 'KqLOev35hJ9H9jx4Fgu-bg',
#   'alias': 'chow-mein-charlie-baltimore',
#   'name': 'Chow Mein Charlie',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/M38S3jjL9y1QyUWqXJ9Ldw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chow-mein-charlie-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 35,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.3446732, 'longitude': -76.6313477},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '508 W Cold Spring Ln',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21210',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['508 W Cold Spring Ln', 'Baltimore, MD 21210']},
#   'phone': '+14108898886',
#   'display_phone': '(410) 889-8886',
#   'distance': 4375.615879846506},
#  {'id': 'Daqo6Vkj-m42dMZghpM6fQ',
#   'alias': 'chang-le-baltimore',
#   'name': 'Chang Le',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zW9a6lAHx8vLzV4M6UcnkQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chang-le-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 2,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.3563004, 'longitude': -76.6097651},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '5415 York Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21212',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['5415 York Rd', 'Baltimore, MD 21212']},
#   'phone': '+14104640880',
#   'display_phone': '(410) 464-0880',
#   'distance': 5216.7156823619935},
#  {'id': 'oacWY_a20bX6c9unbvkqCg',
#   'alias': 'peking-house-baltimore',
#   'name': 'Peking House',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/AONzmVo3svWKsiaV71O_Rg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/peking-house-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 58,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.2894596252579,
#    'longitude': -76.6144597911173},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '115 E Baltimore St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21202',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['115 E Baltimore St', 'Baltimore, MD 21202']},
#   'phone': '+14105398183',
#   'display_phone': '(410) 539-8183',
#   'distance': 2253.4117369395467},
#  {'id': 'VTfawN586c5Lk3-UOIgmDQ',
#   'alias': 'winli-asian-restaurant-parkville',
#   'name': 'Winli Asian Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OSj9-HGKA9oWPt4k3usarQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/winli-asian-restaurant-parkville?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 51,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.38913, 'longitude': -76.54284},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '2519 Putty Hill Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Parkville',
#    'zip_code': '21234',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['2519 Putty Hill Ave', 'Parkville, MD 21234']},
#   'phone': '+14108821388',
#   'display_phone': '(410) 882-1388',
#   'distance': 10541.24056050453},
#  {'id': 'zTzDIDY5GBkVpsHQGPsxsg',
#   'alias': 'asian-taste-baltimore',
#   'name': 'Asian Taste',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mK7NDAulPodKlOQAFBUCnw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/asian-taste-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 112,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'thai', 'title': 'Thai'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.3312658, 'longitude': -76.6316088},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '916 W 36th St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21211',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['916 W 36th St', 'Baltimore, MD 21211']},
#   'phone': '+14104670100',
#   'display_phone': '(410) 467-0100',
#   'distance': 3170.3566668006765},
#  {'id': 'kHHXwR_0Ewfl3zm18WllEw',
#   'alias': 'mi-and-yu-noodle-bar-baltimore',
#   'name': 'Mi & Yu Noodle Bar',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xGrN3cozlgycYPkCXgNrcA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mi-and-yu-noodle-bar-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 368,
#   'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'beerbar', 'title': 'Beer Bar'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.2775395144376, 'longitude': -76.614495953057},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1016 S Charles St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21230',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1016 S Charles St', 'Baltimore, MD 21230']},
#   'phone': '+14433889295',
#   'display_phone': '(443) 388-9295',
#   'distance': 3561.1613569216447},
#  {'id': 'TG3uNkNGCSnBtSs_HGdgyQ',
#   'alias': 'new-china-ii-baltimore',
#   'name': 'New China II',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wV8e36bwBUbzg6rE-hFqxA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/new-china-ii-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 45,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.3378162, 'longitude': -76.635479},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1030 W 41st St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21211',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1030 W 41st St', 'Baltimore, MD 21211']},
#   'phone': '+14108890600',
#   'display_phone': '(410) 889-0600',
#   'distance': 3869.241838396611},
#  {'id': 'Lwtoibioq-6HDhkxdhXNBw',
#   'alias': 'china-room-baltimore',
#   'name': 'China Room',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZaVUAtu00VwGUiKSTVfMRQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-room-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 39.288032, 'longitude': -76.611076},
#   'transactions': [],
#   'location': {'address1': '44 South St',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21202',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['44 South St', 'Baltimore, MD 21202']},
#   'phone': '+14107276666',
#   'display_phone': '(410) 727-6666',
#   'distance': 2368.7705856057846},
#  {'id': 'MH7myc7xK6JMDaKnHupmEg',
#   'alias': 'china-wok-baltimore',
#   'name': 'China Wok',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5jEy92KY0_gA-CEBU44w-g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-wok-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 17,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.373288, 'longitude': -76.61067},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '6372 York Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21212',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['6372 York Rd', 'Baltimore, MD 21212']},
#   'phone': '+14103775933',
#   'display_phone': '(410) 377-5933',
#   'distance': 7118.048663647896},
#  {'id': '4Eln3ufzz3yDa3SHl5iETQ',
#   'alias': 'joy-garden-carry-out-baltimore',
#   'name': 'Joy Garden Carry Out',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YRAwsKak5GBMxltAW5izuQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/joy-garden-carry-out-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 8,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.3161888, 'longitude': -76.596283},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2310 Harford Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21218',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['2310 Harford Rd', 'Baltimore, MD 21218']},
#   'phone': '+14108897608',
#   'display_phone': '(410) 889-7608',
#   'distance': 1339.202085409877},
#  {'id': 'IHOmoBVhY4QimpuPyVaYNw',
#   'alias': 'bodhi-federal-hill-baltimore-2',
#   'name': 'Bodhi Federal Hill',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1mD9vzQuk3_IQPZMj16Urg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bodhi-federal-hill-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 124,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.27299, 'longitude': -76.61207},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1444 Light St',
#    'address2': '',
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21230',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1444 Light St', 'Baltimore, MD 21230']},
#   'phone': '+14437087527',
#   'display_phone': '(443) 708-7527',
#   'distance': 4039.868511499254},
#  {'id': 'JCb1AneRdjCMYdiEj68ZKA',
#   'alias': 'jia-home-cooking-baltimore-2',
#   'name': 'Jia Home Cooking',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XudwuDBnrGkV3rEKcsQ3eQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jia-home-cooking-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 3,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.327324, 'longitude': -76.600356},
#   'transactions': ['pickup', 'delivery'],
#   'location': {'address1': '1101 E 33rd St',
#    'address2': '',
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21218',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1101 E 33rd St', 'Baltimore, MD 21218']},
#   'phone': '+14439973612',
#   'display_phone': '(443) 997-3612',
#   'distance': 2136.058259307638},
#  {'id': 'qBkUx6sD3AcwMh7wOu2sag',
#   'alias': 'peking-court-baltimore-3',
#   'name': 'Peking Court',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CN2cY-a_tGzmh6Nr-g1P8A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/peking-court-baltimore-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 16,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.347091722668125,
#    'longitude': -76.68885373644456},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '5421 Reisterstown Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21215',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['5421 Reisterstown Rd', 'Baltimore, MD 21215']},
#   'phone': '+14107648055',
#   'display_phone': '(410) 764-8055',
#   'distance': 8049.864927337656},
#  {'id': '54ncVboHsebXvd2WXBOzXA',
#   'alias': 'oriental-wok-baltimore',
#   'name': 'Oriental Wok',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/YZxkXugJkRXfhP4wvn6Lzw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/oriental-wok-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 55,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.2867088317871,
#    'longitude': -76.5693435668945},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '3316 Eastern Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21224',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['3316 Eastern Ave', 'Baltimore, MD 21224']},
#   'phone': '+14102763316',
#   'display_phone': '(410) 276-3316',
#   'distance': 4244.620684207598},
#  {'id': '9FDafP9qsin3hKBn-oC6Gw',
#   'alias': 'new-world-carry-out-baltimore',
#   'name': 'New World Carry Out',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xnwbLuEbY6N36hQjD_nYvQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/new-world-carry-out-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 2,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.3112050551715,
#    'longitude': -76.6112018376589},
#   'transactions': [],
#   'location': {'address1': '333 E North Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21202',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['333 E North Ave', 'Baltimore, MD 21202']},
#   'phone': '+14107526855',
#   'display_phone': '(410) 752-6855',
#   'distance': 283.09108678234406},
#  {'id': '6i0YJ-c8RX25NUIelG9OiQ',
#   'alias': 'pinch-dumplings-baltimore',
#   'name': 'Pinch Dumplings',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iGbY7kWXFybLfGE8jzGFAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pinch-dumplings-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 88,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'vegan', 'title': 'Vegan'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.2958526456593,
#    'longitude': -76.6184662457026},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '520 Park Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21201',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['520 Park Ave', 'Baltimore, MD 21201']},
#   'phone': '+16673093445',
#   'display_phone': '(667) 309-3445',
#   'distance': 1699.7637475671245},
#  {'id': 'fEBbuNYy6FiFYY_KP6z-jQ',
#   'alias': 'loon-yee-carry-out-baltimore-2',
#   'name': 'Loon Yee Carry Out',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2ImNkEjzHtUmCj7hXKcBTw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/loon-yee-carry-out-baltimore-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 4,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.2934977263212,
#    'longitude': -76.6930574923754},
#   'transactions': ['delivery'],
#   'location': {'address1': '4566 Edmondson Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21229',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['4566 Edmondson Ave', 'Baltimore, MD 21229']},
#   'phone': '+14109470600',
#   'display_phone': '(410) 947-0600',
#   'distance': 7449.324456717534},
#  {'id': '1i7J-ChCAtY-71H9fDDKgg',
#   'alias': 'ja-kum-sung-glen-burnie',
#   'name': 'Ja Kum Sung',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PsWvje8076KUs148mqlY7Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ja-kum-sung-glen-burnie?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 232,
#   'categories': [{'alias': 'korean', 'title': 'Korean'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 39.1605684234704,
#    'longitude': -76.6204474121332},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '7523 Ritchie Hwy',
#    'address2': '',
#    'address3': '',
#    'city': 'Glen Burnie',
#    'zip_code': '21061',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['7523 Ritchie Hwy', 'Glen Burnie, MD 21061']},
#   'phone': '+14107665208',
#   'display_phone': '(410) 766-5208',
#   'distance': 16565.80812914766},
#  {'id': 'bSoqhbacgin62xRmwV5Ygg',
#   'alias': 'china-express-baltimore',
#   'name': 'China Express',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/AK2GhR12cdd4v5zEAcQGqw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-express-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 32,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.3281556, 'longitude': -76.6100356},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '419 E 33rd St',
#    'address2': None,
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21218',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['419 E 33rd St', 'Baltimore, MD 21218']},
#   'phone': '+14102351100',
#   'display_phone': '(410) 235-1100',
#   'distance': 2102.7023303128194},
#  {'id': 'Ibh1sWpE2SReWUnvuxiK8A',
#   'alias': 'bodhi-corner-baltimore',
#   'name': 'Bodhi Corner',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZJe0Xi5BhQ8ZPhsB9nXHtg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bodhi-corner-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 119,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.33003, 'longitude': -76.6296},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3500 Chestnut Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Baltimore',
#    'zip_code': '21211',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['3500 Chestnut Ave', 'Baltimore, MD 21211']},
#   'phone': '+14434384068',
#   'display_phone': '(443) 438-4068',
#   'distance': 2905.7884543613154},
#  {'id': 'GzsJkLpwdkU9biaRD6Y5Cg',
#   'alias': 'china-moon-carry-out-towson',
#   'name': 'China Moon Carry Out',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-isWvG4ke2VVrCVM96ydCQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-moon-carry-out-towson?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 86,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.429332, 'longitude': -76.622377},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '9 W Ridgely Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Towson',
#    'zip_code': '21093',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['9 W Ridgely Rd', 'Towson, MD 21093']},
#   'phone': '+14102520960',
#   'display_phone': '(410) 252-0960',
#   'distance': 13397.617320275782},
#  {'id': 'vkN3OgAcz-A3-w2DcuimLg',
#   'alias': 'china-kitchen-baltimore',
#   'name': 'China Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BoBkiEHgVWzGWGqBaO0Gcw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/china-kitchen-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 25,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.266288, 'longitude': -76.699627},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '4642 Wilkens Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21229',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['4642 Wilkens Ave', 'Baltimore, MD 21229']},
#   'phone': '+14105360746',
#   'display_phone': '(410) 536-0746',
#   'distance': 9145.476865369334},
#  {'id': 'EfWcMYxg86BiJI_VJNUJgQ',
#   'alias': 'wing-wah-baltimore',
#   'name': 'Wing Wah',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vf0Hc4thLN5CWHwePJSDsQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/wing-wah-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 4,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 39.32419, 'longitude': -76.58825},
#   'transactions': [],
#   'location': {'address1': '2837 Hillen Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21218',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['2837 Hillen Rd', 'Baltimore, MD 21218']},
#   'phone': '+14102352235',
#   'display_phone': '(410) 235-2235',
#   'distance': 2437.902573211982},
#  {'id': 'KpOC2uonHcoP8cMj2mDJOA',
#   'alias': 'number-1-chinese-kitchen-baltimore',
#   'name': 'Number 1 Chinese Kitchen',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p-NTDYQoMTcTphzQseKRjQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/number-1-chinese-kitchen-baltimore?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 37,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 39.3371, 'longitude': -76.63345},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '3998 Roland Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21211',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['3998 Roland Ave', 'Baltimore, MD 21211']},
#   'phone': '+14102351688',
#   'display_phone': '(410) 235-1688',
#   'distance': 3729.0624783302833},
#  {'id': '0E9zZ-t3Xt1GqQzWFXfcDg',
#   'alias': 'new-china-restaurant-baltimore',
#   'name': 'New China Restaurant',
#   'image_url': '',
#   'is_closed': False,
# ...
#   'review_count': 7,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'bbq', 'title': 'Barbeque'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.2822276361819,
#    'longitude': -76.7541631617926},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '822 N Rolling Rd',
#    'address2': None,
#    'address3': None,
#    'city': 'Catonsville',
#    'zip_code': '21228',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['822 N Rolling Rd', 'Catonsville, MD 21228']},
#   'phone': '+14107190033',
#   'display_phone': '(410) 719-0033',
#   'distance': 12845.566276485271},
#  {'id': 'pnUvQAEnn1vTNaZHwVIyGw',
#   'alias': 'crystal-thai-restaurant-owings-mills',
#   'name': 'Crystal Thai Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KQeNe7hmpZ8Lhllpkro6eQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/crystal-thai-restaurant-owings-mills?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 108,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.39749, 'longitude': -76.748265},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '9191 Reisterstown Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Owings Mills',
#    'zip_code': '21117',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['9191 Reisterstown Rd', 'Owings Mills, MD 21117']},
#   'phone': '+14105810444',
#   'display_phone': '(410) 581-0444',
#   'distance': 15475.569706877523},
#  {'id': 'Ggs6p6qyVJVN9p3vYCx-xw',
#   'alias': 'pho-d-lite-parkville',
#   'name': "Pho D'Lite",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/SI6h8hrpZr6DM31yiBmhxA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pho-d-lite-parkville?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 123,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'soup', 'title': 'Soup'},
#    {'alias': 'thai', 'title': 'Thai'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.40217, 'longitude': -76.542174},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '8926 Waltham Woods Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Parkville',
#    'zip_code': '21234',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['8926 Waltham Woods Rd', 'Parkville, MD 21234']},
#   'phone': '+14106577711',
#   'display_phone': '(410) 657-7711',
#   'distance': 11820.420046371672},
#  {'id': 'smRqDeLha2qwstlqKm1RTg',
#   'alias': 'san-sushi-too-towson-2',
#   'name': 'San Sushi Too',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6F95OrlES6ame6JWoFODoA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/san-sushi-too-towson-2?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 124,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.4007150809847,
#    'longitude': -76.6035568711644},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '10 W Pennsylvania Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Towson',
#    'zip_code': '21204',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['10 W Pennsylvania Ave', 'Towson, MD 21204']},
#   'phone': '+14108250907',
#   'display_phone': '(410) 825-0907',
#   'distance': 10177.33807680297},
#  {'id': 'zTWmVSpjbQdGye3R4awrkg',
#   'alias': 'howa-chinese-food-carry-out-dundalk',
#   'name': 'Howa Chinese Food Carry Out',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/howa-chinese-food-carry-out-dundalk?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 2,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 1.0,
#   'coordinates': {'latitude': 39.244149, 'longitude': -76.513212},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '107 Main St',
#    'address2': '',
#    'address3': '',
#    'city': 'Dundalk',
#    'zip_code': '21222',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['107 Main St', 'Dundalk, MD 21222']},
#   'phone': '+14102822880',
#   'display_phone': '(410) 282-2880',
#   'distance': 10977.060670803749},
#  {'id': 'Yneik64IVKrusjr3fBtJ9g',
#   'alias': '8-at-luk-fu-hanover',
#   'name': '8 AT LUK FU',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Y0_JTYPpLKPh5-6HXxBDxg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/8-at-luk-fu-hanover?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 22,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.1573726, 'longitude': -76.726976},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '7002 Arundel Mills Cir',
#    'address2': '',
#    'address3': None,
#    'city': 'Hanover',
#    'zip_code': '21076',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['7002 Arundel Mills Cir', 'Hanover, MD 21076']},
#   'phone': '+14438427000',
#   'display_phone': '(443) 842-7000',
#   'distance': 19710.901282090315},
#  {'id': 'MyJYoOb2LOk6IcCDFHVI_w',
#   'alias': 'qs-asian-cafe-catonsville',
#   'name': "Q's Asian Cafe",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/zyL1r2PFIKSPcZbN9sJDIg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/qs-asian-cafe-catonsville?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 53,
#   'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 39.2868441317606,
#    'longitude': -76.7648959997538},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '6600 Baltimore National Pike',
#    'address2': '',
#    'address3': '',
#    'city': 'Catonsville',
#    'zip_code': '21228',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['6600 Baltimore National Pike',
#     'Catonsville, MD 21228']},
#   'phone': '+14107197033',
#   'display_phone': '(410) 719-7033',
#   'distance': 13641.558061323254},
#  {'id': 'gwjfRoWfbI5_1QkeeVOFxg',
#   'alias': 'east-china-cafe-gwynn-oak',
#   'name': 'East China Cafe',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/east-china-cafe-gwynn-oak?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 39.315879, 'longitude': -76.739471},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1724 Woodlawn Dr',
#    'address2': 'Ste 1',
#    'address3': None,
#    'city': 'Gwynn Oak',
#    'zip_code': '21207',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1724 Woodlawn Dr', 'Ste 1', 'Gwynn Oak, MD 21207']},
#   'phone': '+14105978825',
#   'display_phone': '(410) 597-8825',
#   'distance': 11144.643540667526},
#  {'id': 'hHIYrmLi35Z9S-LS65S_0w',
#   'alias': 'noodles-and-company-towson',
#   'name': 'Noodles & Company',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/y4NcXONOGrBjjOAdxeqseg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/noodles-and-company-towson?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 66,
#   'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.3968347, 'longitude': -76.5845236},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$',
#   'location': {'address1': '825 Goucher Blvd',
#    'address2': '100 B',
#    'address3': '',
#    'city': 'Towson',
#    'zip_code': '21286',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['825 Goucher Blvd', '100 B', 'Towson, MD 21286']},
#   'phone': '+14102960778',
#   'display_phone': '(410) 296-0778',
#   'distance': 9960.53555224952},
#  {'id': 'ceutLk2DAvfqVEbJpwTBOQ',
#   'alias': 'b-and-a-carry-out-peking-glen-burnie',
#   'name': 'B & A Carry Out Peking',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DnXxPvNfEdIUb6ABU0aZ5A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/b-and-a-carry-out-peking-glen-burnie?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 1,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'vegetarian', 'title': 'Vegetarian'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 1.0,
#   'coordinates': {'latitude': 39.1833202000337, 'longitude': -76.639473854982},
#   'transactions': [],
#   'location': {'address1': '7225 Baltimore Annapolis Blvd',
#    'address2': '',
#    'address3': '',
#    'city': 'Glen Burnie',
#    'zip_code': '21061',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['7225 Baltimore Annapolis Blvd',
#     'Glen Burnie, MD 21061']},
#   'phone': '+14107666100',
#   'display_phone': '(410) 766-6100',
#   'distance': 14249.845619857779},
#  {'id': 'O5Jk5m2sm2o_zzOzDYDCTg',
#   'alias': 'ruby-thai-kitchen-towson',
#   'name': 'Ruby Thai Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HxgkNYJaSET5x5TR4ykMaQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ruby-thai-kitchen-towson?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 14,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 39.404075, 'longitude': -76.59921},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '825 Dulaney Valley Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Towson',
#    'zip_code': '21204',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['825 Dulaney Valley Rd', 'Towson, MD 21204']},
#   'phone': '+14104948800',
#   'display_phone': '(410) 494-8800',
#   'distance': 10573.847138426852},
#  {'id': 'UQ6BeOKeM-01v9-8-IQNhw',
#   'alias': 'panera-bread-pikesville',
#   'name': 'Panera Bread',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LnZlJSDp6xIKZ34d-PAAGg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/panera-bread-pikesville?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 37,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.3902676, 'longitude': -76.7412866},
#   'transactions': ['pickup'],
#   'price': '$',
#   'location': {'address1': '1852 Reisterstown Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Pikesville',
#    'zip_code': '21208',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['1852 Reisterstown Rd', 'Pikesville, MD 21208']},
#   'phone': '+14106025125',
#   'display_phone': '(410) 602-5125',
#   'distance': 14504.93675231911},
#  {'id': 'AtwKjW3qylM0781037XMEQ',
#   'alias': 'noodles-and-company-columbia',
#   'name': 'Noodles & Company',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/iMMLXx_hthHRPzXBnIZFbw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/noodles-and-company-columbia?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 135,
#   'categories': [{'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'noodles', 'title': 'Noodles'},
#    {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 39.1994255, 'longitude': -76.81267},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '6191 Old Dobbin Ln',
#    'address2': '',
#    'address3': '',
#    'city': 'Columbia',
#    'zip_code': '21045',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['6191 Old Dobbin Ln', 'Columbia, MD 21045']},
#   'phone': '+14108723729',
#   'display_phone': '(410) 872-3729',
#   'distance': 21369.206243316865},
#  {'id': 'K1Xgb1aTIqL7qD0MjewpAA',
#   'alias': 'kellys-cajun-grill-hanover',
#   'name': "Kelly's Cajun Grill",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HuOdldV7CnwRlnd0Ce9HHA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kellys-cajun-grill-hanover?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 26,
#   'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#    {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 39.1570476964906,
#    'longitude': -76.7256807160005},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '7000 Arundel Mills Cir',
#    'address2': '',
#    'address3': '',
#    'city': 'Hanover',
#    'zip_code': '21076',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['7000 Arundel Mills Cir', 'Hanover, MD 21076']},
#   'phone': '+14105405110',
#   'display_phone': '(410) 540-5110',
#   'distance': 19684.713837345524},
#  {'id': 'viOIpHVViYTOtJw8C7UXng',
#   'alias': 'pho-viet-baltimore-3',
#   'name': 'Pho Viet',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/k5OjG8mHMnTpu1GWiM0I4Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pho-viet-baltimore-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 157,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.290687, 'longitude': -76.614278},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '104 Saint Paul St',
#    'address2': None,
#    'address3': '',
#    'city': 'Baltimore',
#    'zip_code': '21202',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['104 Saint Paul St', 'Baltimore, MD 21202']},
#   'phone': '+14102441428',
#   'display_phone': '(410) 244-1428',
#   'distance': 2116.690510929977},
#  {'id': 'Fyl3yDKK6K_RSBqRfdKykw',
#   'alias': 'panda-express-towson-3',
#   'name': 'Panda Express',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/oEfc3x_vaavTgdrSkYkt1Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/panda-express-towson-3?adjust_creative=dTD4bQ8glEIuLwnjjDnCgQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=dTD4bQ8glEIuLwnjjDnCgQ',
#   'review_count': 2,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 39.393877, 'longitude': -76.618202},
#   'transactions': [],
#   'location': {'address1': '8000 York Rd',
#    'address2': 'Towson University',
#    'address3': None,
#    'city': 'Towson',
#    'zip_code': '21252',
#    'country': 'US',
#    'state': 'MD',
#    'display_address': ['8000 York Rd',
#     'Towson University',
#     'Towson, MD 21252']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 9438.993628984152}]

# %%
df = pd.DataFrame(loaded_results)
df
# Out:
#                          id                                  alias  \
# 0    ry3Y5KSxtn7rVf3amw31rw                china-house-baltimore-2
# 1    ZFFQuoUajWY_gYZ4HjfIKQ  water-song-yunnan-kitchen-baltimore-3
# 2    JZlGOTvnm2a8B7eGRlZZUg                      nihao-baltimore-2
# 3    C6ktcKtaj62akb8X0CqAWg              sunny-carry-out-baltimore
# 4    Mt8KF8_1T27QAY3ol1S2cg              wow-food-cafe-baltimore-9
# ..                      ...                                    ...
# 330  UQ6BeOKeM-01v9-8-IQNhw                panera-bread-pikesville
# 331  AtwKjW3qylM0781037XMEQ           noodles-and-company-columbia
# 332  K1Xgb1aTIqL7qD0MjewpAA             kellys-cajun-grill-hanover
# 333  viOIpHVViYTOtJw8C7UXng                   pho-viet-baltimore-3
# 334  Fyl3yDKK6K_RSBqRfdKykw                 panda-express-towson-3
#
#                           name  \
# 0                  China House
# 1    Water Song Yunnan Kitchen
# 2                        NiHao
# 3              Sunny Carry Out
# 4                WOW Food Cafe
# ..                         ...
# 330               Panera Bread
# 331          Noodles & Company
# 332        Kelly's Cajun Grill
# 333                   Pho Viet
# 334              Panda Express
#
#                                              image_url  is_closed  \
# 0    https://s3-media3.fl.yelpcdn.com/bphoto/EjebY0...      False
# 1    https://s3-media1.fl.yelpcdn.com/bphoto/lL_yo7...      False
# 2    https://s3-media1.fl.yelpcdn.com/bphoto/i5Vmne...      False
# 3    https://s3-media2.fl.yelpcdn.com/bphoto/uTMvf4...      False
# 4    https://s3-media2.fl.yelpcdn.com/bphoto/O8J8BF...      False
# ..                                                 ...        ...
# 330  https://s3-media4.fl.yelpcdn.com/bphoto/LnZlJS...      False
# 331  https://s3-media3.fl.yelpcdn.com/bphoto/iMMLXx...      False
# 332  https://s3-media2.fl.yelpcdn.com/bphoto/HuOdld...      False
# 333  https://s3-media1.fl.yelpcdn.com/bphoto/k5OjG8...      False
# 334  https://s3-media4.fl.yelpcdn.com/bphoto/oEfc3x...      False
#
#                                                    url  review_count  \
# 0    https://www.yelp.com/biz/china-house-baltimore...           184
# 1    https://www.yelp.com/biz/water-song-yunnan-kit...            68
# 2    https://www.yelp.com/biz/nihao-baltimore-2?adj...            79
# 3    https://www.yelp.com/biz/sunny-carry-out-balti...            76
# 4    https://www.yelp.com/biz/wow-food-cafe-baltimo...           177
# ..                                                 ...           ...
# 330  https://www.yelp.com/biz/panera-bread-pikesvil...            37
# 331  https://www.yelp.com/biz/noodles-and-company-c...           135
# 332  https://www.yelp.com/biz/kellys-cajun-grill-ha...            26
# 333  https://www.yelp.com/biz/pho-viet-baltimore-3?...           157
# 334  https://www.yelp.com/biz/panda-express-towson-...             2
#
#                                             categories  rating  \
# 0           [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 1    [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     4.5
# 2           [{'alias': 'chinese', 'title': 'Chinese'}]     4.5
# 3           [{'alias': 'chinese', 'title': 'Chinese'}]     4.0
# 4    [{'alias': 'bubbletea', 'title': 'Bubble Tea'}...     4.5
# ..                                                 ...     ...
# 330  [{'alias': 'sandwiches', 'title': 'Sandwiches'...     3.0
# 331  [{'alias': 'salad', 'title': 'Salad'}, {'alias...     3.0
# 332  [{'alias': 'cajun', 'title': 'Cajun/Creole'}, ...     2.5
# 333  [{'alias': 'vietnamese', 'title': 'Vietnamese'...     3.5
# 334  [{'alias': 'chinese', 'title': 'Chinese'}, {'a...     2.0
#
#                                            coordinates        transactions  \
# 0    {'latitude': 39.2856979370117, 'longitude': -7...          [delivery]
# 1     {'latitude': 39.276528, 'longitude': -76.613502}  [pickup, delivery]
# 2     {'latitude': 39.282945, 'longitude': -76.583924}          [delivery]
# 3       {'latitude': 39.28325, 'longitude': -76.62783}            [pickup]
# 4     {'latitude': 39.292012, 'longitude': -76.616007}          [delivery]
# ..                                                 ...                 ...
# 330  {'latitude': 39.3902676, 'longitude': -76.7412...            [pickup]
# 331   {'latitude': 39.1994255, 'longitude': -76.81267}                  []
# 332  {'latitude': 39.1570476964906, 'longitude': -7...                  []
# 333   {'latitude': 39.290687, 'longitude': -76.614278}  [delivery, pickup]
# 334   {'latitude': 39.393877, 'longitude': -76.618202}                  []
#
#     price                                           location         phone  \
# 0       $  {'address1': '2233 Eastern Ave', 'address2': '...  +14105223456
# 1     NaN  {'address1': '21 E Cross St', 'address2': '', ...  +14438694580
# 2     NaN  {'address1': '2322 Boston St', 'address2': '',...  +14438352036
# 3       $  {'address1': '758 Washington Blvd', 'address2'...  +14102448816
# 4      $$  {'address1': '222 N Charles St', 'address2': '...  +16672130043
# ..    ...                                                ...           ...
# 330     $  {'address1': '1852 Reisterstown Rd', 'address2...  +14106025125
# 331     $  {'address1': '6191 Old Dobbin Ln', 'address2':...  +14108723729
# 332     $  {'address1': '7000 Arundel Mills Cir', 'addres...  +14105405110
# 333    $$  {'address1': '104 Saint Paul St', 'address2': ...  +14102441428
# 334   NaN  {'address1': '8000 York Rd', 'address2': 'Tows...
#
#       display_phone      distance
# 0    (410) 522-3456   3344.553801
# 1    (443) 869-4580   3664.817209
# 2    (443) 835-2036   3640.045127
# 3    (410) 244-8816   3317.393328
# 4    (667) 213-0043   2012.195728
# ..              ...           ...
# 330  (410) 602-5125  14504.936752
# 331  (410) 872-3729  21369.206243
# 332  (410) 540-5110  19684.713837
# 333  (410) 244-1428   2116.690511
# 334                   9438.993629
#
# [335 rows x 16 columns]

# %% [markdown]
# ## Exploratory Analysis
#
# Take the restaurants from the previous question and do an initial exploratory analysis. At minimum, this should include looking at the distribution of features such as price, rating and number of reviews as well as the relations between these dimensions.

# %%
# Your code here
import seaborn as sns
sns.displot(data=df, x='rating')

# %%
sns.displot(data=df, x='review_count')

# %%
df['price'].value_counts(dropna=False).sort_index()#.plot()
# Out:
# $      120
# $$     126
# $$$      3
# NaN     86
# Name: price, dtype: int64

# %%
# sns.catplot(data=df, x='price',kind='count')

# %% [markdown]
# ## Mapping
#
# Look at the initial Yelp example and try and make a map using Folium of the restaurants you retrieved. Be sure to also add popups to the markers giving some basic information such as name, rating and price.

# %%
df['coordinates']
# Out:
# 0      {'latitude': 39.2856979370117, 'longitude': -7...
# 1       {'latitude': 39.276528, 'longitude': -76.613502}
# 2       {'latitude': 39.282945, 'longitude': -76.583924}
# 3         {'latitude': 39.28325, 'longitude': -76.62783}
# 4       {'latitude': 39.292012, 'longitude': -76.616007}
#                              ...
# 330    {'latitude': 39.3902676, 'longitude': -76.7412...
# 331     {'latitude': 39.1994255, 'longitude': -76.81267}
# 332    {'latitude': 39.1570476964906, 'longitude': -7...
# 333     {'latitude': 39.290687, 'longitude': -76.614278}
# 334     {'latitude': 39.393877, 'longitude': -76.618202}
# Name: coordinates, Length: 335, dtype: object

# %%
lat_long = df['coordinates'].iloc[0]
lat_long
# Out:
# {'latitude': 39.2856979370117, 'longitude': -76.5847778320312}

# %%
# Your code here
import folium

lat_long = df['coordinates'].iloc[0]
lat = lat_long['latitude']
long = lat_long['longitude']
yelp_map = folium.Map([lat, long])

for row in df.index:
    try:
        lat_long = df['coordinates'][row]
        lat = lat_long['latitude']
        long = lat_long['longitude']
        name = df['name'][row]
        rating = df['rating'][row]
        price = df['price'][row]
        details = f"{name}\nPrice: {str(price)} Rating:{str(rating)}"
        popup = folium.Popup(details, parse_html=True)
        marker = folium.Marker([lat, long], popup=popup)
        marker.add_to(yelp_map)
    except:
        print('Hit error on row: {}'.format(row))
yelp_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Summary
#
# Nice work! In this lab, you've made multiple API calls to Yelp in order to paginate through a results set, performing some basic exploratory analysis and then creating a nice interactive map to display the results using Folium! Well done!
