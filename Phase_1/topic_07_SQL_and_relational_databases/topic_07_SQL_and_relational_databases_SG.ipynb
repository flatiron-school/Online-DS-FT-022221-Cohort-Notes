# %% [markdown]
# # TOPIC 07: SQL DATABASES

# %% [markdown]
# - onl01-dtsc-ft-022221
# - 03/05/21

# %% [markdown]
# ## LEARNING OBJECTIVES:

# %% [markdown]
# - Understand what a relational database is and how it is different than a DataFrame/Excel sheet.
# - Understand how to read database map (AKA "Entity Relationship Diagram (ERD)")
#     - Primary keys vs forgein keys
# - Understand how to select, filter, order, and group data using SQL
# - Understand the different types of Joins
# #### 🏝 Breakout Group Activity:  [Survive on sql-island](https://sql-island.informatik.uni-kl.de/)

# %% [markdown]
# ### Questions:

# %% [markdown]
# - When doing some of the admin tasks like inserting rows, I tried to run an insert command again and got a "database is locked" error. In what circumstances does this happen, and are there best practices for closing the connection to avoid locking?
#
#
# - The SQL quiz had a question about the role of Associated Entities on many-to-many joins. I went back through the lessons and couldn't find a section which talked about that term. What should we know about many-to-many joins other than that they can become very large?
#
#
#
# - Can you rephrase the below statement?
# >"For example, let's say you have another table 'restaurants' that has many columns including name, city, and rating. If you were to join this 'restaurants' table with the offices table using the shared city column, you might get some unexpected behavior. That is, in the office table, there is only one office per city. However, because there will likely be more than one restaurant for each of these cities in your second table, you will get unique combinations of Offices and Restaurants from your join. If there are 513 restaurants for Boston in your restaurant table and 1 office for Boston, your joined table will have each of these 513 rows, one for each restaurant along with the one office.<br>
# If you had 2 offices for Boston and 513 restaurants, your join would have 1026 rows for Boston; 513 for each restaurant along with the first office and 513 for each restaurant with the second office. Three offices in Boston would similarly produce 1539 rows; one for each unique combination of restaurants and offices. This is where you should be particularly careful of many to many joins as the resulting set size can explode drastically potentially consuming vast amounts of memory and other resources."

# %% [markdown]
# # SQL Databases

# %% [markdown]
# <img src="https://raw.githubusercontent.com/learn-co-students/dsc-sql-introduction-online-ds-sp-000/master/images/Database-Schema.png">

# %% [markdown]
# - SQL is designed to work with **relational data**.
# - This really just means pieces of data that are **related to eachother**.
#
# - Each table has a **primary key** (like a DataFrame index), with a unique index for each row in the database.
# - The name of the primary key is preceded by an asterix (\*).
#
# - Columns that are the **primary key one on table** can also appear on **other tables**.
#     - Then it is refered to as a **foreign key** aka the primary key from a different ("foreign") table.

# %% [markdown]
# ### ⨠ Q: Why do we need databases? Why can't we just use a bunch of Pandas DataFrames?

# %% [markdown]
# -

# %% [markdown]
# ## Querying Databases - `SELECT`ing data

# %% [markdown]
# - To retrieve data from one or more tables you usually use a `SELECT` statement.
# ```SQL
# SELECT * FROM table;
# ```
#
#
# > - NOTE: SQL queries dot not _have_ to be all-caps, but it is a convention to help differentiate sql syntax versus names of tables/columns.
#
#
#
# - A more advanced select query.
# ```SQL
# SELECT col1, col2, col3
# FROM table
# WHERE records match criteria
# LIMIT 100;
# ```
#
# - **All select statements must:**
#     1. **start with the `SELECT`**
#     2. followed by **what you want to select**. Separate multiple column names separated by a `,`
#     3. Then specify where the data is coming `FROM` followed by the table name.
#     4. **Afterward, you can provide conditions such as filters or sorting**.
#
# ```SQL
# SELECT *
# FROM payments
# ORDER BY amount DESC
# LIMIT 10;
# ```
#
# <!--
# ```SQL
#
# ```
#  -->

# %% [markdown]
# ## SQL with `sqlite3`

# %% [markdown]
# - Use `sqlite3` for SQL queries in Python.
#     1. Connect to database
#     2. Create a cursor.
#     3. Form your query
#     4. Execute/fetch your results.
#
# ```python
# import sqlite3
# connection = sqlite3.connect('pet_database.db') # Creates pet_database, but empty until create a table
# cursor = connection.cursor()
#
#
# # Select from table
# cursor.execute('''SELECT name FROM cats;''').fetchall()
#
# ```

# %%
import pandas as pd
import os
os.getcwd()
# Out:
# '/Users/jamesirving/Documents/GitHub/_COHORT_NOTES/022221FT/Online-DS-FT-022221-Cohort-Notes/Phase_1/topic_07_SQL_and_relational_databases'

# %%
## Our data.sqlite is in the datasets folder in our note repo.
db = '../../datasets/SQL/data.sqlite'

# %%
import sqlite3
# connect to database
conn = sqlite3.connect(db)
cur = conn.cursor()

type(conn)
# Out:
# sqlite3.Connection

# %% [markdown]
# ### How to get all of the table names in a database
# >- The container for all tables in a database with sqlite3 is called `sqlite_master`
# >- We can find the name of all of the tables in a db using:
# >```python
# table_names = cur.execute("""
# SELECT name
# FROM sqlite_master
# WHERE type='table';
# """).fetchall()
# ```

# %%
# Get table names
table_names = cur.execute("""
SELECT name 
FROM sqlite_master 
WHERE type='table';
""").fetchall()
table_names
# Out:
# [('orderdetails',),
#  ('payments',),
#  ('offices',),
#  ('customers',),
#  ('orders',),
#  ('productlines',),
#  ('products',),
#  ('employees',),
#  ('cats',)]

# %%
## Clean up the list of table names to be just 1 list with strings
table_names = [x[0] for x in table_names]
table_names
# Out:
# ['orderdetails',
#  'payments',
#  'offices',
#  'customers',
#  'orders',
#  'productlines',
#  'products',
#  'employees',
#  'cats']

# %% [markdown]
# <img src="https://raw.githubusercontent.com/learn-co-students/dsc-sql-introduction-online-ds-sp-000/master/images/Database-Schema.png" width=500>

# %% [markdown]
# ### How to get the column names after executing a query:

# %%
df = pd.DataFrame(cur.execute("select * from products").fetchall())
df
# Out:
#              0                                      1             2      3  \
# 0     S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles   1:10
# 1     S10_1949               1952 Alpine Renault 1300  Classic Cars   1:10
# 2     S10_2016                  1996 Moto Guzzi 1100i   Motorcycles   1:10
# 3     S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles   1:10
# 4     S10_4757                    1972 Alfa Romeo GTA  Classic Cars   1:10
# ..         ...                                    ...           ...    ...
# 105  S700_3505                            The Titanic         Ships  1:700
# 106  S700_3962                         The Queen Mary         Ships  1:700
# 107  S700_4002              American Airlines: MD-11S        Planes  1:700
# 108   S72_1253                       Boeing X-32A JSF        Planes   1:72
# 109   S72_3212                             Pont Yacht         Ships   1:72
#
#                              4  \
# 0              Min Lin Diecast
# 1      Classic Metal Creations
# 2     Highway 66 Mini Classics
# 3            Red Start Diecast
# 4      Motor City Art Classics
# ..                         ...
# 105   Carousel DieCast Legends
# 106  Welly Diecast Productions
# 107        Second Gear Diecast
# 108    Motor City Art Classics
# 109       Unimax Art Galleries
#
#                                                      5     6      7       8
# 0    This replica features working kickstand, front...  7933  48.81   95.70
# 1    Turnable front wheels; steering function; deta...  7305  98.58  214.30
# 2    Official Moto Guzzi logos and insignias, saddl...  6625  68.99  118.94
# 3    Model features, official Harley Davidson logos...  5582  91.02  193.66
# 4    Features include: Turnable front wheels; steer...  3252  85.68  136.00
# ..                                                 ...   ...    ...     ...
# 105  Completed model measures 19 1/2 inches long, 9...  1956  51.09  100.17
# 106  Exact replica. Wood and Metal. Many extras inc...  5088  53.63   99.31
# 107  Polished finish. Exact replia with official lo...  8820  36.27   74.03
# 108  10" Wingspan with retractable landing gears.Co...  4857  32.77   49.66
# 109  Measures 38 inches Long x 33 3/4 inches High. ...   414  33.30   54.60
#
# [110 rows x 9 columns]

# %% [markdown]
# > - the cursor has a `.description` that contains information about the column names

# %%
cur.description
# Out:
# (('productCode', None, None, None, None, None, None),
#  ('productName', None, None, None, None, None, None),
#  ('productLine', None, None, None, None, None, None),
#  ('productScale', None, None, None, None, None, None),
#  ('productVendor', None, None, None, None, None, None),
#  ('productDescription', None, None, None, None, None, None),
#  ('quantityInStock', None, None, None, None, None, None),
#  ('buyPrice', None, None, None, None, None, None),
#  ('MSRP', None, None, None, None, None, None))

# %%
## Get a list of just the column names from the description
col_names =[col[0] for col in cur.description]
print(col_names)
# Out:
# ['productCode', 'productName', 'productLine', 'productScale', 'productVendor', 'productDescription', 'quantityInStock', 'buyPrice', 'MSRP']

# %%
df = pd.DataFrame(cur.execute('select * from products').fetchall(),
                  columns=col_names)
df.head()
# Out:
#   productCode                            productName   productLine  \
# 0    S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1    S10_1949               1952 Alpine Renault 1300  Classic Cars
# 2    S10_2016                  1996 Moto Guzzi 1100i   Motorcycles
# 3    S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles
# 4    S10_4757                    1972 Alfa Romeo GTA  Classic Cars
#
#   productScale             productVendor  \
# 0         1:10           Min Lin Diecast
# 1         1:10   Classic Metal Creations
# 2         1:10  Highway 66 Mini Classics
# 3         1:10         Red Start Diecast
# 4         1:10   Motor City Art Classics
#
#                                   productDescription quantityInStock buyPrice  \
# 0  This replica features working kickstand, front...            7933    48.81
# 1  Turnable front wheels; steering function; deta...            7305    98.58
# 2  Official Moto Guzzi logos and insignias, saddl...            6625    68.99
# 3  Model features, official Harley Davidson logos...            5582    91.02
# 4  Features include: Turnable front wheels; steer...            3252    85.68
#
#      MSRP
# 0   95.70
# 1  214.30
# 2  118.94
# 3  193.66
# 4  136.00

# %%
cur.execute("""PRAGMA table_info(products)""").fetchall()
# Out:
# [(0, 'productCode', '', 0, None, 0),
#  (1, 'productName', '', 0, None, 0),
#  (2, 'productLine', '', 0, None, 0),
#  (3, 'productScale', '', 0, None, 0),
#  (4, 'productVendor', '', 0, None, 0),
#  (5, 'productDescription', '', 0, None, 0),
#  (6, 'quantityInStock', '', 0, None, 0),
#  (7, 'buyPrice', '', 0, None, 0),
#  (8, 'MSRP', '', 0, None, 0)]

# %% [markdown]
# >### Quick Activity: Make executing the query -> dataframe into a function

# %%
def query_to_df(query,cursor=cur):
    df = pd.DataFrame(cursor.execute(query).fetchall(),
                  columns=[col[0] for col in cursor.description])
    return df

# %%
query_to_df("""SELECT * FROM EMPLOYEES""")
# Out:
#    employeeNumber   lastName firstName extension  \
# 0            1002     Murphy     Diane     x5800
# 1            1056  Patterson      Mary     x4611
# 2            1076   Firrelli      Jeff     x9273
# 3            1088  Patterson   William     x4871
# 4            1102     Bondur    Gerard     x5408
# 5            1143        Bow   Anthony     x5428
# 6            1165   Jennings    Leslie     x3291
# 7            1166   Thompson    Leslie     x4065
# 8            1188   Firrelli     Julie     x2173
# 9            1216  Patterson     Steve     x4334
# 10           1286      Tseng  Foon Yue     x2248
# 11           1323     Vanauf    George     x4102
# 12           1337     Bondur      Loui     x6493
# 13           1370  Hernandez    Gerard     x2028
# 14           1401   Castillo    Pamela     x2759
# 15           1501       Bott     Larry     x2311
# 16           1504      Jones     Barry      x102
# 17           1611     Fixter      Andy      x101
# 18           1612      Marsh     Peter      x102
# 19           1619       King       Tom      x103
# 20           1621      Nishi      Mami      x101
# 21           1625       Kato   Yoshimi      x102
# 22           1702     Gerard    Martin     x2312
#
#                               email officeCode reportsTo              jobTitle
# 0      dmurphy@classicmodelcars.com          1                       President
# 1    mpatterso@classicmodelcars.com          1      1002              VP Sales
# 2    jfirrelli@classicmodelcars.com          1      1002          VP Marketing
# 3   wpatterson@classicmodelcars.com          6      1056  Sales Manager (APAC)
# 4      gbondur@classicmodelcars.com          4      1056   Sale Manager (EMEA)
# 5         abow@classicmodelcars.com          1      1056    Sales Manager (NA)
# 6    ljennings@classicmodelcars.com          1      1143             Sales Rep
# 7    lthompson@classicmodelcars.com          1      1143             Sales Rep
# 8    jfirrelli@classicmodelcars.com          2      1143             Sales Rep
# 9   spatterson@classicmodelcars.com          2      1143             Sales Rep
# 10      ftseng@classicmodelcars.com          3      1143             Sales Rep
# 11     gvanauf@classicmodelcars.com          3      1143             Sales Rep
# 12     lbondur@classicmodelcars.com          4      1102             Sales Rep
# 13   ghernande@classicmodelcars.com          4      1102             Sales Rep
# 14   pcastillo@classicmodelcars.com          4      1102             Sales Rep
# 15       lbott@classicmodelcars.com          7      1102             Sales Rep
# 16      bjones@classicmodelcars.com          7      1102             Sales Rep
# 17     afixter@classicmodelcars.com          6      1088             Sales Rep
# 18      pmarsh@classicmodelcars.com          6      1088             Sales Rep
# 19       tking@classicmodelcars.com          6      1088             Sales Rep
# 20      mnishi@classicmodelcars.com          5      1056             Sales Rep
# 21       ykato@classicmodelcars.com          5      1621             Sales Rep
# 22     mgerard@classicmodelcars.com          4      1102             Sales Rep

# %% [markdown]
# # FILTERING AND ORDERING

# %% [markdown]
# - `ORDER BY` - `DESC`/`ASC`
# - `LIMIT`
# - `BETWEEN`
# - `NULL`
# - `COUNT`
# - `GROUP BY`

# %%
query = """select * from products
GROUP BY productLine 
ORDER BY quantityInStock DESC;"""
query_to_df(query)
# Out:
#   productCode                            productName       productLine  \
# 0    S18_1342                   1937 Lincoln Berline      Vintage Cars
# 1    S10_1678  1969 Harley Davidson Ultimate Chopper       Motorcycles
# 2    S10_1949               1952 Alpine Renault 1300      Classic Cars
# 3    S18_3259               Collectable Wooden Train            Trains
# 4    S18_1662            1980s Black Hawk Helicopter            Planes
# 5    S18_3029                 1999 Yamaha Speed Boat             Ships
# 6    S12_1666                         1958 Setra Bus  Trucks and Buses
#
#   productScale              productVendor  \
# 0         1:18    Motor City Art Classics
# 1         1:10            Min Lin Diecast
# 2         1:10    Classic Metal Creations
# 3         1:18   Carousel DieCast Legends
# 4         1:18          Red Start Diecast
# 5         1:18            Min Lin Diecast
# 6         1:12  Welly Diecast Productions
#
#                                   productDescription quantityInStock buyPrice  \
# 0  Features opening engine cover, doors, trunk, a...            8693    60.62
# 1  This replica features working kickstand, front...            7933    48.81
# 2  Turnable front wheels; steering function; deta...            7305    98.58
# 3  Hand crafted wooden toy train set is in about ...            6450    67.56
# 4  1:18 scale replica of actual Army's UH-60L BLA...            5330    77.27
# 5  Exact replica. Wood and Metal. Many extras inc...            4259    51.61
# 6  Model features 30 windows, skylights & glare r...            1579    77.90
#
#      MSRP
# 0  102.74
# 1   95.70
# 2  214.30
# 3  100.84
# 4  157.69
# 5   86.02
# 6  136.67

# %% [markdown]
# ## GROUPING DATA WITH SQL

# %% [markdown]
# - Like we do with Pandas, we can use GROUP BY statements in SQL and then apply **aggregate functions:**
#     - `COUNT`
#     - `MAX`
#     - `MIN`
#     - `SUM`
#     - `AVG`

# %% [markdown]
# ```SQL
# SELECT city, COUNT(employeeNumber)
# FROM offices
# JOIN employees
# USING(officeCode)
# GROUP BY city
# ORDER BY count(employeeNumber) DESC;
# ```

# %%
query="""SELECT city, COUNT(employeeNumber)
FROM offices 
JOIN employees
USING(officeCode)
GROUP BY city
ORDER BY count(employeeNumber) DESC;"""
query_to_df(query)
# Out:
#             city  COUNT(employeeNumber)
# 0  San Francisco                      6
# 1          Paris                      5
# 2         Sydney                      4
# 3          Tokyo                      2
# 4            NYC                      2
# 5         London                      2
# 6         Boston                      2

# %% [markdown]
# ## ALIASING

# %% [markdown]
# - can assign a temporary name to data being imported
# - Useful for `JOIN`,`GROUP BY`, and aggregates.

# %%
query="""SELECT city, COUNT(employeeNumber) AS numEmployees
               FROM offices
               JOIN employees
               USING(officeCode)
               GROUP BY 1
               ORDER BY numEmployees DESC;"""
query_to_df(query)
# Out:
#             city  numEmployees
# 0  San Francisco             6
# 1          Paris             5
# 2         Sydney             4
# 3          Tokyo             2
# 4            NYC             2
# 5         London             2
# 6         Boston             2

# %%
query_to_df("""SELECT customerName,
               COUNT(customerName) AS number_purchases,
               MIN(amount) AS min_purchase,
               MAX(amount) AS max_purchase,
               AVG(amount) AS avg_purchase,
               SUM(amount) AS total_spent
               FROM customers
               JOIN payments
               USING(customerNumber)
               GROUP BY 1
               ORDER BY SUM(amount) DESC;""")
# Out:
#                     customerName  number_purchases min_purchase max_purchase  \
# 0         Euro+ Shopping Channel                13    116208.40     65071.26
# 1   Mini Gifts Distributors Ltd.                 9    101244.59     85410.87
# 2     Australian Collectors, Co.                 4     44894.74     82261.22
# 3             Muscle Machine Inc                 4     20314.44     58841.35
# 4        Dragon Souveniers, Ltd.                 4    105743.00     44380.15
# ..                           ...               ...          ...          ...
# 93                  Royale Belge                 4      1128.20      1627.56
# 94            Frau da Collezione                 2     17746.26      7612.06
# 95             Atelier graphique                 3     14571.44      6066.78
# 96       Auto-Moto Classics Inc.                 3      5858.56      9658.74
# 97             Boards & Toys Co.                 2      3452.75      4465.85
#
#     avg_purchase  total_spent
# 0   55056.844615    715738.98
# 1   64909.804444    584188.24
# 2   45146.267500    180585.07
# 3   44478.487500    177913.95
# 4   39062.757500    156251.03
# ..           ...          ...
# 93   7304.295000     29217.18
# 94  12679.160000     25358.32
# 95   7438.120000     22314.36
# 96   7184.753333     21554.26
# 97   3959.300000      7918.60
#
# [98 rows x 6 columns]

# %% [markdown]
# ## The `WHERE` Clause

# %% [markdown]
# In general, the `WHERE` clause filters query results by some condition. As you are starting to see, you can also combine multiple conditions.
#
# -
# ```python
# cur.execute("""SELECT * FROM customers WHERE city = 'Boston' OR city = 'Madrid';""")
# df = pd.DataFrame(cur.fetchall())
# df.columns = [x[0] for x in cur.description]
# df
# ```
#
#
# - To refine your searches, you can add `ORDER BY` and `LIMIT` clauses.
#     - The order by clause allows you to sort the results by a particular feature.
# - Finally, the limit clause is typically the last argument in a SQL query and simply limits the output to a set number of results.

# %%
query_to_df("""SELECT * FROM customers WHERE city = 'Boston' OR city = 'Madrid';""")
# Out:
#   customerNumber                customerName contactLastName contactFirstName  \
# 0            141      Euro+ Shopping Channel          Freyre           Diego
# 1            237               ANG Resellers          Camino       Alejandra
# 2            344                 CAF Imports       Fernandez            Jesus
# 3            362           Gifts4AllAges.com         Yoshido             Juri
# 4            458  Corrida Auto Replicas, Ltd          Sommer          Martín
# 5            465         Anton Designs, Ltd.           Anton           Carmen
# 6            495        Diecast Collectables          Franco          Valarie
#
#              phone                      addressLine1           addressLine2  \
# 0   (91) 555 94 44                C/ Moralzarzal, 86
# 1    (91) 745 6555                       Gran Vía, 1
# 2  +34 913 728 555                   Merchants House  27-30 Merchant's Quay
# 3       6175559555                8616 Spinnaker Dr.
# 4   (91) 555 22 82                    C/ Araquil, 67
# 5   +34 913 728555  c/ Gobelas, 19-1 Urb. La Florida
# 6       6175552555                    6251 Ingle Ln.
#
#      city state postalCode country salesRepEmployeeNumber creditLimit
# 0  Madrid            28034   Spain                   1370   227600.00
# 1  Madrid            28001   Spain                               0.00
# 2  Madrid            28023   Spain                   1702    59600.00
# 3  Boston    MA      51003     USA                   1216    41900.00
# 4  Madrid            28023   Spain                   1702   104600.00
# 5  Madrid            28023   Spain                               0.00
# 6  Boston    MA      51003     USA                   1188    85100.00

# %% [markdown]
# ## The `HAVING` clause

# %% [markdown]
#  The `HAVING` clause works similarly to the `WHERE` clause, except it is used to filter data selections on conditions **after** the `GROUP BY` clause.

# %%
query_to_df("""SELECT city, COUNT(customerNumber) AS number_customers
               FROM customers
               GROUP BY 1
               HAVING COUNT(customerNumber)>=5;""")
# Out:
#      city  number_customers
# 0  Madrid                 5
# 1     NYC                 5

# %% [markdown]
# ## Combining `WHERE` and `HAVING`

# %% [markdown]
# We can also use the `WHERE` and `HAVING` clauses in conjunction with each other for more complex rules.
#
# - For example, let's say we want a list of customers who have made at least 3 purchases of over 50K each.

# %%
query_to_df("""SELECT customerName,
               COUNT(amount) AS number_purchases_over_50K
               FROM customers
               JOIN payments
               USING(customerNumber)
               WHERE amount >= 50000
               GROUP BY 1
               HAVING count(amount) >= 3
               ORDER BY number_purchases_over_50K DESC;""")
# Out:
#                     customerName  number_purchases_over_50K
# 0         Euro+ Shopping Channel                         13
# 1   Mini Gifts Distributors Ltd.                          9
# 2        Tokyo Collectables, Ltd                          4
# 3           Technics Stores Inc.                          4
# 4                   Royale Belge                          4
# 5             Reims Collectables                          4
# 6             Muscle Machine Inc                          4
# 7        Dragon Souveniers, Ltd.                          4
# 8     Down Under Souveniers, Inc                          4
# 9       Danish Wholesale Imports                          4
# 10          Blauer See Auto, Co.                          4
# 11            Baane Mini Imports                          4
# 12    Australian Collectors, Co.                          4
# 13       Anna's Decorations, Ltd                          4
# 14               Vitachrome Inc.                          3
# 15             Toys4GrownUps.com                          3
# 16          Toys of Finland, Co.                          3
# 17           Suominen Souveniers                          3
# 18      Stylish Desk Decors, Co.                          3
# 19     Souveniers And Things Co.                          3
# 20            Signal Gift Stores                          3
# 21        Saveley & Henriot, Co.                          3
# 22         Salzburg Collectables                          3
# 23                 Rovelli Gifts                          3
# 24  Québec Home Shopping Network                          3
# 25       Oulu Toy Supplies, Inc.                          3
# 26  Online Diecast Creations Co.                          3
# 27  Motor Mint Distributors Inc.                          3
# 28               Mini Wheels Co.                          3
# 29           Mini Creations Ltd.                          3
# 30                   Mini Caravy                          3
# 31               Mini Auto Werke                          3
# 32          Marseille Mini Autos                          3
# 33               Lyon Souveniers                          3
# 34             Land of Toys Inc.                          3
# 35             La Rochelle Gifts                          3
# 36     La Corne D'abondance, Co.                          3
# 37             Kelly's Gift Shop                          3
# 38              Handji Gifts& Co                          3
# 39              Gift Ideas Corp.                          3
# 40               Gift Depot Inc.                          3
# 41              FunGiftIdeas.com                          3
# 42            Enaco Distributors                          3
# 43               Cruz & Sons Co.                          3
# 44    Corrida Auto Replicas, Ltd                          3
# 45    Collectables For Less Inc.                          3
# 46          Classic Legends Inc.                          3
# 47       Auto-Moto Classics Inc.                          3
# 48             Auto Canal+ Petit                          3
# 49   Australian Gift Network, Co                          3
# 50             Atelier graphique                          3
# 51                  Alpha Cognac                          3
# 52                AV Stores, Co.                          3

# %%
query_to_df("""SELECT customerName,
               COUNT(amount) AS number_purchases_over_50K
               FROM customers
               JOIN payments
               USING(customerNumber)
               WHERE amount >= 50000
               GROUP BY 1
               HAVING number_purchases_over_50K >= 3
               ORDER BY number_purchases_over_50K DESC;""")

# %% [markdown]
# # JOINS

# %% [markdown]
# ### TYPES OF JOINS

# %% [markdown]
# - Joins may be:
#     - INNER (default)
#     - OUTER
#     - LEFT
#     - RIGHT

# %% [markdown]
# <img src="https://raw.githubusercontent.com/learn-co-students/dsc-join-statements-online-ds-sp-000/master/images/venn.png">

# %% [markdown]
# ## `JOIN` Statements

# %% [markdown]
# ### Primary vs Foreign Keys
# - primary key:
# - forgein key:

# %% [markdown]
# <img src="https://raw.githubusercontent.com/learn-co-students/dsc-sql-introduction-online-ds-sp-000/master/images/Database-Schema.png">

# %% [markdown]
# ### The `USING` clause

# %% [markdown]
# - If the column name is identical,you can use  is the `USING` clause.
# - Rather then saying on `tableA.column = tableB.column` we can simply say `using(column)`.
# - Only works if the column is **identically named** for both tables.

# %% [markdown]
# #### Task: Displaying product details along with order details
#
# Let's say you need to generate some report that includes details about products from orders. To do that, we would need to take data from multiple tables in a single statement.

# %%
query_to_df("""SELECT * 
               FROM orderdetails
               JOIN products
               ON orderdetails.productCode = products.productCode
               LIMIT 10;
               """)
# Out:
#   orderNumber productCode quantityOrdered priceEach orderLineNumber  \
# 0       10100    S18_1749              30    136.00               3
# 1       10100    S18_2248              50     55.09               2
# 2       10100    S18_4409              22     75.46               4
# 3       10100    S24_3969              49     35.29               1
# 4       10101    S18_2325              25    108.06               4
# 5       10101    S18_2795              26    167.06               1
# 6       10101    S24_1937              45     32.53               3
# 7       10101    S24_2022              46     44.35               2
# 8       10102    S18_1342              39     95.55               2
# 9       10102    S18_1367              41     43.13               1
#
#   productCode                                productName   productLine  \
# 0    S18_1749                   1917 Grand Touring Sedan  Vintage Cars
# 1    S18_2248                         1911 Ford Town Car  Vintage Cars
# 2    S18_4409        1932 Alfa Romeo 8C2300 Spider Sport  Vintage Cars
# 3    S24_3969           1936 Mercedes Benz 500k Roadster  Vintage Cars
# 4    S18_2325                  1932 Model A Ford J-Coupe  Vintage Cars
# 5    S18_2795                     1928 Mercedes-Benz SSK  Vintage Cars
# 6    S24_1937                1939 Chevrolet Deluxe Coupe  Vintage Cars
# 7    S24_2022  1938 Cadillac V-16 Presidential Limousine  Vintage Cars
# 8    S18_1342                       1937 Lincoln Berline  Vintage Cars
# 9    S18_1367   1936 Mercedes-Benz 500K Special Roadster  Vintage Cars
#
#   productScale              productVendor  \
# 0         1:18  Welly Diecast Productions
# 1         1:18    Motor City Art Classics
# 2         1:18              Exoto Designs
# 3         1:24          Red Start Diecast
# 4         1:18      Autoart Studio Design
# 5         1:18       Gearbox Collectibles
# 6         1:24    Motor City Art Classics
# 7         1:24    Classic Metal Creations
# 8         1:18    Motor City Art Classics
# 9         1:18        Studio M Art Models
#
#                                   productDescription quantityInStock buyPrice  \
# 0  This 1:18 scale replica of the 1917 Grand Tour...            2724    86.70
# 1  Features opening hood, opening doors, opening ...             540    33.30
# 2  This 1:18 scale precision die cast replica fea...            6553    43.26
# 3  This model features grille-mounted chrome horn...            2081    21.75
# 4  This model features grille-mounted chrome horn...            9354    58.48
# 5  This 1:18 replica features grille-mounted chro...             548    72.56
# 6  This 1:24 scale die-cast replica of the 1939 C...            7332    22.57
# 7  This 1:24 scale precision die cast replica of ...            2847    20.61
# 8  Features opening engine cover, doors, trunk, a...            8693    60.62
# 9  This 1:18 scale replica is constructed of heav...            8635    24.26
#
#      MSRP
# 0  170.00
# 1   60.54
# 2   92.03
# 3   41.03
# 4  127.13
# 5  168.75
# 6   33.19
# 7   44.80
# 8  102.74
# 9   53.91

# %% [markdown]
# ## Types of Relationships Between Tables

# %% [markdown]
# #### One-to-One, One-to-many, many-to-many Joins
#
#
# - **Let's say we have databases A and B**
#
#
# - **One-to-One joins:**
#     - There is only 1 entry in database B that aligns with each individual entry in database A
#     - e.g. A person and their social security number.
#
#
# - **One-to-Many join:**
#     - There are multiple entries in database B that match the entry in database A
#     - e.g. Joining an order number from db A with the individual products in db B.
#
#
# - **Many-to-many joins:**
#     - There are multiple entries in database A that match multiple entries in database B.
#     - e.g. A = classes at a college, B = students.

# %% [markdown]
# ### One-to-One

# %% [markdown]
# - There is only 1 entry in database B that aligns with each individual entry in database A
# - e.g. A person and their social security number.

# %%
## Preview full offices table
query_to_df("Select * FROM offices;")
# Out:
#   officeCode           city             phone              addressLine1  \
# 0          1  San Francisco   +1 650 219 4782         100 Market Street
# 1          2         Boston   +1 215 837 0825          1550 Court Place
# 2          3            NYC   +1 212 555 3000      523 East 53rd Street
# 3          4          Paris   +33 14 723 4404  43 Rue Jouffroy D'abbans
# 4          5          Tokyo   +81 33 224 5000               4-1 Kioicho
# 5          6         Sydney   +61 2 9264 2451     5-11 Wentworth Avenue
# 6          7         London  +44 20 7877 2041       25 Old Broad Street
#
#   addressLine2       state    country postalCode territory
# 0    Suite 300          CA        USA      94080        NA
# 1    Suite 102          MA        USA      02107        NA
# 2      apt. 5A          NY        USA      10022        NA
# 3                              France      75017      EMEA
# 4               Chiyoda-Ku      Japan   102-8578     Japan
# 5     Floor #2              Australia   NSW 2010      APAC
# 6      Level 7                     UK   EC2N 1HN      EMEA

# %%
## Preview full employees table
query_to_df("Select * FROM employees;")
# Out:
#    employeeNumber   lastName firstName extension  \
# 0            1002     Murphy     Diane     x5800
# 1            1056  Patterson      Mary     x4611
# 2            1076   Firrelli      Jeff     x9273
# 3            1088  Patterson   William     x4871
# 4            1102     Bondur    Gerard     x5408
# 5            1143        Bow   Anthony     x5428
# 6            1165   Jennings    Leslie     x3291
# 7            1166   Thompson    Leslie     x4065
# 8            1188   Firrelli     Julie     x2173
# 9            1216  Patterson     Steve     x4334
# 10           1286      Tseng  Foon Yue     x2248
# 11           1323     Vanauf    George     x4102
# 12           1337     Bondur      Loui     x6493
# 13           1370  Hernandez    Gerard     x2028
# 14           1401   Castillo    Pamela     x2759
# 15           1501       Bott     Larry     x2311
# 16           1504      Jones     Barry      x102
# 17           1611     Fixter      Andy      x101
# 18           1612      Marsh     Peter      x102
# 19           1619       King       Tom      x103
# 20           1621      Nishi      Mami      x101
# 21           1625       Kato   Yoshimi      x102
# 22           1702     Gerard    Martin     x2312
#
#                               email officeCode reportsTo              jobTitle
# 0      dmurphy@classicmodelcars.com          1                       President
# 1    mpatterso@classicmodelcars.com          1      1002              VP Sales
# 2    jfirrelli@classicmodelcars.com          1      1002          VP Marketing
# 3   wpatterson@classicmodelcars.com          6      1056  Sales Manager (APAC)
# 4      gbondur@classicmodelcars.com          4      1056   Sale Manager (EMEA)
# 5         abow@classicmodelcars.com          1      1056    Sales Manager (NA)
# 6    ljennings@classicmodelcars.com          1      1143             Sales Rep
# 7    lthompson@classicmodelcars.com          1      1143             Sales Rep
# 8    jfirrelli@classicmodelcars.com          2      1143             Sales Rep
# 9   spatterson@classicmodelcars.com          2      1143             Sales Rep
# 10      ftseng@classicmodelcars.com          3      1143             Sales Rep
# 11     gvanauf@classicmodelcars.com          3      1143             Sales Rep
# 12     lbondur@classicmodelcars.com          4      1102             Sales Rep
# 13   ghernande@classicmodelcars.com          4      1102             Sales Rep
# 14   pcastillo@classicmodelcars.com          4      1102             Sales Rep
# 15       lbott@classicmodelcars.com          7      1102             Sales Rep
# 16      bjones@classicmodelcars.com          7      1102             Sales Rep
# 17     afixter@classicmodelcars.com          6      1088             Sales Rep
# 18      pmarsh@classicmodelcars.com          6      1088             Sales Rep
# 19       tking@classicmodelcars.com          6      1088             Sales Rep
# 20      mnishi@classicmodelcars.com          5      1056             Sales Rep
# 21       ykato@classicmodelcars.com          5      1621             Sales Rep
# 22     mgerard@classicmodelcars.com          4      1102             Sales Rep

# %%
## One to one join
query_to_df('''SELECT * FROM employees 
JOIN offices USING(officeCode)
ORDER  BY officeCode;''')
# Out:
#    employeeNumber   lastName firstName extension  \
# 0            1002     Murphy     Diane     x5800
# 1            1056  Patterson      Mary     x4611
# 2            1076   Firrelli      Jeff     x9273
# 3            1143        Bow   Anthony     x5428
# 4            1165   Jennings    Leslie     x3291
# 5            1166   Thompson    Leslie     x4065
# 6            1188   Firrelli     Julie     x2173
# 7            1216  Patterson     Steve     x4334
# 8            1286      Tseng  Foon Yue     x2248
# 9            1323     Vanauf    George     x4102
# 10           1102     Bondur    Gerard     x5408
# 11           1337     Bondur      Loui     x6493
# 12           1370  Hernandez    Gerard     x2028
# 13           1401   Castillo    Pamela     x2759
# 14           1702     Gerard    Martin     x2312
# 15           1621      Nishi      Mami      x101
# 16           1625       Kato   Yoshimi      x102
# 17           1088  Patterson   William     x4871
# 18           1611     Fixter      Andy      x101
# 19           1612      Marsh     Peter      x102
# 20           1619       King       Tom      x103
# 21           1501       Bott     Larry     x2311
# 22           1504      Jones     Barry      x102
#
#                               email officeCode reportsTo  \
# 0      dmurphy@classicmodelcars.com          1
# 1    mpatterso@classicmodelcars.com          1      1002
# 2    jfirrelli@classicmodelcars.com          1      1002
# 3         abow@classicmodelcars.com          1      1056
# 4    ljennings@classicmodelcars.com          1      1143
# 5    lthompson@classicmodelcars.com          1      1143
# 6    jfirrelli@classicmodelcars.com          2      1143
# 7   spatterson@classicmodelcars.com          2      1143
# 8       ftseng@classicmodelcars.com          3      1143
# 9      gvanauf@classicmodelcars.com          3      1143
# 10     gbondur@classicmodelcars.com          4      1056
# 11     lbondur@classicmodelcars.com          4      1102
# 12   ghernande@classicmodelcars.com          4      1102
# 13   pcastillo@classicmodelcars.com          4      1102
# 14     mgerard@classicmodelcars.com          4      1102
# 15      mnishi@classicmodelcars.com          5      1056
# 16       ykato@classicmodelcars.com          5      1621
# 17  wpatterson@classicmodelcars.com          6      1056
# 18     afixter@classicmodelcars.com          6      1088
# 19      pmarsh@classicmodelcars.com          6      1088
# 20       tking@classicmodelcars.com          6      1088
# 21       lbott@classicmodelcars.com          7      1102
# 22      bjones@classicmodelcars.com          7      1102
#
#                 jobTitle           city             phone  \
# 0              President  San Francisco   +1 650 219 4782
# 1               VP Sales  San Francisco   +1 650 219 4782
# 2           VP Marketing  San Francisco   +1 650 219 4782
# 3     Sales Manager (NA)  San Francisco   +1 650 219 4782
# 4              Sales Rep  San Francisco   +1 650 219 4782
# 5              Sales Rep  San Francisco   +1 650 219 4782
# 6              Sales Rep         Boston   +1 215 837 0825
# 7              Sales Rep         Boston   +1 215 837 0825
# 8              Sales Rep            NYC   +1 212 555 3000
# 9              Sales Rep            NYC   +1 212 555 3000
# 10   Sale Manager (EMEA)          Paris   +33 14 723 4404
# 11             Sales Rep          Paris   +33 14 723 4404
# 12             Sales Rep          Paris   +33 14 723 4404
# 13             Sales Rep          Paris   +33 14 723 4404
# 14             Sales Rep          Paris   +33 14 723 4404
# 15             Sales Rep          Tokyo   +81 33 224 5000
# 16             Sales Rep          Tokyo   +81 33 224 5000
# 17  Sales Manager (APAC)         Sydney   +61 2 9264 2451
# 18             Sales Rep         Sydney   +61 2 9264 2451
# 19             Sales Rep         Sydney   +61 2 9264 2451
# 20             Sales Rep         Sydney   +61 2 9264 2451
# 21             Sales Rep         London  +44 20 7877 2041
# 22             Sales Rep         London  +44 20 7877 2041
#
#                 addressLine1 addressLine2       state    country postalCode  \
# 0          100 Market Street    Suite 300          CA        USA      94080
# 1          100 Market Street    Suite 300          CA        USA      94080
# 2          100 Market Street    Suite 300          CA        USA      94080
# 3          100 Market Street    Suite 300          CA        USA      94080
# 4          100 Market Street    Suite 300          CA        USA      94080
# 5          100 Market Street    Suite 300          CA        USA      94080
# 6           1550 Court Place    Suite 102          MA        USA      02107
# 7           1550 Court Place    Suite 102          MA        USA      02107
# 8       523 East 53rd Street      apt. 5A          NY        USA      10022
# 9       523 East 53rd Street      apt. 5A          NY        USA      10022
# 10  43 Rue Jouffroy D'abbans                              France      75017
# 11  43 Rue Jouffroy D'abbans                              France      75017
# 12  43 Rue Jouffroy D'abbans                              France      75017
# 13  43 Rue Jouffroy D'abbans                              France      75017
# 14  43 Rue Jouffroy D'abbans                              France      75017
# 15               4-1 Kioicho               Chiyoda-Ku      Japan   102-8578
# 16               4-1 Kioicho               Chiyoda-Ku      Japan   102-8578
# 17     5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 18     5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 19     5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 20     5-11 Wentworth Avenue     Floor #2              Australia   NSW 2010
# 21       25 Old Broad Street      Level 7                     UK   EC2N 1HN
# 22       25 Old Broad Street      Level 7                     UK   EC2N 1HN
#
#    territory
# 0         NA
# 1         NA
# 2         NA
# 3         NA
# 4         NA
# 5         NA
# 6         NA
# 7         NA
# 8         NA
# 9         NA
# 10      EMEA
# 11      EMEA
# 12      EMEA
# 13      EMEA
# 14      EMEA
# 15     Japan
# 16     Japan
# 17      APAC
# 18      APAC
# 19      APAC
# 20      APAC
# 21      EMEA
# 22      EMEA

# %% [markdown]
# ### One-to-Many

# %% [markdown]
# - There are multiple entries in database B that match the entry in database A
# - e.g. Joining an order number from db A with the individual products in db B.

# %%
## preview table 1 
query_to_df("SELECT * FROM products;")
# Out:
#     productCode                            productName   productLine  \
# 0      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1      S10_1949               1952 Alpine Renault 1300  Classic Cars
# 2      S10_2016                  1996 Moto Guzzi 1100i   Motorcycles
# 3      S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles
# 4      S10_4757                    1972 Alfa Romeo GTA  Classic Cars
# ..          ...                                    ...           ...
# 105   S700_3505                            The Titanic         Ships
# 106   S700_3962                         The Queen Mary         Ships
# 107   S700_4002              American Airlines: MD-11S        Planes
# 108    S72_1253                       Boeing X-32A JSF        Planes
# 109    S72_3212                             Pont Yacht         Ships
#
#     productScale              productVendor  \
# 0           1:10            Min Lin Diecast
# 1           1:10    Classic Metal Creations
# 2           1:10   Highway 66 Mini Classics
# 3           1:10          Red Start Diecast
# 4           1:10    Motor City Art Classics
# ..           ...                        ...
# 105        1:700   Carousel DieCast Legends
# 106        1:700  Welly Diecast Productions
# 107        1:700        Second Gear Diecast
# 108         1:72    Motor City Art Classics
# 109         1:72       Unimax Art Galleries
#
#                                     productDescription quantityInStock  \
# 0    This replica features working kickstand, front...            7933
# 1    Turnable front wheels; steering function; deta...            7305
# 2    Official Moto Guzzi logos and insignias, saddl...            6625
# 3    Model features, official Harley Davidson logos...            5582
# 4    Features include: Turnable front wheels; steer...            3252
# ..                                                 ...             ...
# 105  Completed model measures 19 1/2 inches long, 9...            1956
# 106  Exact replica. Wood and Metal. Many extras inc...            5088
# 107  Polished finish. Exact replia with official lo...            8820
# 108  10" Wingspan with retractable landing gears.Co...            4857
# 109  Measures 38 inches Long x 33 3/4 inches High. ...             414
#
#     buyPrice    MSRP
# 0      48.81   95.70
# 1      98.58  214.30
# 2      68.99  118.94
# 3      91.02  193.66
# 4      85.68  136.00
# ..       ...     ...
# 105    51.09  100.17
# 106    53.63   99.31
# 107    36.27   74.03
# 108    32.77   49.66
# 109    33.30   54.60
#
# [110 rows x 9 columns]

# %%
## preview table 2
query_to_df("SELECT * FROM productlines;")
# Out:
#         productLine                                    textDescription  \
# 0      Classic Cars  Attention car enthusiasts: Make your wildest c...
# 1       Motorcycles  Our motorcycles are state of the art replicas ...
# 2            Planes  Unique, diecast airplane and helicopter replic...
# 3             Ships  The perfect holiday or anniversary gift for ex...
# 4            Trains  Model trains are a rewarding hobby for enthusi...
# 5  Trucks and Buses  The Truck and Bus models are realistic replica...
# 6      Vintage Cars  Our Vintage Car models realistically portray a...
#
#   htmlDescription image
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
## One-to-Many Join
query_to_df("""SELECT * 
               FROM products
               LEFT JOIN productlines
               USING(productLine);""")
# Out:
#     productCode                            productName   productLine  \
# 0      S10_1678  1969 Harley Davidson Ultimate Chopper   Motorcycles
# 1      S10_1949               1952 Alpine Renault 1300  Classic Cars
# 2      S10_2016                  1996 Moto Guzzi 1100i   Motorcycles
# 3      S10_4698   2003 Harley-Davidson Eagle Drag Bike   Motorcycles
# 4      S10_4757                    1972 Alfa Romeo GTA  Classic Cars
# ..          ...                                    ...           ...
# 105   S700_3505                            The Titanic         Ships
# 106   S700_3962                         The Queen Mary         Ships
# 107   S700_4002              American Airlines: MD-11S        Planes
# 108    S72_1253                       Boeing X-32A JSF        Planes
# 109    S72_3212                             Pont Yacht         Ships
#
#     productScale              productVendor  \
# 0           1:10            Min Lin Diecast
# 1           1:10    Classic Metal Creations
# 2           1:10   Highway 66 Mini Classics
# 3           1:10          Red Start Diecast
# 4           1:10    Motor City Art Classics
# ..           ...                        ...
# 105        1:700   Carousel DieCast Legends
# 106        1:700  Welly Diecast Productions
# 107        1:700        Second Gear Diecast
# 108         1:72    Motor City Art Classics
# 109         1:72       Unimax Art Galleries
#
#                                     productDescription quantityInStock  \
# 0    This replica features working kickstand, front...            7933
# 1    Turnable front wheels; steering function; deta...            7305
# 2    Official Moto Guzzi logos and insignias, saddl...            6625
# 3    Model features, official Harley Davidson logos...            5582
# 4    Features include: Turnable front wheels; steer...            3252
# ..                                                 ...             ...
# 105  Completed model measures 19 1/2 inches long, 9...            1956
# 106  Exact replica. Wood and Metal. Many extras inc...            5088
# 107  Polished finish. Exact replia with official lo...            8820
# 108  10" Wingspan with retractable landing gears.Co...            4857
# 109  Measures 38 inches Long x 33 3/4 inches High. ...             414
#
#     buyPrice    MSRP                                    textDescription  \
# 0      48.81   95.70  Our motorcycles are state of the art replicas ...
# 1      98.58  214.30  Attention car enthusiasts: Make your wildest c...
# 2      68.99  118.94  Our motorcycles are state of the art replicas ...
# 3      91.02  193.66  Our motorcycles are state of the art replicas ...
# 4      85.68  136.00  Attention car enthusiasts: Make your wildest c...
# ..       ...     ...                                                ...
# 105    51.09  100.17  The perfect holiday or anniversary gift for ex...
# 106    53.63   99.31  The perfect holiday or anniversary gift for ex...
# 107    36.27   74.03  Unique, diecast airplane and helicopter replic...
# 108    32.77   49.66  Unique, diecast airplane and helicopter replic...
# 109    33.30   54.60  The perfect holiday or anniversary gift for ex...
#
#     htmlDescription image
# 0
# 1
# 2
# 3
# 4
# ..              ...   ...
# 105
# 106
# 107
# 108
# 109
#
# [110 rows x 12 columns]

# %% [markdown]
# ### Many-to-Many

# %% [markdown]
# - There are multiple entries in database A that match multiple entries in database B.
# - e.g. A = classes at a college, B = students.

# %%
query_to_df("""SELECT * FROM offices
                        JOIN customers
                        USING(state);""")
# Out:
#     officeCode           city             phone         addressLine1  \
# 0            1  San Francisco   +1 650 219 4782    100 Market Street
# 1            1  San Francisco   +1 650 219 4782    100 Market Street
# 2            1  San Francisco   +1 650 219 4782    100 Market Street
# 3            1  San Francisco   +1 650 219 4782    100 Market Street
# 4            1  San Francisco   +1 650 219 4782    100 Market Street
# ..         ...            ...               ...                  ...
# 240          7         London  +44 20 7877 2041  25 Old Broad Street
# 241          7         London  +44 20 7877 2041  25 Old Broad Street
# 242          7         London  +44 20 7877 2041  25 Old Broad Street
# 243          7         London  +44 20 7877 2041  25 Old Broad Street
# 244          7         London  +44 20 7877 2041  25 Old Broad Street
#
#     addressLine2 state country postalCode territory customerNumber  ...  \
# 0      Suite 300    CA     USA      94080        NA            124  ...
# 1      Suite 300    CA     USA      94080        NA            129  ...
# 2      Suite 300    CA     USA      94080        NA            161  ...
# 3      Suite 300    CA     USA      94080        NA            205  ...
# 4      Suite 300    CA     USA      94080        NA            219  ...
# ..           ...   ...     ...        ...       ...            ...  ...
# 240      Level 7            UK   EC2N 1HN      EMEA            480  ...
# 241      Level 7            UK   EC2N 1HN      EMEA            481  ...
# 242      Level 7            UK   EC2N 1HN      EMEA            484  ...
# 243      Level 7            UK   EC2N 1HN      EMEA            489  ...
# 244      Level 7            UK   EC2N 1HN      EMEA            496  ...
#
#     contactLastName contactFirstName             phone  \
# 0            Nelson            Susan        4155551450
# 1            Murphy            Julie        6505555787
# 2         Hashimoto             Juri        6505556809
# 3             Young            Julie        6265557265
# 4             Young             Mary        3105552373
# ..              ...              ...               ...
# 240         Semenov       Alexander    +7 812 293 0521
# 241     Altagar,G M           Raanan  + 972 9 959 8555
# 242            Roel      José Pedro     (95) 555 82 82
# 243           Smith          Thomas     (171) 555-7555
# 244         Snowden             Tony     +64 9 5555500
#
#                   addressLine1 addressLine2              city postalCode  \
# 0              5677 Strong St.                     San Rafael      97562
# 1    5557 North Pendale Street                  San Francisco      94217
# 2            9408 Furth Circle                     Burlingame      94217
# 3           78934 Hillside Dr.                       Pasadena      90003
# 4             4097 Douglas Av.                       Glendale      92561
# ..                         ...          ...               ...        ...
# 240            2 Pobedy Square               Saint Petersburg     196143
# 241             3 Hagalim Blv.                        Herzlia      47625
# 242              C/ Romero, 33                        Sevilla      41101
# 243            120 Hanover Sq.                         London    WA1 1DP
# 244         Arenales 1938 3'A'                     Auckland
#
#          country salesRepEmployeeNumber creditLimit
# 0            USA                   1165   210500.00
# 1            USA                   1165    64600.00
# 2            USA                   1165    84600.00
# 3            USA                   1166    90700.00
# 4            USA                   1166    11000.00
# ..           ...                    ...         ...
# 240       Russia                               0.00
# 241       Israel                               0.00
# 242        Spain                   1702    65700.00
# 243           UK                   1501    43300.00
# 244  New Zealand                   1612   110000.00
#
# [245 rows x 21 columns]

# %% [markdown]
# ## SQL Subqueries

# %% [markdown]
# - WHen making a subq, start by testing the  sub-Q itself before using in the larger query

# %% [markdown]
# ```python
# cur.execute("""SELECT lastName, firstName, officeCode
#                FROM employees
#                WHERE officeCode IN (SELECT officeCode
#                                     FROM offices
#                                     WHERE country = "USA");
#                                     """)
# df = pd.DataFrame(cur.fetchall())
# df.columns = [x[0] for x in cur.description]
# df
# ```

# %% [markdown]
# ###  Example Subquery

# %% [markdown]
# ```SQL
# SELECT LAB_MONTH,MPI
# ,CW_UPI
# ,LAST_NAME
# ,FIRST_NAME
# ,FACILITY_NUMBER
# ,CCN
# ,FACILITY_NAME
# ,NUMBER_OF_CLINICS
# ,HOME_FACILITY
# ,TRANSIENT
# ,CASE WHEN ADMITDATE <= '7/1/2020'
#   AND (PATIENTDISCHARGEDATE >= '7/31/2020'
#     OR PATIENTDISCHARGEDATE IS NULL)
#   THEN 'FULL MONTH' ELSE 'LESS THAN A MONTH' END FULL_MONTH
# ,ADMITDATE AS ADMIT_DATE
# ,ADMITREASON AS ADMIT_REASON
# ,CASE WHEN PATIENTDISCHARGEDATE >= ADMITDATE
#   THEN PATIENTDISCHARGEDATE ELSE NULL END DISCHARGE_DATE
# FROM (
#   SELECT *
#   ,ROW_NUMBER() OVER (PARTITION BY MPI, FACILITY_NUMBER ORDER BY ADMITDATE DESC) ADMIT_ROW_NUM
#   FROM (
#     SELECT DISTINCT
#     LAB_MONTH
#     ,labs.IDPATIENT AS MPI
#     ,map.CWIDPATIENT AS CW_UPI
#     ,name.LASTNAME AS LAST_NAME
#     ,name.FIRSTNAME AS FIRST_NAME
#     ,cln.IDCORPCLINIC AS FACILITY_NUMBER
#     ,TRANSLATE(MEDICARECERTNUM, '-', '') AS CCN
#     ,NAMECLINIC AS FACILITY_NAME
#     ,NUM_CLINICS AS NUMBER_OF_CLINICS
#     ,CASE WHEN labs.IDCLINICNUMBER = pnt.HOME_LOCATIONID
#       THEN 'YES' ELSE 'NO' END HOME_FACILITY
#     ,per.TRANSIENT
#     ,per.ADMITDATE
#     ,per.ADMITREASON
#     ,pnt.PATIENTDISCHARGEDATE
#     ,pnt.REC_EFFECTIVE_START_DATE AS PNT_REC_EFFECTIVE_START_DATE
#     FROM(
#       SELECT *
#       ,COUNT(DISTINCT IDCLINICNUMBER) OVER (PARTITION BY IDPATIENT) AS NUM_CLINICS
#       ,TO_CHAR(LAST_DAY(DATEDRAW),'yyyymm') AS LAB_MONTH
#       FROM AUD_RSLTS_VW
#       WHERE AUD_CURRENT_ROW_FLAG = 'Y'
#       AND DATEDRAW BETWEEN '2020-07-01' AND '2020-07-31'
#       ) labs
#     LEFT JOIN AUD_CLINIC_VW cln
#     ON labs.IDCLINICNUMBER = cln.CODECLINIC
#     LEFT JOIN CWPATIENTMAP_VW map
#     ON labs.IDPATIENT = map.IDPATIENT
#     LEFT JOIN (
#       SELECT
#       PATIENTID
#       ,LASTNAME
#       ,FIRSTNAME
#       FROM MSTR_PATIENT_DIM_VW
#       WHERE REC_CURRENT_IND = 1
#       ) name
#     ON labs.IDPATIENT = name.PATIENTID
#     LEFT JOIN MSTR_PATIENT_DIM_VW pnt
#     ON labs.IDPATIENT = pnt.PATIENTID
#     AND labs.IDCLINICNUMBER = pnt.HOME_LOCATIONID
#     LEFT JOIN MSTR_FACILITY_DIM_VW fac
#     ON labs.IDCLINICNUMBER = fac.LOCATIONID
#     LEFT JOIN CW_GAP_PERIOD_PREVALENCE_VW per
#     ON labs.IDPATIENT = per.ORGPATIENTID
#     AND cln.IDCORPCLINIC = LPAD(CAST(per.ORGFACILITYCODE AS VARCHAR(5)), 5, '0')
#     WHERE NUM_CLINICS > 1
#     AND cln.AUD_CURRENT_ROW_FLAG = 'Y'
#     AND fac.REC_CURRENT_IND = 1
#     AND fac.REC_DELETED_IND <> 1
#     ) X
#   ) Y
# WHERE ADMIT_ROW_NUM = 1
# ORDER BY NUMBER_OF_CLINICS ASC, MPI, HOME_FACILITY DESC, FACILITY_NUMBER
#     ```

# %% [markdown]
# # Pandas + SQL

# %% [markdown]
# ## Using SQL-like queries in Pandas - `df.query()`

# %% [markdown]
# - Pandas DataFrames have a method called `.query()`
# - This allows us to use SQL-like commands to reference data.
# ```python
# ## Normal Pandas Syntax
# foo_df = bar_df.loc[bar_df['Col_1']>bar_df['Col_2']]
# ```
#
# ```python
# ## Using .query()
# foo_df = bar_df.query("Col_1 > Col_2")
# ```
# - How to use:
#     - Enter the querty as a single string, using just column names to reference data.
#     - To use and/or statements, use `&` and `|`, respectively
#
# ```python
# foo_df = bar_df.query("Col_1 > Col_2 & Col_2 <= Col_3")
# ```

# %% [markdown]
# ## Using SQL syntax with `pandasql`

# %% [markdown]
# - There is a library is called [pandasql](https://pypi.org/project/pandasql/) that allows for sql queries with pandas
#
# We can install `pandasql` using the bash command `pip install pandasql`.

# %% [markdown]
# ### Importing pandasql
#
# - In order to use `pandasql`, we need to start by importing a `sqldf` object from `pandasql`
# - You must also already have loaded in all dataframes that you wish to query
# ```python
# from pandasql import sqldf
# pysqldf = lambda q: sqldf(q, globals())
# ```
#
# ### Writing Queries
# ```python
# q = """SELECT
#         m.date, m.beef, b.births
#      FROM
#         meats m
#      INNER JOIN
#         births b
#            ON m.date = b.date;"""
#
# results = pysqldf(q)
#
# ```

# %% [markdown]
# ## DATABASE ADMIN 101

# %% [markdown]
# ### Creating Tables/SQL Data Types

# %% [markdown]
# - `CREATE TABLE IF NOT EXISTS table_name`
#     -  Must include (col_name, datatype, and if its the key)
# ```PYTHON
#   cur.execute("""CREATE TABLE IF NOT EXISTS cats (
#     id INTEGER PRIMARY KEY,
#     name TEXT,
#     age INTEGER,
#     breed TEXT)
#     """)
#     ```

# %% [markdown]
# - Data types in SQLite3:
#     - https://www.sqlite.org/datatype3.html
#
# - Data types:
#     - TEXT
#     - INTEGER
#     - REAL
#     - BLOB
#     - NULL

# %% [markdown]
# #### Dropping a Table
# - `DROP TABLE table_name`
#     - `DROP TABLE IF EXISTS table_name`

# %% [markdown]
# #### Adding values to a table
# - `INSERT INTO table_name`
#     - list the columns to fill in first and then the VALUES()
# ```python
# cur.execute('''INSERT INTO cats (name, age, breed)
#                   VALUES ('Maru', 3, 'Scottish Fold');
#             ''')
# ```
#
# - To add multiple:
# ```python
# cur.execute('''INSERT INTO cats (name, age, breed)
#             VALUES (?, ?, ?);
#       ''',(dict_cats))
# ```
# - `UPDATE`
#
# ```python
# for dct in contacts:
#     fname = dct['firstName']
#     lname = dct['lastName']
#     role = dct['role']
#     phone = dct['telephone ']
#     street = dct['street']
#     city = dct['city']
#     state = dct['state']
#     z = dct['zipcode ']
#
#     cur.execute('''INSERT INTO contactInfo (firstname, lastname, role, telephone, street, city, state, zipcode)
# VALUES (?,?,?,?,?,?,?,?)''', (fname, lname, role, phone, street, city, state, z))
# ```

# %%
# cur.execute("""CREATE TABLE cats (
#     id INTEGER PRIMARY KEY,
#     name TEXT,
#     age INTEGER,
#     breed TEXT)
#     """)

# %% [markdown]
# # 🏝 Breakout Group Activity:  [Survive on sql-island](https://sql-island.informatik.uni-kl.de/)

# %% [markdown]
# - Survive on sql-island
#     - https://sql-island.informatik.uni-kl.de/
# - 3 min walk through together before breakout rooms

# %% [markdown]
# #### Fist, change language to English
# - click white menu button.
# <img src="https://raw.githubusercontent.com/flatiron-school/Online-DS-FT-022221-Cohort-Notes/master/assets/images/sql-island/SQL%20Island%201.png">
#
# - Select option to change language (option 3)
# <img src="https://raw.githubusercontent.com/flatiron-school/Online-DS-FT-022221-Cohort-Notes/master/assets/images/sql-island/SQL%20Island%202.png" width=35%>
#
# - Select English
# <img src="https://raw.githubusercontent.com/flatiron-school/Online-DS-FT-022221-Cohort-Notes/master/assets/images/sql-island/SQL%20Island%203.png" width=35%>

# %% [markdown]
# #### Take Note of the Tables and Column Names

# %% [markdown]
# <img src="https://raw.githubusercontent.com/flatiron-school/Online-DS-FT-022221-Cohort-Notes/master/assets/images/sql-island/SQL%20Island%204.png" width=80%>
