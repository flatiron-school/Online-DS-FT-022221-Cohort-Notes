# %% [markdown]
# # Topic 37: Intro to Time Series

# %% [markdown]
# - 05/27/21
# - onl01-dtsc-ft-022221

# %% [markdown]
# ## Learning Objectives:

# %% [markdown]
# - Learn how to load in timeseries data into pandas
# - Learn how to plot timeseries in pandas
# - Learn how to resample at different time frequencies
# - Learn about types of time series trends and how to remove them.
# - Learn about seasonal decomposition
#
# - Prepare a time series dataset to use for modeling next class

# %% [markdown]
# ## Questions?

# %% [markdown]
# -

# %% [markdown]
# # Intro to Time Series

# %% [markdown]
# ## References

# %% [markdown]
# - [Pandas Timeseries Documentation](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html)
# - ['Timeseries Offset Aliases'](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#timeseries-offset-aliases)
# - [Anchored Offsets](https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#anchored-offsets)
#
#
# - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Timestamp.html

# %% [markdown]
# # Working with Time Series

# %%
## Import the essentials
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import numpy as np
import pandas as pd
import os,sys


## Setting figures to timeseries-friendly
plt.rcParams['figure.figsize'] = (12,4)
# sns.set_context('talk')

# import warnings
# warnings.filterwarnings('ignore')

## Time Series Tools from statsmodels
import statsmodels.tsa.api as tsa
import statsmodels
print(f'Statsmodels version = {statsmodels.__version__}')
# Out:
# Statsmodels version = 0.12.2

# %% [markdown]
# ## Creating a Time Series from a DataFrame

# %% [markdown]
# ### Data is from Baltimore's Open-Data Portal

# %% [markdown]
# - New Crime Stats Just downloaded:
# - [Baltimore Open Data](https://www.baltimorepolice.org/crime-stats/open-data)
#     - We Are Using [Part 1 Crime](https://data.baltimorecity.gov/search?q=crime%20data):
#     - https://data.baltimorecity.gov/datasets/3eeb0a2cbae94b3e8549a8193717a9e1_0/explore
#
# - **Note: to save space, I converted the .csv to a .csv.gz using this code**
# ```python
# ## Read orig csv from Downloads and save .gz vers to local folder
# df = pd.read_csv('/Users/jamesirving/Downloads/Part1_Crime_data.csv')
# df.to_csv('baltimore_crime_05-26-21.csv.gz',compression='gzip',index=False)
# ```

# %%
## Read in the data
file = 'baltimore_crime_05-26-21.csv.gz'
df = pd.read_csv(file)
df
# Out:
#               X        Y   RowID           CrimeDateTime CrimeCode  \
# 0      -76.6985  39.3324       1  2021/05/22 14:01:44+00        1A
# 1      -76.6755  39.2928       2  2021/05/22 00:01:00+00        4D
# 2      -76.6552  39.2976       3  2021/05/22 18:11:00+00        1A
# 3      -76.6064  39.2948       4  2021/05/22 19:44:00+00        4E
# 4      -76.5957  39.2995       5  2021/05/22 15:10:00+00        4E
# ...         ...      ...     ...                     ...       ...
# 336768 -76.6913  39.2896  337407  1975/06/01 00:00:00+00        2A
# 336769 -76.6872  39.3262  337408  1973/07/01 23:00:00+00        2A
# 336770 -76.6571  39.3100  337409  1970/06/15 00:01:00+00        2A
# 336771 -76.6353  39.3589  337410  1969/07/20 21:00:00+00        2A
# 336772 -76.7026  39.3269  337411  1963/10/30 00:00:00+00        2A
#
#                           Location     Description Inside_Outside   Weapon  \
# 0         4900 LIBERTY HEIGHTS AVE        HOMICIDE        Outside  FIREARM
# 1               3500 W FRANKLIN ST    AGG. ASSAULT              O    HANDS
# 2       2400 CALVERTON HEIGHTS AVE        HOMICIDE        Outside  FIREARM
# 3                     400 ENSOR ST  COMMON ASSAULT              O      NaN
# 4                1600 E MADISON ST  COMMON ASSAULT              O      NaN
# ...                            ...             ...            ...      ...
# 336768       4400 OLD FREDERICK RD            RAPE              I    OTHER
# 336769         4000 SPRINGDALE AVE            RAPE              I    OTHER
# 336770         2400 ST STEPHENS CT            RAPE              I    OTHER
# 336771             5400 ROLAND AVE            RAPE            NaN    OTHER
# 336772           3100 FERNDALE AVE            RAPE              I    OTHER
#
#        Post   District         Neighborhood  Latitude  Longitude  \
# 0       622  NORTHWEST          HOWARD PARK   39.3324   -76.6985
# 1       824  SOUTHWEST            ALLENDALE   39.2928   -76.6755
# 2       723    WESTERN       EVERGREEN LAWN   39.2976   -76.6552
# 3       324    EASTERN              OLDTOWN   39.2948   -76.6064
# 4       323    EASTERN           GAY STREET   39.2995   -76.5957
# ...     ...        ...                  ...       ...        ...
# 336768  822  SOUTHWEST              UPLANDS   39.2896   -76.6913
# 336769  621  NORTHWEST  CENTRAL FOREST PARK   39.3262   -76.6872
# 336770  731    WESTERN            MONDAWMIN   39.3100   -76.6571
# 336771  534   NORTHERN          ROLAND PARK   39.3589   -76.6353
# 336772  622  NORTHWEST          HOWARD PARK   39.3269   -76.7026
#
#                GeoLocation               Premise VRIName  Total_Incidents
# 0       (39.3324,-76.6985)           PARKING LOT     NaN                1
# 1       (39.2928,-76.6755)  STREET                   NaN                1
# 2       (39.2976,-76.6552)              DWELLING     NaN                1
# 3       (39.2948,-76.6064)  STREET                   NaN                1
# 4       (39.2995,-76.5957)  STREET                   NaN                1
# ...                    ...                   ...     ...              ...
# 336768  (39.2896,-76.6913)  OTHER - INSIDE           NaN                1
# 336769  (39.3262,-76.6872)     ROW/TOWNHOUSE-OCC     NaN                1
# 336770    (39.31,-76.6571)     ROW/TOWNHOUSE-OCC     NaN                1
# 336771  (39.3589,-76.6353)                   NaN     NaN                1
# 336772  (39.3269,-76.7026)     ROW/TOWNHOUSE-OCC     NaN                1
#
# [336773 rows x 18 columns]

# %%
## Keeping Necessary/Desired Columns
keep_cols = ['CrimeDateTime','Description','Total_Incidents',
             'District','Neighborhood'
#               'Weapon', 'Latitude','Longitude',
            ]
df = df[keep_cols]
df
# Out:
#                  CrimeDateTime     Description  Total_Incidents   District  \
# 0       2021/05/22 14:01:44+00        HOMICIDE                1  NORTHWEST
# 1       2021/05/22 00:01:00+00    AGG. ASSAULT                1  SOUTHWEST
# 2       2021/05/22 18:11:00+00        HOMICIDE                1    WESTERN
# 3       2021/05/22 19:44:00+00  COMMON ASSAULT                1    EASTERN
# 4       2021/05/22 15:10:00+00  COMMON ASSAULT                1    EASTERN
# ...                        ...             ...              ...        ...
# 336768  1975/06/01 00:00:00+00            RAPE                1  SOUTHWEST
# 336769  1973/07/01 23:00:00+00            RAPE                1  NORTHWEST
# 336770  1970/06/15 00:01:00+00            RAPE                1    WESTERN
# 336771  1969/07/20 21:00:00+00            RAPE                1   NORTHERN
# 336772  1963/10/30 00:00:00+00            RAPE                1  NORTHWEST
#
#                Neighborhood
# 0               HOWARD PARK
# 1                 ALLENDALE
# 2            EVERGREEN LAWN
# 3                   OLDTOWN
# 4                GAY STREET
# ...                     ...
# 336768              UPLANDS
# 336769  CENTRAL FOREST PARK
# 336770            MONDAWMIN
# 336771          ROLAND PARK
# 336772          HOWARD PARK
#
# [336773 rows x 5 columns]

# %% [markdown]
# ## Preparing Data for Time Series Visualization

# %% [markdown]
# - Index must be a `datetimeindex`

# %%
## Check Index 
df.index
# Out:
# RangeIndex(start=0, stop=336773, step=1)

# %%
## Convert CrimeDateTime to datetime and set as index
df['CrimeDateTime'] = pd.to_datetime(df['CrimeDateTime'])
df.set_index('CrimeDateTime',inplace=True)
df.index
# Out:
# <ipython-input-42-f7419459dba5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CrimeDateTime'] = pd.to_datetime(df['CrimeDateTime'])
# DatetimeIndex(['2021-05-22 14:01:44+00:00', '2021-05-22 00:01:00+00:00',
#                '2021-05-22 18:11:00+00:00', '2021-05-22 19:44:00+00:00',
#                '2021-05-22 15:10:00+00:00', '2021-05-22 13:00:00+00:00',
#                '2021-05-22 13:00:00+00:00', '2021-05-22 11:40:00+00:00',
#                '2021-05-22 12:00:00+00:00', '2021-05-22 22:00:00+00:00',
#                ...
#                '1979-01-01 00:01:00+00:00', '1978-01-01 00:00:00+00:00',
#                '1978-01-01 10:30:00+00:00', '1978-01-01 00:00:00+00:00',
#                '1977-05-01 00:01:00+00:00', '1975-06-01 00:00:00+00:00',
#                '1973-07-01 23:00:00+00:00', '1970-06-15 00:01:00+00:00',
#                '1969-07-20 21:00:00+00:00', '1963-10-30 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='CrimeDateTime', length=336773, freq=None)

# %%
df.head()
# Out:
#                               Description  Total_Incidents   District  \
# CrimeDateTime
# 2021-05-22 14:01:44+00:00        HOMICIDE                1  NORTHWEST
# 2021-05-22 00:01:00+00:00    AGG. ASSAULT                1  SOUTHWEST
# 2021-05-22 18:11:00+00:00        HOMICIDE                1    WESTERN
# 2021-05-22 19:44:00+00:00  COMMON ASSAULT                1    EASTERN
# 2021-05-22 15:10:00+00:00  COMMON ASSAULT                1    EASTERN
#
#                              Neighborhood
# CrimeDateTime
# 2021-05-22 14:01:44+00:00     HOWARD PARK
# 2021-05-22 00:01:00+00:00       ALLENDALE
# 2021-05-22 18:11:00+00:00  EVERGREEN LAWN
# 2021-05-22 19:44:00+00:00         OLDTOWN
# 2021-05-22 15:10:00+00:00      GAY STREET

# %% [markdown]
# #### What do we notice about the index?

# %% [markdown]
# - frequency?
# - range?

# %%
df['Description'].value_counts().to_frame().style.bar()
# Out:
# <style  type="text/css" >
# #T_504da030_bf08_11eb_aa96_acde48001122row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_504da030_bf08_11eb_aa96_acde48001122row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 76.5%, transparent 76.5%);
#         }#T_504da030_bf08_11eb_aa96_acde48001122row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 62.1%, transparent 62.1%);
#         }#T_504da030_bf08_11eb_aa96_acde48001122row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 57.1%, transparent 57.1%);
#         }#T_504da030_bf08_11eb_aa96_acde48001122row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 50.6%, transparent 50.6%);
#         }#T_504da030_bf08_11eb_aa96_acde48001122row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 38.3%, transparent 38.3%);
#         }#T_504da030_bf08_11eb_aa96_acde48001122row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 29.5%, transparent 29.5%);
#         }#T_504da030_bf08_11eb_aa96_acde48001122row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.1%, transparent 6.1%);
#         }#T_504da030_bf08_11eb_aa96_acde48001122row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.6%, transparent 4.6%);
#         }#T_504da030_bf08_11eb_aa96_acde48001122row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.0%, transparent 3.0%);
#         }#T_504da030_bf08_11eb_aa96_acde48001122row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.3%, transparent 2.3%);
#         }#T_504da030_bf08_11eb_aa96_acde48001122row11_col0,#T_504da030_bf08_11eb_aa96_acde48001122row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
#         }#T_504da030_bf08_11eb_aa96_acde48001122row13_col0{
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_504da030_bf08_11eb_aa96_acde48001122" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_504da030_bf08_11eb_aa96_acde48001122level0_row0" class="row_heading level0 row0" >LARCENY</th>
#                         <td id="T_504da030_bf08_11eb_aa96_acde48001122row0_col0" class="data row0 col0" >74681</td>
#             </tr>
#             <tr>
#                         <th id="T_504da030_bf08_11eb_aa96_acde48001122level0_row1" class="row_heading level0 row1" >COMMON ASSAULT</th>
#                         <td id="T_504da030_bf08_11eb_aa96_acde48001122row1_col0" class="data row1 col0" >57451</td>
#             </tr>
#             <tr>
#                         <th id="T_504da030_bf08_11eb_aa96_acde48001122level0_row2" class="row_heading level0 row2" >BURGLARY</th>
#                         <td id="T_504da030_bf08_11eb_aa96_acde48001122row2_col0" class="data row2 col0" >46935</td>
#             </tr>
#             <tr>
#                         <th id="T_504da030_bf08_11eb_aa96_acde48001122level0_row3" class="row_heading level0 row3" >LARCENY FROM AUTO</th>
#                         <td id="T_504da030_bf08_11eb_aa96_acde48001122row3_col0" class="data row3 col0" >43223</td>
#             </tr>
#             <tr>
#                         <th id="T_504da030_bf08_11eb_aa96_acde48001122level0_row4" class="row_heading level0 row4" >AGG. ASSAULT</th>
#                         <td id="T_504da030_bf08_11eb_aa96_acde48001122row4_col0" class="data row4 col0" >38478</td>
#             </tr>
#             <tr>
#                         <th id="T_504da030_bf08_11eb_aa96_acde48001122level0_row5" class="row_heading level0 row5" >AUTO THEFT</th>
#                         <td id="T_504da030_bf08_11eb_aa96_acde48001122row5_col0" class="data row5 col0" >29502</td>
#             </tr>
#             <tr>
#                         <th id="T_504da030_bf08_11eb_aa96_acde48001122level0_row6" class="row_heading level0 row6" >ROBBERY - STREET</th>
#                         <td id="T_504da030_bf08_11eb_aa96_acde48001122row6_col0" class="data row6 col0" >23056</td>
#             </tr>
#             <tr>
#                         <th id="T_504da030_bf08_11eb_aa96_acde48001122level0_row7" class="row_heading level0 row7" >ROBBERY - COMMERCIAL</th>
#                         <td id="T_504da030_bf08_11eb_aa96_acde48001122row7_col0" class="data row7 col0" >5872</td>
#             </tr>
#             <tr>
#                         <th id="T_504da030_bf08_11eb_aa96_acde48001122level0_row8" class="row_heading level0 row8" >SHOOTING</th>
#                         <td id="T_504da030_bf08_11eb_aa96_acde48001122row8_col0" class="data row8 col0" >4788</td>
#             </tr>
#             <tr>
#                         <th id="T_504da030_bf08_11eb_aa96_acde48001122level0_row9" class="row_heading level0 row9" >ROBBERY - RESIDENCE</th>
#                         <td id="T_504da030_bf08_11eb_aa96_acde48001122row9_col0" class="data row9 col0" >3590</td>
#             </tr>
#             <tr>
#                         <th id="T_504da030_bf08_11eb_aa96_acde48001122level0_row10" class="row_heading level0 row10" >ROBBERY - CARJACKING</th>
#                         <td id="T_504da030_bf08_11eb_aa96_acde48001122row10_col0" class="data row10 col0" >3128</td>
#             </tr>
#             <tr>
#                         <th id="T_504da030_bf08_11eb_aa96_acde48001122level0_row11" class="row_heading level0 row11" >RAPE</th>
#                         <td id="T_504da030_bf08_11eb_aa96_acde48001122row11_col0" class="data row11 col0" >2333</td>
#             </tr>
#             <tr>
#                         <th id="T_504da030_bf08_11eb_aa96_acde48001122level0_row12" class="row_heading level0 row12" >HOMICIDE</th>
#                         <td id="T_504da030_bf08_11eb_aa96_acde48001122row12_col0" class="data row12 col0" >2327</td>
#             </tr>
#             <tr>
#                         <th id="T_504da030_bf08_11eb_aa96_acde48001122level0_row13" class="row_heading level0 row13" >ARSON</th>
#                         <td id="T_504da030_bf08_11eb_aa96_acde48001122row13_col0" class="data row13 col0" >1409</td>
#             </tr>
#     </tbody></table>

# %%
## Grab All Shootings  - using groupby
group_df = df.groupby('Description').get_group('SHOOTING')
group_df
# Out:
#                           Description  Total_Incidents   District  \
# CrimeDateTime
# 2021-05-22 22:54:00+00:00    SHOOTING                1    WESTERN
# 2021-05-21 15:48:00+00:00    SHOOTING                1    WESTERN
# 2021-05-21 15:48:00+00:00    SHOOTING                1    WESTERN
# 2021-05-20 19:42:00+00:00    SHOOTING                1    CENTRAL
# 2021-05-20 23:00:00+00:00    SHOOTING                1  NORTHWEST
# ...                               ...              ...        ...
# 2014-01-05 19:41:00+00:00    SHOOTING                1    CENTRAL
# 2014-01-05 16:30:00+00:00    SHOOTING                1  SOUTHWEST
# 2014-01-03 14:32:00+00:00    SHOOTING                1    WESTERN
# 2014-01-01 22:31:00+00:00    SHOOTING                1  NORTHEAST
# 2014-01-01 17:35:00+00:00    SHOOTING                1  NORTHWEST
#
#                                    Neighborhood
# CrimeDateTime
# 2021-05-22 22:54:00+00:00   SANDTOWN-WINCHESTER
# 2021-05-21 15:48:00+00:00        EVERGREEN LAWN
# 2021-05-21 15:48:00+00:00        EVERGREEN LAWN
# 2021-05-20 19:42:00+00:00                 UPTON
# 2021-05-20 23:00:00+00:00      TOWANDA-GRANTLEY
# ...                                         ...
# 2014-01-05 19:41:00+00:00                 UPTON
# 2014-01-05 16:30:00+00:00        ROGNEL HEIGHTS
# 2014-01-03 14:32:00+00:00       FRANKLIN SQUARE
# 2014-01-01 22:31:00+00:00        GLENHAM-BELHAR
# 2014-01-01 17:35:00+00:00  CENTRAL PARK HEIGHTS
#
# [4788 rows x 4 columns]

# %%
## Checking total-incidents value_counts
df['Total_Incidents'].value_counts()
# Out:
# 1    336773
# Name: Total_Incidents, dtype: int64

# %%
## Lets get just Shootings in a new series
crime = 'SHOOTING'
group_df = df.groupby('Description').get_group(crime)['Total_Incidents'].rename(crime)

# %%
## Get list of crimes to iterate through
crimes = list(df['Description'].unique())
crimes
# Out:
# ['HOMICIDE',
#  'AGG. ASSAULT',
#  'COMMON ASSAULT',
#  'LARCENY',
#  'AUTO THEFT',
#  'ROBBERY - CARJACKING',
#  'BURGLARY',
#  'LARCENY FROM AUTO',
#  'ROBBERY - COMMERCIAL',
#  'SHOOTING',
#  'ROBBERY - RESIDENCE',
#  'ROBBERY - STREET',
#  'ARSON',
#  'RAPE']

# %%
## make a dict of all crime types' DataFrames 
CRIMES = {}

## For each crime type
for crime in crimes:    
    ## Get the group df
    group_df = df.groupby('Description').get_group(crime)['Total_Incidents'].rename(crime)
    ## Save the group_df into the CRIMES dict
    CRIMES[crime] =group_df
    
## Display the keys
CRIMES.keys()
# Out:
# dict_keys(['HOMICIDE', 'AGG. ASSAULT', 'COMMON ASSAULT', 'LARCENY', 'AUTO THEFT', 'ROBBERY - CARJACKING', 'BURGLARY', 'LARCENY FROM AUTO', 'ROBBERY - COMMERCIAL', 'SHOOTING', 'ROBBERY - RESIDENCE', 'ROBBERY - STREET', 'ARSON', 'RAPE'])

# %% [markdown]
# # Visualizing Time Series

# %%
## Pull out shooting from CRIMES dict
ts = CRIMES['SHOOTING'].copy()

# %%
## Plot the ts
ts.plot()
# Out:
# <AxesSubplot:xlabel='CrimeDateTime'>

# %% [markdown]
# #### Q: What went wrong? What are we looking at?

# %% [markdown]
# -

# %% [markdown]
# ## Time Series Frequencies & Resampling

# %%
## Resample to daily data ("D")
ts = ts.resample("D").sum()
ts
# Out:
# CrimeDateTime
# 1970-01-01 00:00:00+00:00    11
# 1970-01-02 00:00:00+00:00     0
# 1970-01-03 00:00:00+00:00     0
# 1970-01-04 00:00:00+00:00     0
# 1970-01-05 00:00:00+00:00     0
#                              ..
# 2021-05-18 00:00:00+00:00     3
# 2021-05-19 00:00:00+00:00     0
# 2021-05-20 00:00:00+00:00     3
# 2021-05-21 00:00:00+00:00     2
# 2021-05-22 00:00:00+00:00     1
# Freq: D, Name: SHOOTING, Length: 18770, dtype: int64

# %%
## Check the index, whats different?
ts.index
# Out:
# DatetimeIndex(['1970-01-01 00:00:00+00:00', '1970-01-02 00:00:00+00:00',
#                '1970-01-03 00:00:00+00:00', '1970-01-04 00:00:00+00:00',
#                '1970-01-05 00:00:00+00:00', '1970-01-06 00:00:00+00:00',
#                '1970-01-07 00:00:00+00:00', '1970-01-08 00:00:00+00:00',
#                '1970-01-09 00:00:00+00:00', '1970-01-10 00:00:00+00:00',
#                ...
#                '2021-05-13 00:00:00+00:00', '2021-05-14 00:00:00+00:00',
#                '2021-05-15 00:00:00+00:00', '2021-05-16 00:00:00+00:00',
#                '2021-05-17 00:00:00+00:00', '2021-05-18 00:00:00+00:00',
#                '2021-05-19 00:00:00+00:00', '2021-05-20 00:00:00+00:00',
#                '2021-05-21 00:00:00+00:00', '2021-05-22 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='CrimeDateTime', length=18770, freq='D')

# %%
## PLot the time series
ts.plot()
# Out:
# <AxesSubplot:xlabel='CrimeDateTime'>

# %% [markdown]
# >#### Q: It worked! But whats the issue?

# %% [markdown]
# ## Slicing With Time Series

# %% [markdown]
# - Make sure your index is sorted first'
# - Use `.loc` with dates as strings for slicing

# %%
## Slice out dates prior to rise in daily counts
ts.sort_index(inplace=True)

# %%
ts[2015:]
# Out:
# CrimeDateTime
# 1975-07-09 00:00:00+00:00    0
# 1975-07-10 00:00:00+00:00    0
# 1975-07-11 00:00:00+00:00    0
# 1975-07-12 00:00:00+00:00    0
# 1975-07-13 00:00:00+00:00    0
#                             ..
# 2021-05-18 00:00:00+00:00    3
# 2021-05-19 00:00:00+00:00    0
# 2021-05-20 00:00:00+00:00    3
# 2021-05-21 00:00:00+00:00    2
# 2021-05-22 00:00:00+00:00    1
# Freq: D, Name: SHOOTING, Length: 16755, dtype: int64

# %%
ts.loc["2015-":]
# Out:
# CrimeDateTime
# 2015-06-01 00:00:00+00:00    1
# 2015-06-02 00:00:00+00:00    3
# 2015-06-03 00:00:00+00:00    0
# 2015-06-04 00:00:00+00:00    0
# 2015-06-05 00:00:00+00:00    0
#                             ..
# 2021-05-18 00:00:00+00:00    3
# 2021-05-19 00:00:00+00:00    0
# 2021-05-20 00:00:00+00:00    3
# 2021-05-21 00:00:00+00:00    2
# 2021-05-22 00:00:00+00:00    1
# Freq: D, Name: SHOOTING, Length: 2183, dtype: int64

# %%
ts = ts.loc["2015":]
ts.plot()
# Out:
# <AxesSubplot:xlabel='CrimeDateTime'>

# %% [markdown]
# >#### Much better! sort of... but whats the issue now?

# %% [markdown]
# ### Time series Frequencies

# %% [markdown]
# - We want the daily counts for our crimes.
#     - In order to do so we have to resample the ts using the correct frequency alias.
# - For time series modeling, we will need our time series as a specific frequency without missing data.

# %% [markdown]
# #### Pandas Frequency Aliases

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/user_guide/timeseries.html#timeseries-offset-aliases
#
#
# |Alias	| Description|
# | --- | --- |
# |B |	business day frequency|
# |C |	custom business day frequency|
# |D |	calendar day frequency|
# |W |	weekly frequency|
# |M |	month end frequency|
# |SM |	semi-month end frequency (15th and end of month)|
# |BM |	business month end frequency|
# |CBM |	custom business month end frequency|
# |MS |	month start frequency|
# |SMS |	semi-month start frequency (1st and 15th)|
# |BMS |	business month start frequency|
# |CBMS |	custom business month start frequency|
# |Q |	quarter end frequency|
# |BQ |	business quarter end frequency|
# |QS |	quarter start frequency|
# |BQS |	business quarter start frequency|
# |A, Y |	year end frequency|
# |BA, BY |	business year end frequency|
# |AS, YS |	year start frequency|
# |BAS, BYS |	business year start frequency|
# |BH | business hour frequency|
# |H | hourly frequency|
# |T |  min	minutely frequency|
# |S | secondly frequency|
# |L |  ms	milliseconds|
# |U |  us	microseconds|
# |N | nanoseconds|

# %% [markdown]
# #### Compare Resampled ts

# %%
## Plot the same ts as different frequencies
## Specify freq codes daily, every 3 days, weekly, Monthly, Quarterly, yearly
freq_codes = ['D','3D','W','M','Q','A']
## select ts from CRIMES
ts = CRIMES['SHOOTING'].sort_index().loc['2015':]
## For each freq code
for freq in freq_codes:
    ## make a new figure, resample and plot
    plt.figure()
    ts.resample(freq).sum().plot(title=freq)

# %%
## Plot the same ts as different frequencies
## Specify freq codes daily, every 3 days, weekly, Monthly, Quarterly, yearly
freq_codes = ['D','3D','W','M','Q','A']
## select ts from CRIMES
ts = CRIMES['SHOOTING'].sort_index().loc['2015':]
## For each freq code
for freq in freq_codes:
    ## make a new figure, resample and plot
#     plt.figure()
    ts.resample(freq).sum().plot(title=freq)

# %% [markdown]
# ## Visualize all CRIMES as "D" Freq

# %% [markdown]
# >- **Loop through all CRIMES, slice out 2015-Present, and resample as "D"**
#     - We can always downsample without issue, but upsampling is a problematic

# %% [markdown]
# ### Using Dictionaries for TIme Series preprocessing

# %%
df
# Out:
#                               Description  Total_Incidents   District  \
# CrimeDateTime
# 2021-05-22 14:01:44+00:00        HOMICIDE                1  NORTHWEST
# 2021-05-22 00:01:00+00:00    AGG. ASSAULT                1  SOUTHWEST
# 2021-05-22 18:11:00+00:00        HOMICIDE                1    WESTERN
# 2021-05-22 19:44:00+00:00  COMMON ASSAULT                1    EASTERN
# 2021-05-22 15:10:00+00:00  COMMON ASSAULT                1    EASTERN
# ...                                   ...              ...        ...
# 1975-06-01 00:00:00+00:00            RAPE                1  SOUTHWEST
# 1973-07-01 23:00:00+00:00            RAPE                1  NORTHWEST
# 1970-06-15 00:01:00+00:00            RAPE                1    WESTERN
# 1969-07-20 21:00:00+00:00            RAPE                1   NORTHERN
# 1963-10-30 00:00:00+00:00            RAPE                1  NORTHWEST
#
#                                   Neighborhood
# CrimeDateTime
# 2021-05-22 14:01:44+00:00          HOWARD PARK
# 2021-05-22 00:01:00+00:00            ALLENDALE
# 2021-05-22 18:11:00+00:00       EVERGREEN LAWN
# 2021-05-22 19:44:00+00:00              OLDTOWN
# 2021-05-22 15:10:00+00:00           GAY STREET
# ...                                        ...
# 1975-06-01 00:00:00+00:00              UPLANDS
# 1973-07-01 23:00:00+00:00  CENTRAL FOREST PARK
# 1970-06-15 00:01:00+00:00            MONDAWMIN
# 1969-07-20 21:00:00+00:00          ROLAND PARK
# 1963-10-30 00:00:00+00:00          HOWARD PARK
#
# [336773 rows x 4 columns]

# %%
## make a dict of all crime types' DataFrames 
TS = {}

## For each crime type
for crime in crimes:    
    ## Get the group df
    group_df = df.groupby('Description').get_group(crime)['Total_Incidents'].rename(crime)
    ## Save the group_df into the CRIMES dict
    TS[crime] =group_df.resample('D').sum().loc['2014':]
    
## Display the keys
TS.keys()
# Out:
# dict_keys(['HOMICIDE', 'AGG. ASSAULT', 'COMMON ASSAULT', 'LARCENY', 'AUTO THEFT', 'ROBBERY - CARJACKING', 'BURGLARY', 'LARCENY FROM AUTO', 'ROBBERY - COMMERCIAL', 'SHOOTING', 'ROBBERY - RESIDENCE', 'ROBBERY - STREET', 'ARSON', 'RAPE'])

# %%
## Check shooting
TS["SHOOTING"]
# Out:
# CrimeDateTime
# 2014-01-01 00:00:00+00:00    2
# 2014-01-02 00:00:00+00:00    0
# 2014-01-03 00:00:00+00:00    1
# 2014-01-04 00:00:00+00:00    0
# 2014-01-05 00:00:00+00:00    2
#                             ..
# 2021-05-18 00:00:00+00:00    3
# 2021-05-19 00:00:00+00:00    0
# 2021-05-20 00:00:00+00:00    3
# 2021-05-21 00:00:00+00:00    2
# 2021-05-22 00:00:00+00:00    1
# Freq: D, Name: SHOOTING, Length: 2699, dtype: int64

# %% [markdown]
# ### Now that we have the same frequency for each crime series, make them into a dataframe

# %%
## Concatenate all ts together into one ts_df
ts_df = pd.concat(TS,axis=1)
ts_df
# Out:
#                            HOMICIDE  AGG. ASSAULT  COMMON ASSAULT  LARCENY  \
# CrimeDateTime
# 2014-01-01 00:00:00+00:00         2            22              19       34
# 2014-01-02 00:00:00+00:00         3             6              23       26
# 2014-01-03 00:00:00+00:00         1            11              17       16
# 2014-01-04 00:00:00+00:00         0            14              23       23
# 2014-01-05 00:00:00+00:00         0             9              22       19
# ...                             ...           ...             ...      ...
# 2021-05-18 00:00:00+00:00         0             9              12       19
# 2021-05-19 00:00:00+00:00         1             7              24       12
# 2021-05-20 00:00:00+00:00         0            15              15       14
# 2021-05-21 00:00:00+00:00         2            11              19        6
# 2021-05-22 00:00:00+00:00         2            11              14        5
#
#                            AUTO THEFT  ROBBERY - CARJACKING  BURGLARY  \
# CrimeDateTime
# 2014-01-01 00:00:00+00:00           9                   NaN        20
# 2014-01-02 00:00:00+00:00           7                   1.0        28
# 2014-01-03 00:00:00+00:00           3                   0.0        13
# 2014-01-04 00:00:00+00:00          14                   0.0        20
# 2014-01-05 00:00:00+00:00          11                   2.0        14
# ...                               ...                   ...       ...
# 2021-05-18 00:00:00+00:00           8                   0.0         9
# 2021-05-19 00:00:00+00:00          10                   1.0         6
# 2021-05-20 00:00:00+00:00           5                   3.0        10
# 2021-05-21 00:00:00+00:00           9                   1.0         3
# 2021-05-22 00:00:00+00:00           5                   1.0         3
#
#                            LARCENY FROM AUTO  ROBBERY - COMMERCIAL  SHOOTING  \
# CrimeDateTime
# 2014-01-01 00:00:00+00:00                 15                     2         2
# 2014-01-02 00:00:00+00:00                 10                     1         0
# 2014-01-03 00:00:00+00:00                  6                     1         1
# 2014-01-04 00:00:00+00:00                 15                     1         0
# 2014-01-05 00:00:00+00:00                 13                     0         2
# ...                                      ...                   ...       ...
# 2021-05-18 00:00:00+00:00                  5                     1         3
# 2021-05-19 00:00:00+00:00                  5                     0         0
# 2021-05-20 00:00:00+00:00                  6                     2         3
# 2021-05-21 00:00:00+00:00                  4                     1         2
# 2021-05-22 00:00:00+00:00                  1                     1         1
#
#                            ROBBERY - RESIDENCE  ROBBERY - STREET  ARSON  RAPE
# CrimeDateTime
# 2014-01-01 00:00:00+00:00                  1.0               8.0    NaN   5.0
# 2014-01-02 00:00:00+00:00                  1.0               4.0    NaN   0.0
# 2014-01-03 00:00:00+00:00                  1.0               2.0    NaN   0.0
# 2014-01-04 00:00:00+00:00                  1.0               7.0    NaN   0.0
# 2014-01-05 00:00:00+00:00                  1.0              10.0    NaN   1.0
# ...                                        ...               ...    ...   ...
# 2021-05-18 00:00:00+00:00                  2.0               5.0    2.0   NaN
# 2021-05-19 00:00:00+00:00                  2.0               6.0    NaN   NaN
# 2021-05-20 00:00:00+00:00                  1.0              10.0    NaN   NaN
# 2021-05-21 00:00:00+00:00                  1.0               9.0    NaN   NaN
# 2021-05-22 00:00:00+00:00                  NaN               NaN    NaN   NaN
#
# [2699 rows x 14 columns]

# %% [markdown]
# ### Visualize all ts with the differnet requency codes

# %%
## Plot the same ts as different frequencies
ts_df.plot()
# Out:
# <AxesSubplot:xlabel='CrimeDateTime'>

# %% [markdown]
# ### Dealing with Null Values

# %%
## Check For Null Values
ts_df.isna().sum()
# Out:
# HOMICIDE                0
# AGG. ASSAULT            0
# COMMON ASSAULT          0
# LARCENY                 0
# AUTO THEFT              0
# ROBBERY - CARJACKING    1
# BURGLARY                0
# LARCENY FROM AUTO       0
# ROBBERY - COMMERCIAL    0
# SHOOTING                0
# ROBBERY - RESIDENCE     1
# ROBBERY - STREET        1
# ARSON                   9
# RAPE                    6
# dtype: int64

# %%
# save a T/F index for if a row has any nulls
nulls = ts_df.isna().any(axis=1)


# check out the null rows
ts_df[nulls]
# Out:
#                            HOMICIDE  AGG. ASSAULT  COMMON ASSAULT  LARCENY  \
# CrimeDateTime
# 2014-01-01 00:00:00+00:00         2            22              19       34
# 2014-01-02 00:00:00+00:00         3             6              23       26
# 2014-01-03 00:00:00+00:00         1            11              17       16
# 2014-01-04 00:00:00+00:00         0            14              23       23
# 2014-01-05 00:00:00+00:00         0             9              22       19
# 2021-05-17 00:00:00+00:00         3            14              25       12
# 2021-05-18 00:00:00+00:00         0             9              12       19
# 2021-05-19 00:00:00+00:00         1             7              24       12
# 2021-05-20 00:00:00+00:00         0            15              15       14
# 2021-05-21 00:00:00+00:00         2            11              19        6
# 2021-05-22 00:00:00+00:00         2            11              14        5
#
#                            AUTO THEFT  ROBBERY - CARJACKING  BURGLARY  \
# CrimeDateTime
# 2014-01-01 00:00:00+00:00           9                   NaN        20
# 2014-01-02 00:00:00+00:00           7                   1.0        28
# 2014-01-03 00:00:00+00:00           3                   0.0        13
# 2014-01-04 00:00:00+00:00          14                   0.0        20
# 2014-01-05 00:00:00+00:00          11                   2.0        14
# 2021-05-17 00:00:00+00:00           5                   2.0        11
# 2021-05-18 00:00:00+00:00           8                   0.0         9
# 2021-05-19 00:00:00+00:00          10                   1.0         6
# 2021-05-20 00:00:00+00:00           5                   3.0        10
# 2021-05-21 00:00:00+00:00           9                   1.0         3
# 2021-05-22 00:00:00+00:00           5                   1.0         3
#
#                            LARCENY FROM AUTO  ROBBERY - COMMERCIAL  SHOOTING  \
# CrimeDateTime
# 2014-01-01 00:00:00+00:00                 15                     2         2
# 2014-01-02 00:00:00+00:00                 10                     1         0
# 2014-01-03 00:00:00+00:00                  6                     1         1
# 2014-01-04 00:00:00+00:00                 15                     1         0
# 2014-01-05 00:00:00+00:00                 13                     0         2
# 2021-05-17 00:00:00+00:00                 12                     1         3
# 2021-05-18 00:00:00+00:00                  5                     1         3
# 2021-05-19 00:00:00+00:00                  5                     0         0
# 2021-05-20 00:00:00+00:00                  6                     2         3
# 2021-05-21 00:00:00+00:00                  4                     1         2
# 2021-05-22 00:00:00+00:00                  1                     1         1
#
#                            ROBBERY - RESIDENCE  ROBBERY - STREET  ARSON  RAPE
# CrimeDateTime
# 2014-01-01 00:00:00+00:00                  1.0               8.0    NaN   5.0
# 2014-01-02 00:00:00+00:00                  1.0               4.0    NaN   0.0
# 2014-01-03 00:00:00+00:00                  1.0               2.0    NaN   0.0
# 2014-01-04 00:00:00+00:00                  1.0               7.0    NaN   0.0
# 2014-01-05 00:00:00+00:00                  1.0              10.0    NaN   1.0
# 2021-05-17 00:00:00+00:00                  0.0               6.0    0.0   NaN
# 2021-05-18 00:00:00+00:00                  2.0               5.0    2.0   NaN
# 2021-05-19 00:00:00+00:00                  2.0               6.0    NaN   NaN
# 2021-05-20 00:00:00+00:00                  1.0              10.0    NaN   NaN
# 2021-05-21 00:00:00+00:00                  1.0               9.0    NaN   NaN
# 2021-05-22 00:00:00+00:00                  NaN               NaN    NaN   NaN

# %% [markdown]
# #### Q: what do we notice about our null values? Where are they?

# %% [markdown]
# > - We have several options for filling in null values for time series, based on what would be best for our data.

# %%
## FFill null values with the next non-null value
ts_df.bfill()[nulls]
# Out:
#                            HOMICIDE  AGG. ASSAULT  COMMON ASSAULT  LARCENY  \
# CrimeDateTime
# 2014-01-01 00:00:00+00:00         2            22              19       34
# 2014-01-02 00:00:00+00:00         3             6              23       26
# 2014-01-03 00:00:00+00:00         1            11              17       16
# 2014-01-04 00:00:00+00:00         0            14              23       23
# 2014-01-05 00:00:00+00:00         0             9              22       19
# 2021-05-17 00:00:00+00:00         3            14              25       12
# 2021-05-18 00:00:00+00:00         0             9              12       19
# 2021-05-19 00:00:00+00:00         1             7              24       12
# 2021-05-20 00:00:00+00:00         0            15              15       14
# 2021-05-21 00:00:00+00:00         2            11              19        6
# 2021-05-22 00:00:00+00:00         2            11              14        5
#
#                            AUTO THEFT  ROBBERY - CARJACKING  BURGLARY  \
# CrimeDateTime
# 2014-01-01 00:00:00+00:00           9                   1.0        20
# 2014-01-02 00:00:00+00:00           7                   1.0        28
# 2014-01-03 00:00:00+00:00           3                   0.0        13
# 2014-01-04 00:00:00+00:00          14                   0.0        20
# 2014-01-05 00:00:00+00:00          11                   2.0        14
# 2021-05-17 00:00:00+00:00           5                   2.0        11
# 2021-05-18 00:00:00+00:00           8                   0.0         9
# 2021-05-19 00:00:00+00:00          10                   1.0         6
# 2021-05-20 00:00:00+00:00           5                   3.0        10
# 2021-05-21 00:00:00+00:00           9                   1.0         3
# 2021-05-22 00:00:00+00:00           5                   1.0         3
#
#                            LARCENY FROM AUTO  ROBBERY - COMMERCIAL  SHOOTING  \
# CrimeDateTime
# 2014-01-01 00:00:00+00:00                 15                     2         2
# 2014-01-02 00:00:00+00:00                 10                     1         0
# 2014-01-03 00:00:00+00:00                  6                     1         1
# 2014-01-04 00:00:00+00:00                 15                     1         0
# 2014-01-05 00:00:00+00:00                 13                     0         2
# 2021-05-17 00:00:00+00:00                 12                     1         3
# 2021-05-18 00:00:00+00:00                  5                     1         3
# 2021-05-19 00:00:00+00:00                  5                     0         0
# 2021-05-20 00:00:00+00:00                  6                     2         3
# 2021-05-21 00:00:00+00:00                  4                     1         2
# 2021-05-22 00:00:00+00:00                  1                     1         1
#
#                            ROBBERY - RESIDENCE  ROBBERY - STREET  ARSON  RAPE
# CrimeDateTime
# 2014-01-01 00:00:00+00:00                  1.0               8.0    2.0   5.0
# 2014-01-02 00:00:00+00:00                  1.0               4.0    2.0   0.0
# 2014-01-03 00:00:00+00:00                  1.0               2.0    2.0   0.0
# 2014-01-04 00:00:00+00:00                  1.0               7.0    2.0   0.0
# 2014-01-05 00:00:00+00:00                  1.0              10.0    2.0   1.0
# 2021-05-17 00:00:00+00:00                  0.0               6.0    0.0   NaN
# 2021-05-18 00:00:00+00:00                  2.0               5.0    2.0   NaN
# 2021-05-19 00:00:00+00:00                  2.0               6.0    NaN   NaN
# 2021-05-20 00:00:00+00:00                  1.0              10.0    NaN   NaN
# 2021-05-21 00:00:00+00:00                  1.0               9.0    NaN   NaN
# 2021-05-22 00:00:00+00:00                  NaN               NaN    NaN   NaN

# %%
## FFill null values with the previous non-null value
ts_df.ffill()[nulls]
# Out:
#                            HOMICIDE  AGG. ASSAULT  COMMON ASSAULT  LARCENY  \
# CrimeDateTime
# 2014-01-01 00:00:00+00:00         2            22              19       34
# 2014-01-02 00:00:00+00:00         3             6              23       26
# 2014-01-03 00:00:00+00:00         1            11              17       16
# 2014-01-04 00:00:00+00:00         0            14              23       23
# 2014-01-05 00:00:00+00:00         0             9              22       19
# 2021-05-17 00:00:00+00:00         3            14              25       12
# 2021-05-18 00:00:00+00:00         0             9              12       19
# 2021-05-19 00:00:00+00:00         1             7              24       12
# 2021-05-20 00:00:00+00:00         0            15              15       14
# 2021-05-21 00:00:00+00:00         2            11              19        6
# 2021-05-22 00:00:00+00:00         2            11              14        5
#
#                            AUTO THEFT  ROBBERY - CARJACKING  BURGLARY  \
# CrimeDateTime
# 2014-01-01 00:00:00+00:00           9                   NaN        20
# 2014-01-02 00:00:00+00:00           7                   1.0        28
# 2014-01-03 00:00:00+00:00           3                   0.0        13
# 2014-01-04 00:00:00+00:00          14                   0.0        20
# 2014-01-05 00:00:00+00:00          11                   2.0        14
# 2021-05-17 00:00:00+00:00           5                   2.0        11
# 2021-05-18 00:00:00+00:00           8                   0.0         9
# 2021-05-19 00:00:00+00:00          10                   1.0         6
# 2021-05-20 00:00:00+00:00           5                   3.0        10
# 2021-05-21 00:00:00+00:00           9                   1.0         3
# 2021-05-22 00:00:00+00:00           5                   1.0         3
#
#                            LARCENY FROM AUTO  ROBBERY - COMMERCIAL  SHOOTING  \
# CrimeDateTime
# 2014-01-01 00:00:00+00:00                 15                     2         2
# 2014-01-02 00:00:00+00:00                 10                     1         0
# 2014-01-03 00:00:00+00:00                  6                     1         1
# 2014-01-04 00:00:00+00:00                 15                     1         0
# 2014-01-05 00:00:00+00:00                 13                     0         2
# 2021-05-17 00:00:00+00:00                 12                     1         3
# 2021-05-18 00:00:00+00:00                  5                     1         3
# 2021-05-19 00:00:00+00:00                  5                     0         0
# 2021-05-20 00:00:00+00:00                  6                     2         3
# 2021-05-21 00:00:00+00:00                  4                     1         2
# 2021-05-22 00:00:00+00:00                  1                     1         1
#
#                            ROBBERY - RESIDENCE  ROBBERY - STREET  ARSON  RAPE
# CrimeDateTime
# 2014-01-01 00:00:00+00:00                  1.0               8.0    NaN   5.0
# 2014-01-02 00:00:00+00:00                  1.0               4.0    NaN   0.0
# 2014-01-03 00:00:00+00:00                  1.0               2.0    NaN   0.0
# 2014-01-04 00:00:00+00:00                  1.0               7.0    NaN   0.0
# 2014-01-05 00:00:00+00:00                  1.0              10.0    NaN   1.0
# 2021-05-17 00:00:00+00:00                  0.0               6.0    0.0   1.0
# 2021-05-18 00:00:00+00:00                  2.0               5.0    2.0   1.0
# 2021-05-19 00:00:00+00:00                  2.0               6.0    2.0   1.0
# 2021-05-20 00:00:00+00:00                  1.0              10.0    2.0   1.0
# 2021-05-21 00:00:00+00:00                  1.0               9.0    2.0   1.0
# 2021-05-22 00:00:00+00:00                  1.0               9.0    2.0   1.0

# %%
## We have crime counts, so it makes sense to fill with 0
ts_df.fillna(0,inplace=True)

# %%
## Save df to csv for time series modeling next class
# ts_df.to_csv('baltimore_crime_counts_2021.csv')

# %% [markdown]
# # Time Series Trends

# %% [markdown]
# ## Types of Trends

# %% [markdown]
# <img src="https://raw.githubusercontent.com/learn-co-students/dsc-removing-trends-online-ds-ft-100719/master/images/new_trendseasonal.png" width=80%>

# %% [markdown]
# ### Stationarity

# %% [markdown]
# <div style="text-align:center;font-size:2em">Mean</div>
#
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-types-of-trends-online-ds-ft-100719/master/images/new_mean_nonstationary.png" width=70%>
# <br><br>
# <div style="text-align:center;font-size:3em">Variance</div>
# <img src="https://raw.githubusercontent.com/jirvingphd/dsc-types-of-trends-online-ds-ft-100719/master/images/new_cov_nonstationary.png" width=70%>
# </div>

# %% [markdown]
# ## Detecting Trends

# %%
## Grab ROBBERY - STREET and resample as weekly data
ts = ts_df["ROBBERY - STREET"].resample("W").sum()
ts.plot()
# Out:
# <AxesSubplot:xlabel='CrimeDateTime'>

# %% [markdown]
# ### Augmented Dickey Fuller Test for Stationarity

# %%
## Lab Function
# from statsmodels.tsa.stattools import adfuller

def adfuller_test_df(ts,index=['AD Fuller Results']):
    """Returns the AD Fuller Test Results and p-values for the null hypothesis
    that there the data is non-stationary (that there is a unit root in the data)"""
    
    df_res = tsa.stattools.adfuller(ts)

    names = ['Test Statistic','p-value','#Lags Used','# of Observations Used']
    res  = dict(zip(names,df_res[:4]))
    
    res['p<.05'] = res['p-value']<.05
    res['Stationary?'] = res['p<.05']
    
    if isinstance(index,str):
        index = [index]
    res_df = pd.DataFrame(res,index=index)
    res_df = res_df[['Test Statistic','#Lags Used',
                     '# of Observations Used','p-value','p<.05',
                    'Stationary?']]
    return res_df



def stationarity_check(TS,window=8,plot=True,index=['AD Fuller Results']):
    """Adapted from https://github.com/learn-co-curriculum/dsc-removing-trends-lab/tree/solution"""
    
    # Calculate rolling statistics
    roll_mean = TS.rolling(window=window, center=False).mean()
    roll_std = TS.rolling(window=window, center=False).std()
    
    # Perform the Dickey Fuller Test
    dftest = adfuller_test_df(TS,index=index)
    
    if plot:
        # Plot rolling statistics:
        fig = plt.figure(figsize=(12,6))
        plt.plot(TS, color='blue',label=f'Original (freq={TS.index.freq})')
        plt.plot(roll_mean, color='red', label=f'Rolling Mean (window={window})')
        plt.plot(roll_std, color='black', label = f'Rolling Std (window={window})')
        plt.legend(loc='best')
        plt.title('Rolling Mean & Standard Deviation')
        display(dftest)
        plt.show(block=False)
        
    return dftest

# %%
## Test stationariy check function 
res = stationarity_check(ts)
# Out:
#                    Test Statistic  #Lags Used  # of Observations Used  \
# AD Fuller Results       -2.720824           5                     380
#
#                     p-value  p<.05  Stationary?
# AD Fuller Results  0.070504  False        False

# %% [markdown]
# ## Removing Trends

# %% [markdown]
# - For time series modeling, we will want to get our time series stationary.*
#
# #### Trend Removal Methods
# - Differencing (`.diff()`)
# - Log-Transformation (`np.log`)
# - Subtract Rolling Mean (`ts-ts.rolling().mean()`)
# - Subtract Exponentially-Weighted Mean (`ts-ts.ewm().mean()`)
# - Seasonal Decomposition (`from statsmodels.tsa.seasonal import seasonal_decompose`
# )
#
# _`*`=caveat to be discussed tomorrow_

# %%
## Plot Original Time Series and Check for Stationarity
res = adfuller_test_df(ts)
ts.plot()
res
# Out:
#                    Test Statistic  #Lags Used  # of Observations Used  \
# AD Fuller Results       -1.851922           4                     172
#
#                     p-value  p<.05  Stationary?
# AD Fuller Results  0.355005  False        False

# %%
## Apply differnncing, plot and get adfuller test
ts_diff =ts.diff().dropna()
ts_diff.plot()
adfuller_test_df(ts_diff)
# Out:
#                    Test Statistic  #Lags Used  # of Observations Used  \
# AD Fuller Results      -11.342414           5                     379
#
#                         p-value  p<.05  Stationary?
# AD Fuller Results  1.046701e-20   True         True

# %%
## Log Transform, plot and get adfuller test
ts_log = np.log(ts)
ts_log.plot()
adfuller_test_df(ts_log)
# Out:
#                    Test Statistic  #Lags Used  # of Observations Used  \
# AD Fuller Results       -2.582485           4                     381
#
#                     p-value  p<.05  Stationary?
# AD Fuller Results  0.096672  False        False

# %%
ts.index.freq
# Out:
# <Week: weekday=6>

# %%
## Subtract Rolling mean
ts_rolling = ts-ts.rolling(4).mean()
ts_rolling.dropna(inplace=True)
ts_rolling.plot()
adfuller_test_df(ts_rolling)
# Out:
#                    Test Statistic  #Lags Used  # of Observations Used  \
# AD Fuller Results      -11.055785           4                     378
#
#                         p-value  p<.05  Stationary?
# AD Fuller Results  4.949090e-20   True         True

# %%
## Subtract Exponentially Weight Mean Rolling mean
ts_ewm = ts-ts.ewm(4).mean().dropna()
ts_ewm.dropna(inplace=True)

ts_ewm.plot()
adfuller_test_df(ts_ewm)
# Out:
#                    Test Statistic  #Lags Used  # of Observations Used  \
# AD Fuller Results      -10.919076           1                     384
#
#                         p-value  p<.05  Stationary?
# AD Fuller Results  1.049201e-19   True         True

# %% [markdown]
# #### Q: What do we notice? What methods achieved stationarity?

# %% [markdown]
# ### Seasonal Decomposition

# %%
## Use seasonal decompose on the ts and plot
plt.rcParams['figure.figsize']=(12,6)
decomp = tsa.seasonal_decompose(ts)
decomp.plot();

# %%
decomp.seasonal
# Out:
# CrimeDateTime
# 2014-01-05 00:00:00+00:00    -5.828279
# 2014-01-12 00:00:00+00:00   -11.339497
# 2014-01-19 00:00:00+00:00    -1.809048
# 2014-01-26 00:00:00+00:00     0.894477
# 2014-02-02 00:00:00+00:00    -5.926036
#                                ...
# 2021-04-25 00:00:00+00:00    -7.674433
# 2021-05-02 00:00:00+00:00    -4.418023
# 2021-05-09 00:00:00+00:00    -3.014177
# 2021-05-16 00:00:00+00:00    10.702170
# 2021-05-23 00:00:00+00:00    11.110823
# Freq: W-SUN, Name: seasonal, Length: 386, dtype: float64

# %% [markdown]
# #### Checking which components are stationary

# %%
## Save seasonal/trend/resid in a dictionary.
decomp_dict = {'seasonal':decomp.seasonal,
              'trend':decomp.trend,
              'resod':decomp.resid}
decomp_dict
# Out:
# {'seasonal': CrimeDateTime
#  2014-01-05 00:00:00+00:00    -5.828279
#  2014-01-12 00:00:00+00:00   -11.339497
#  2014-01-19 00:00:00+00:00    -1.809048
#  2014-01-26 00:00:00+00:00     0.894477
#  2014-02-02 00:00:00+00:00    -5.926036
#                                 ...
#  2021-04-25 00:00:00+00:00    -7.674433
#  2021-05-02 00:00:00+00:00    -4.418023
#  2021-05-09 00:00:00+00:00    -3.014177
#  2021-05-16 00:00:00+00:00    10.702170
#  2021-05-23 00:00:00+00:00    11.110823
#  Freq: W-SUN, Name: seasonal, Length: 386, dtype: float64,
#  'trend': CrimeDateTime
#  2014-01-05 00:00:00+00:00   NaN
#  2014-01-12 00:00:00+00:00   NaN
#  2014-01-19 00:00:00+00:00   NaN
#  2014-01-26 00:00:00+00:00   NaN
#  2014-02-02 00:00:00+00:00   NaN
#                               ..
#  2021-04-25 00:00:00+00:00   NaN
#  2021-05-02 00:00:00+00:00   NaN
#  2021-05-09 00:00:00+00:00   NaN
#  2021-05-16 00:00:00+00:00   NaN
#  2021-05-23 00:00:00+00:00   NaN
#  Freq: W-SUN, Name: trend, Length: 386, dtype: float64,
#  'resod': CrimeDateTime
#  2014-01-05 00:00:00+00:00   NaN
#  2014-01-12 00:00:00+00:00   NaN
#  2014-01-19 00:00:00+00:00   NaN
#  2014-01-26 00:00:00+00:00   NaN
#  2014-02-02 00:00:00+00:00   NaN
#                               ..
#  2021-04-25 00:00:00+00:00   NaN
#  2021-05-02 00:00:00+00:00   NaN
#  2021-05-09 00:00:00+00:00   NaN
#  2021-05-16 00:00:00+00:00   NaN
#  2021-05-23 00:00:00+00:00   NaN
#  Freq: W-SUN, Name: resid, Length: 386, dtype: float64}

# %%
## Make a list of adfuller results to append
results = []
## Save results of orig ts
results.append(adfuller_test_df(ts,index=['Original']))

## Loop through decomp dict, 
for trend, ts_ in decomp_dict.items():
    # Fill any missing values, get adfuller result
    ts_ = ts_.fillna(0)
    res = adfuller_test_df(ts_,index=trend)
    results.append(res)

    
    ## Append res to decomp_stationary

## make into a df
res_df = pd.concat(results)
res_df
# Out:
#           Test Statistic  #Lags Used  # of Observations Used       p-value  \
# Original       -2.720824           5                     380  7.050365e-02
# seasonal       -6.405976          17                     368  1.942891e-08
# trend          -1.256098           0                     385  6.490106e-01
# resod          -9.523942           1                     384  3.012835e-16
#
#           p<.05  Stationary?
# Original  False        False
# seasonal   True         True
# trend     False        False
# resod      True         True

# %%
## Pldot decomp again for convenient comparison
decomp.plot();

# %% [markdown]
# ### Summary

# %% [markdown]
# - Tomorrow we will continue working with the dataset we processed today for time series modeling.

# %% [markdown]
# # APPENDIX

# %% [markdown]
# ### Date Str Formatting

# %% [markdown]
# Formatting follows the Python datetime <strong><a href='http://strftime.org/'>strftime</a></strong> codes.<br>
# The following examples are based on <tt>datetime.datetime(2001, 2, 3, 16, 5, 6)</tt>:
# <br><br>
#
# <table style="display: inline-block">
# <tr><th>CODE</th><th>MEANING</th><th>EXAMPLE</th><tr>
# <tr><td>%Y</td><td>Year with century as a decimal number.</td><td>2001</td></tr>
# <tr><td>%y</td><td>Year without century as a zero-padded decimal number.</td><td>01</td></tr>
# <tr><td>%m</td><td>Month as a zero-padded decimal number.</td><td>02</td></tr>
# <tr><td>%B</td><td>Month as locale’s full name.</td><td>February</td></tr>
# <tr><td>%b</td><td>Month as locale’s abbreviated name.</td><td>Feb</td></tr>
# <tr><td>%d</td><td>Day of the month as a zero-padded decimal number.</td><td>03</td></tr>
# <tr><td>%A</td><td>Weekday as locale’s full name.</td><td>Saturday</td></tr>
# <tr><td>%a</td><td>Weekday as locale’s abbreviated name.</td><td>Sat</td></tr>
# <tr><td>%H</td><td>Hour (24-hour clock) as a zero-padded decimal number.</td><td>16</td></tr>
# <tr><td>%I</td><td>Hour (12-hour clock) as a zero-padded decimal number.</td><td>04</td></tr>
# <tr><td>%p</td><td>Locale’s equivalent of either AM or PM.</td><td>PM</td></tr>
# <tr><td>%M</td><td>Minute as a zero-padded decimal number.</td><td>05</td></tr>
# <tr><td>%S</td><td>Second as a zero-padded decimal number.</td><td>06</td></tr>
# </table>
# <table style="display: inline-block">
# <tr><th>CODE</th><th>MEANING</th><th>EXAMPLE</th><tr>
# <tr><td>%#m</td><td>Month as a decimal number. (Windows)</td><td>2</td></tr>
# <tr><td>%-m</td><td>Month as a decimal number. (Mac/Linux)</td><td>2</td></tr>
# <tr><td>%#x</td><td>Long date</td><td>Saturday, February 03, 2001</td></tr>
# <tr><td>%#c</td><td>Long date and time</td><td>Saturday, February 03, 2001 16:05:06</td></tr>
# </table>

# %% [markdown]
# ### Attempting Using Grouper like in lab, but not working

# %%
# ts_q = ts.to_frame()

# ts_q#.plot()

# %%
 # Use pandas grouper to group values using annual frequency
# year_groups = ts_q.groupby(pd.Grouper(freq ='A'))

# %%
# # Create a new DataFrame and store yearly values in columns 
# ts_annual = pd.DataFrame()

# for yr, group in year_groups:
# #     display(group.values)
# #     ts_annual[yr.year] = group.values.ravel()
    
# # Plot the yearly groups as subplots
# # ts_annual.plot(figsize = (13,8), subplots=True, legend=True);
